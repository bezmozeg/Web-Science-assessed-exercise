# %% [markdown]
# ### Imports

# %%
import tweepy
from pymongo import MongoClient
import json
import datetime
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from collections import Counter
import networkx as nx
import itertools

# %% [markdown]
# ### connect to mongodb

# %%
connection = MongoClient('localhost', 27017)
db = connection.TwitterStream
db.tweets.ensure_index("id", unique=True, dropDups=True)
collection = db.nba
# Out:
# C:\Users\Richard\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: ensure_index is deprecated. Use create_index instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Overriding stream Listener class

# %%
#override tweepy.StreamListener to add logic to on_status
class MyStreamListener(tweepy.StreamListener):

    def on_data(self, data):
        
        # Load the Tweet into the variable t
        tweet = json.loads(data)

        # Save the data to mongodb
        collection.save(tweet)

        return True

    def on_error(self, status_code):
        if status_code == 420:
        #returning False in on_error disconnects the stream
            return False

# %% [markdown]
# ### Authentication

# %%
app_key = "Ul47R28vil4FT307t0HcmYsPh"
app_secret = "ItL7fT9UyK94LLRTjgq8PZcsy7CKcbcf28j7qsm8IBwRKKHJz2"

access_token = "4860290417-8tvGbMQduk2x0rLZoqdwcM1pWK0tiI2QO1oqx1d"
access_token_secret = "d3AsnWVi70I2NNS5hK9FXhZPIyza8cUxOXi8vSvUaxvtn"

auth = tweepy.OAuthHandler(app_key, app_secret)
auth.set_access_token(access_token,access_token_secret)

api = tweepy.API(auth)

try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")
# Out:
# Authentication OK

# %% [markdown]
# ### call stream listener to collect data

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener,tweet_mode='extended')

myStream.filter(track=['NBA','Atlanta Hawks','Atlanta Hawks','Brooklyn Nets',
                      'Charlotte Hornets','Chicago Bulls','Cleveland Cavaliers',
                      'Dallas Mavericks','Denver Nuggets','Detroit Pistons',
                      'Golden State Warriors','GSW','Houston Rockets',
                      'Indiana Pacers','LA Clippers','Los Angeles Clippers',
                      'Los Angeles Lakers','LA Lakers','Memphis Grizzlies',
                      'Miami Heat','Milwaukee Bucks','Minnesota Timberwolves',
                      'New Orleans Pelicans','New York Knicks','NY Knicks',
                      'Oklahoma City Thunder','OKC','Orlando Magic',
                      'Philadelphia 76ers','76ers','Phoenix Suns',
                      'Portland Trail Blazers','Sacramento Kings',
                      'San Antonio Spurs','Toronto Raptors','Utah Jazz',
                      'Washington Wizards'])

# %% [markdown]
# ### enrich stream data with REST API data, probing tweets from NBA teams, most popular NBA players and NBA itself

# %%
accounts = ['NBA','kawhileonard','KingJames','JHarden13','StephenCurry30','AntDavis23','Yg_Trece',
           'JoelEmbiid','russwest44','KDTrey5','Dame_Lillard']
tweets = list()
for acc in accounts:
    for status in tweepy.Cursor(api.user_timeline, id=acc).items(500):
        tweets.append(status)

# %%
for i in range(len(tweets)):
    collection.save(tweets[i]._json)
print(len(tweets))
# Out:
# C:\Users\Richard\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: save is deprecated. Use insert_one or replace_one instead
# 5004

# %% [markdown]
# ### inspecting the most mentioned/retweeted/replied to usernames

# %%
usernames = list()

for tweet in collection.find():
    if tweet['in_reply_to_screen_name'] is not None:
        usernames.append(tweet['in_reply_to_screen_name'])
    try: 
        usernames.append(tweet['retweeted_status']['user']['screen_name'])
    except:
        pass
    try: 
        usernames.append(tweet['quoted_status']['user']['screen_name'])
    except:
        pass
    try:
        for user in tweet['entities']['user_mentions']:
            usernames.append(user['screen_name'])
    except:
        pass

# %%
frame = pd.DataFrame(usernames,columns=['username'])

# %%
frame['username'].value_counts()
# Out:
# J_UNDFTD           10725
# NBA                 2028
# Ballislife          1654
# DimesFromRose       1105
# BleacherReport       452
#                    ...
# ALeague                1
# EcopeSports            1
# HoopBallFantasy        1
# Theis_Fanclub          1
# Penya1930              1
# Name: username, Length: 4557, dtype: int64

# %%
hashtags = list()

for tweet in collection.find():
    try:
        for hashtag in tweet['entities']['hashtags']:
            hashtags.append(hashtag['text'])
    except:
        pass
hashes = pd.DataFrame(hashtags,columns=['hashtags'])
hashes['hashtags'].value_counts()
# Out:
# NBA                       1339
# nba                        146
# PS4live                    125
# NBATwitter                 121
# DFS                         88
#                           ...
# TeamZMP                      1
# LosAngeles                   1
# getpolished                  1
# forbes                       1
# Top25CollegeBasketball       1
# Name: hashtags, Length: 1419, dtype: int64

# %% [markdown]
# 1. cluster tweets based on text and time posted to separate tweets into
# 2. find important users
# 3. create network of user interactions

# %% [markdown]
# ### get tweets from database that are not retweets for clustering, also use english tweets only

# %%
clustering_tweets = list()

for tweet in collection.find({ "retweeted_status" : { "$exists" : False },'lang':'en' }):
    clustering_tweets.append(tweet)

# %%
len(clustering_tweets)
# Out:
# 5273

# %% [markdown]
# ### extract text, timestamp and userid from tweets to use for clustering

# %%
texts = list()
timestamps = list()
userids = list()

for tweet in clustering_tweets:
    texts.append(tweet['text'])
    timestamps.append(tweet['timestamp_ms'])
    userids.append(tweet['user']['id'])

# %%
clustering_data = pd.DataFrame({'text':texts,'timestamp':timestamps,'user_id':userids})

# %%
clustering_data.head()
# Out:
#                                                 text      timestamp  \
# 0  One of my favorite @NBA players growing up @re...  1583358796097
# 1     Move so garb it’s finally started going in 😂😂😂  1583358800328
# 2            Not gonna lie, I want LaMelo in the NBA  1583358801011
# 3  @BlackPressureC1 @MjsGoat Bench pressed over 5...  1583358802651
# 4  @NBABet5 @PuntsHeister @banks_220 @Geebee1st @...  1583358803553
#
#                user_id
# 0           2790755710
# 1  1085858856821960704
# 2  1034019455721000961
# 3  1056680460103925760
# 4            337388238

# %% [markdown]
# ### use only text for clustering

# %%
clustering_text = clustering_data['text']

# %%
vectorizer = TfidfVectorizer(stop_words='english',ngram_range=(1,2))

# %%
vectorizer.fit(clustering_text)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
text_matrix = vectorizer.transform(clustering_text)

# %%
clusterizer = KMeans(n_clusters=300)
clusterizer.fit(text_matrix)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=300, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
clustering_data['clusters'] = clusterizer.labels_

# %%
clustering_data['clusters'].value_counts().head(10)
# Out:
# 153    4386
# 195      91
# 5        76
# 37       51
# 27       18
# 11       15
# 6        15
# 173      15
# 52       14
# 227      11
# Name: clusters, dtype: int64

# %% [markdown]
# ### inspecting individual clusters

# %%
clustering_data[clustering_data['clusters']==153].head()
# Out:
#                                                 text      timestamp  \
# 0  One of my favorite @NBA players growing up @re...  1583358796097
# 1     Move so garb it’s finally started going in 😂😂😂  1583358800328
# 2            Not gonna lie, I want LaMelo in the NBA  1583358801011
# 3  @BlackPressureC1 @MjsGoat Bench pressed over 5...  1583358802651
# 4  @NBABet5 @PuntsHeister @banks_220 @Geebee1st @...  1583358803553
#
#                user_id  clusters
# 0           2790755710       153
# 1  1085858856821960704       153
# 2  1034019455721000961       153
# 3  1056680460103925760       153
# 4            337388238       153

# %%
clustering_data[clustering_data['clusters']==195].head()
# Out:
#                                                   text      timestamp  \
# 20   Check out my broadcast from my PlayStation 4! ...  1583358830114
# 43   Check out my broadcast from my PlayStation 4! ...  1583359296357
# 82   Check out my broadcast from my PlayStation 4! ...  1583359342559
# 97   Check out my broadcast from my PlayStation 4! ...  1583359369714
# 114  Check out my broadcast from my PlayStation 4! ...  1583359399030
#
#                  user_id  clusters
# 20   1117204447325765632       195
# 43    796215554885357569       195
# 82   1085628089915330560       195
# 97    796215554885357569       195
# 114             38917224       195

# %%
clustering_data[clustering_data['clusters']==5].head()
# Out:
#                                                   text      timestamp  \
# 73              Tony has 3, SSX tricky or NBA street 2  1583359333951
# 79                  NBA Street Vol 2 and GTA Vice City  1583359340511
# 88   Top 5:\nBully\nSan Andreas \nNBA Street vol 2\...  1583359351731
# 338  Midnight Club, NFL &amp; NBA Street, TH Pro Sk...  1583359650977
# 384                             nba street @Tye_birdie  1583359701018
#
#                 user_id  clusters
# 73            619335443         5
# 79            127573027         5
# 88           1668072798         5
# 338           576821141         5
# 384  751957017716203520         5

# %%
clustering_data[clustering_data['clusters']==37].head()
# Out:
#                                                   text      timestamp  \
# 145  NBA YoungBoy Drum Kit - Young GOAT - YoungBoy ...  1583359423975
# 325  NBA YoungBoy shit b hard but it just be like h...  1583359625396
# 332  nba youngboy fans getting viruses after trying...  1583359634993
# 348                   After she let NBA YoungBoy fuck.  1583359663356
# 530  I can't decide who's more garbage between him,...  1583359879031
#
#                  user_id  clusters
# 145            131835364        37
# 325           1666447922        37
# 332  1118988741190782976        37
# 348            152257299        37
# 530           1147085976        37

# %%
clustering_data[clustering_data['clusters']==27].head()
# Out:
#                                                    text      timestamp  \
# 118                                          Weak ass 😂  1583359402498
# 275                                      so weak 🤦🏻‍♂️😂  1583359554961
# 308                                Move is not weak 😂😂😂  1583359604440
# 688   If he killin dem with it, then how is it a wea...  1583360082642
# 1247                                    😂😂 not weak ass  1583360750817
#
#                  user_id  clusters
# 118            572187930        27
# 275            295243397        27
# 308            333173663        27
# 688   993842079938818049        27
# 1247           246461192        27

# %%
clustering_data[clustering_data['clusters']==11].head()
# Out:
#                                                    text      timestamp  \
# 721                             Start Kawhi, bench Bron  1583360117434
# 933                                Cut Giannis too easy  1583360378672
# 1182          Easy. Start Bron, bench Kawhi cut Giannis  1583360651518
# 1423   Start Bron, bench Kahwi, cut Giannis. I'm sorry.  1583360994255
# 1481  This easy, start Bron, Bench Bron, Cut everyon...  1583361042184
#
#          user_id  clusters
# 721    266699883        11
# 933    388337198        11
# 1182  3248075424        11
# 1423   496796977        11
# 1481  1180601594        11

# %%
clustering_data[clustering_data['clusters']==6].head()
# Out:
#             text      timestamp              user_id  clusters
# 395       On god  1583359714525           2500554718         6
# 538   On god😂😂😂😂  1583359889779            392490047         6
# 644    😂😂😂on god  1583360027658  1146101247163998208         6
# 907     Wash God  1583360356556             24348934         6
# 1405    Bron=God  1583360969017            965747156         6

# %%
clustering_data['clusters'].value_counts().describe()
# Out:
# count     300.000000
# mean       17.576667
# std       253.168016
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max      4386.000000
# Name: clusters, dtype: float64

# %% [markdown]
# ### developing user interaction network

# %%
#find users with highest number of mentions
tweets = collection.find()
mentions = list()

for tweet in tweets:
    try:
        for user in tweet['entities']['user_mentions']:
            mentions.append(user['screen_name'])
    except:
        pass

mentions = pd.DataFrame(mentions,columns=['mentioned'])

mentions['mentioned'].value_counts().head(10)
# Out:
# J_UNDFTD          4721
# NBA               1247
# Ballislife         721
# DimesFromRose      537
# espn               208
# BleacherReport     206
# KingJames          185
# PelicansNBA        144
# warriors           143
# JSJZBEY            143
# Name: mentioned, dtype: int64

# %%
#find most retweeted users
tweets = collection.find()
retweets = list()

for tweet in tweets:
    try: 
        retweets.append(tweet['retweeted_status']['user']['screen_name'])
    except:
        pass

retweets = pd.DataFrame(retweets,columns=['retweeted'])

retweets['retweeted'].value_counts().head(10)
# Out:
# J_UNDFTD          4712
# Ballislife         718
# NBA                555
# DimesFromRose      534
# BleacherReport     195
# espn               176
# JSJZBEY            143
# warriors           119
# alper_forza         88
# A_S12               86
# Name: retweeted, dtype: int64

# %%
#find most replied to users
tweets = collection.find()
replies = list()

for tweet in tweets:
    if tweet['in_reply_to_screen_name'] is not None:
        replies.append(tweet['in_reply_to_screen_name'])

replies = pd.DataFrame(replies,columns=['replied'])

replies['replied'].value_counts().head(10)
# Out:
# NBA                93
# barstoolsports     12
# OperationSports    11
# Bucks              11
# Lakers              8
# espn                8
# Lillard_SPFC        7
# undisputed          7
# nbastats            7
# EASPORTSNBALM       7
# Name: replied, dtype: int64

# %%
#find most quoted users
tweets = collection.find()
quoted = list()

for tweet in tweets:
    try: 
        quoted.append(tweet['quoted_status']['user']['screen_name'])
    except:
        pass

quoted = pd.DataFrame(quoted,columns=['quoted'])

quoted['quoted'].value_counts().head(10)
# Out:
# J_UNDFTD          1292
# Ballislife         213
# NBA                133
# HLNinEngeland      128
# ESPNNBA            127
# wojespn             78
# BenStinar           51
# AndrewDBailey       50
# BleacherReport      46
# sny_knicks          46
# Name: quoted, dtype: int64

# %% [markdown]
# ### generate edges for graph with python counter

# %%
edges = Counter()

# %%
for tweet in collection.find():
    user = tweet['user']['screen_name']
    
    if tweet['in_reply_to_screen_name'] is not None:
        edges[tuple([user,tweet['in_reply_to_screen_name']])]+=1
    try: 
        edges[tuple([user,tweet['retweeted_status']['user']['screen_name']])]+=1
    except:
        pass
    try: 
        edges[tuple([user,tweet['quoted_status']['user']['screen_name']])]+=1
    except:
        pass
    try:
        for mention in tweet['entities']['user_mentions']:
            edges[tuple([user,mention['screen_name']])]+=1
    except:
        pass

# %%
edges.most_common()
# Out:
# [(('bgeLYDsmCr4acLf', 'NBA'), 52),
#  (('Mell1453', 'NBA'), 30),
#  (('SethMadeNBA', 'NBA'), 20),
#  (('canteiro_hugo', 'NBA'), 20),
#  (('sultanabdumalik', 'iyaboawokoya'), 20),
#  (('James46493', 'NBALatam'), 18),
#  (('Flowgawd', 'NBA'), 18),
#  (('Ste_Gualdoni', 'NBA'), 18),
#  (('emre30680967', 'magnesei'), 16),
#  (('SGDNation', 'SGDNation'), 14),
#  (('mister_agyenkwa', 'NBA'), 14),
#  (('falatah_waleed', 'NBA'), 14),
#  (('Lillard_SPFC', 'Lillard_SPFC'), 13),
#  (('sportsAllnews_', 'NBA'), 13),
#  (('iAmTerrace', 'iAmTerrace'), 12),
#  (('AwesemoNBA', 'AwesemoNBA'), 12),
#  (('tvselm', 'Dee_Black_MMA_'), 12),
#  (('WJB_27', 'OnTheRotoRadar'), 11),
#  (('Homacityjosh', 'Homacityjosh'), 10),
#  (('freebagfamily', 'JimmyTheBag'), 10),
#  (('BrandonDoooooo', 'BrandonDoooooo'), 10),
#  (('Tom_RR_', 'OnTheRotoRadar'), 10),
#  (('dfsgustii', 'OnTheRotoRadar'), 10),
#  (('FlashPugUK', 'SportsWatch1'), 10),
#  (('KidBloggerJosh', 'courtsideheat'), 10),
#  (('hillshit_x2', 'hillshit2'), 9),
#  (('Underarmour3030', 'cavs'), 8),
#  (('LouissBluess', 'StefanosBetting'), 8),
#  (('GameUpLive', 'PercentBets'), 8),
#  (('MikePradaSBN', 'MikePradaSBN'), 8),
#  (('JoshMcGuire21', 'McGuireTipping'), 8),
#  (('McGuireTipping', 'McGuireTipping'), 8),
#  (('beltrancarlos6', 'EmbiidBetting'), 8),
#  (('dailysportpickz', 'dailysportpickz'), 8),
#  (('Osenny30', 'NBA'), 8),
#  (('MiamiMemeKing', 'RobLep1'), 8),
#  (('Kelvin_Rose09', 'NBALatam'), 8),
#  (('LUFC_JMC', 'McGuireTipping'), 8),
#  (('davidwon4206', 'DetroitPistons'), 8),
#  (('blowoutcards', 'BlowoutBuzz'), 8),
#  (('Lakers_newsnow', 'sports623'), 8),
#  (('StevieCozens', 'ripcityproject'), 8),
#  (('McWaYnE56', 'Ballislife'), 8),
#  (('FLAVORFLAV50', 'NBAextra'), 8),
#  (('youngsavaaaaage', 'Ballislife'), 8),
#  (('ApostolKurkchi1', 'NBA'), 8),
#  (('Tkre13', 'NBAJPN'), 8),
#  (('Mell1453', 'nbastats'), 8),
#  (('ekosilvo', 'ekosilvo'), 8),
#  (('Emerson79092373', 'BoomRadioNG'), 8),
#  (('ThisIsBasketbal', 'NBA'), 8),
#  (('Ste_Gualdoni', 'SLAMonline'), 8),
#  (('LouissBluess', 'EmbiidBetting'), 7),
#  (('bahisi13', 'magnesei'), 7),
#  (('BenRivelli', 'LAClippers'), 7),
#  (('beltrancarlos6', 'StefanosBetting'), 7),
#  (('tabito3005', 'Lakers'), 7),
#  (('tabito3005', 'CH14_'), 7),
#  (('tabito3005', 'LAGalaxy'), 7),
#  (('WJB_27', 'RotoRadarRiemer'), 7),
#  (('SGDNation', 'YouTube'), 7),
#  (('NotAirid', '_rockrob'), 7),
#  (('17RRaSO737X2fht', 'VegasBets4u'), 7),
#  (('DtjRoto', 'OnTheRotoRadar'), 6),
#  (('tahir99604545', 'magnesei'), 6),
#  (('ScottSt1963', 'dklive'), 6),
#  (('LockedOnNBANet', 'JeffGSpursZone'), 6),
#  (('LouissBluess', 'PronoLikes'), 6),
#  (('Anto7645287572', 'AMC_PRONOS'), 6),
#  (('JamesW91183', 'Kilapt5b'), 6),
#  (('WinWithMalliard', 'ekosilvo'), 6),
#  (('koyobez', 'NBA'), 6),
#  (('jkendrick1367', 'Ballislife'), 6),
#  (('JamesW91183', 'mitchell_ness'), 6),
#  (('kulgerald', 'OlumideAkpata'), 6),
#  (('CommunicateFail', 'CommunicateFail'), 6),
#  (('MUNEGU6010', 'PronoLikes'), 6),
#  (('LamarUnleashed', 'WashWizards'), 6),
#  (('Jadenblue13', 'NBA'), 6),
#  (('GaryWoodwardNU', 'PointSourceDFS'), 6),
#  (('rbakr34', 'alper_forza'), 6),
#  (('redsmith1', 'TheHerd'), 6),
#  (('bettingresource', 'dquanpicks'), 6),
#  (('Lonzoyeng3', 'NBA'), 6),
#  (('tabito3005', 'MRACIDO5'), 6),
#  (('Awesemo_Com', 'AwesemoNBA'), 6),
#  (('tmac36daexpert', 'cboyd304'), 6),
#  (('Gravy_gil', 'NBA'), 6),
#  (('choryman_30', '7Apuestas'), 6),
#  (('james58819561', 'NBA'), 6),
#  (('JesusCorral19', 'NBAspain'), 6),
#  (('radameldrogba', 'magnesei'), 6),
#  (('moralesw40', 'NBA'), 6),
#  (('jonrsinn', 'jkylemann'), 6),
#  (('Almightyspace', '_lamar3'), 6),
#  (('Kicklahoma', 'Kicklahoma'), 6),
#  (('DieselGreens', 'NBA'), 6),
#  (('_thatniggataje', 'Ballislife'), 6),
#  (('DFSolutionsCBB', 'DFSolutionsteam'), 6),
#  (('SheillaDingus', 'rwesthead'), 6),
#  (('LoveFox9', 'ct_nba'), 6),
#  (('SportBallBasket', 'SportBallBasket'), 6),
#  (('Basquetips', 'Basquetips'), 6),
#  (('SaidKaim4', 'NBAextra'), 6),
#  (('JaysonCDimaano2', 'DetroitPistons'), 6),
#  (('TheyCallMeMayu', 'NBA'), 6),
#  (('ASB_shadowrider', 'NBA'), 6),
#  (('cmolina_23', 'NBALatam'), 6),
#  (('donnie16393109', 'NBA'), 6),
#  (('jerome_olisa', 'NBA'), 6),
#  (('Ste_Gualdoni', 'MavsPR'), 6),
#  (('sx9d02c', 'komajuni'), 5),
#  (('dailypowerpicks', 'DiabloSports1'), 5),
#  (('MrNBA16', 'NBA'), 5),
#  (('xFreshie', 'FantasyLabsNBA'), 5),
#  (('flunch4life', 'TR_Pronos'), 5),
#  (('MRACIDO5', 'MRACIDO5'), 5),
#  (('MRACIDO5', 'Lakers'), 5),
#  (('Mell1453', 'dallasmavs'), 5),
#  (('LockedOnSpurs', 'JeffGSpursZone'), 5),
#  (('NEBRON46', 'NBA'), 5),
#  (('AustinHudson48', 'J_UNDFTD'), 5),
#  (('BaianoJokic', 'EditsLCzin'), 5),
#  (('SandyHuggins1', 'OnTheRotoRadar'), 5),
#  (('Namisauce', 'J_UNDFTD'), 5),
#  (('kovboy682', 'magnesei'), 5),
#  (('WJB_27', 'RotoRadarCEO'), 5),
#  (('MattWithAMouth', 'FinkMark1'), 5),
#  (('LegendaryJMFT', 'Jumpahoo'), 5),
#  (('ShelbyTMitchell', 'DavePasch'), 5),
#  (('Sportsandcard', 'PaniniAmerica'), 5),
#  (('HITMAN484848', 'AndrewDBailey'), 5),
#  (('showtimexv', 'NBA'), 5),
#  (('41_quinto', 'NBA'), 5),
#  (('NotAirid', 'nqstril'), 5),
#  (('echaan_', 'warriors'), 5),
#  (('keeenramos', 'NBA'), 5),
#  (('Jide_CB', 'HLNinEngeland'), 5),
#  (('atironho07', 'alphapronos_'), 5),
#  (('alvarrofficial', 'alphapronos_'), 5),
#  (('luisesoto171275', 'elgringo_mlb'), 5),
#  (('basketDAI1002', 'NBA'), 5),
#  (('uchi_96nba', 'uchi_96nba'), 5),
#  (('yagamikouhei', 'jjredick712'), 5),
#  (('bgeLYDsmCr4acLf', 'NBAonTNT'), 5),
#  (('LeManyRibera', 'SknurtBetting'), 5),
#  (('ArauldFranck', 'sekou_doums'), 5),
#  (('lildamo03', 'Ballislife'), 4),
#  (('ArasTozkoparan', 'magnesei'), 4),
#  (('abdullahmersi14', 'magnesei'), 4),
#  (('HaydiAdoo', 'magnesei'), 4),
#  (('Bahistasyonu', 'magnesei'), 4),
#  (('cakvukcak', 'magnesei'), 4),
#  (('AllSportsNoBull', 'SportsInsights'), 4),
#  (('bcsalvador', 'NBA'), 4),
#  (('real11722', 'magnesei'), 4),
#  (('sbnGrizzlies', 'sbnGrizzlies'), 4),
#  (('theninjadude10', 'warriors'), 4),
#  (('GameUpLive', 'SportsInsights'), 4),
#  (('Bevlin19', 'madewitlean'), 4),
#  (('Bevlin19', 'RandomHopJunkie'), 4),
#  (('dfsbachelor', 'FantasyLabsNBA'), 4),
#  (('edb288', 'cparrottSQUAWK'), 4),
#  (('FaizanQurashi', 'FaizanQurashi'), 4),
#  (('DdaGOAT_19', 'NBA'), 4),
#  (('Muzaffer1253', 'magnesei'), 4),
#  (('Arasyka_1', 'alper_forza'), 4),
#  (('Bendero_57', 'TR_Pronos'), 4),
#  (('BatistutaWin', 'BetBenjamin54'), 4),
#  (('Pluggedd_', 'J_UNDFTD'), 4),
#  (('MSIPronos_', 'REDsportsBE'), 4),
#  (('keysersoze_mil', 'NBA'), 4),
#  (('McQueenTips', 'alper_forza'), 4),
#  (('Alihikm50839378', 'alper_forza'), 4),
#  (('LilianPamphile', 'PronoLikes'), 4),
#  (('PhillyAnimal6', 'kornhauser22'), 4),
#  (('LightPronos', 'REDsportsBE'), 4),
#  (('nutmegiwobi', 'NBA'), 4),
#  (('mannebritt', 'J_UNDFTD'), 4),
#  (('CLobbos', 'twolves_brasil'), 4),
#  (('TherethaBoi', 'Ballislife'), 4),
#  (('chesselkhb', 'statmuse'), 4),
#  (('MRACIDO5', 'CH14_'), 4),
#  (('MRACIDO5', 'LAGalaxy'), 4),
#  (('level___up', 'nbawordandmovie'), 4),
#  (('Hatixx1', 'TR_Pronos'), 4),
#  (('WinWithMalliard', 'WinWithMalliard'), 4),
#  (('omartalib', 'NBA'), 4),
#  (('ClataroJames', 'kvng_matt29'), 4),
#  (('Osmanl145319', 'jojobetsosyal'), 4),
#  (('Rob_C54', 'J_UNDFTD'), 4),
#  (('Sir_Martineau', 'NBA'), 4),
#  (('xela751', 'PronoLikes'), 4),
#  (('Whatoynama27', 'magnesei'), 4),
#  (('ZANKA1907ZANKA', 'alper_forza'), 4),
#  (('JoshMcGuire21', 'NBA'), 4),
#  (('SportWarto', 'FirstTeam101'), 4),
#  (('kiriyama00', 'dunkshot25'), 4),
#  (('_MatthewPeralta', 'LakersNation'), 4),
#  (('T_Austin35', 'LeBronFactory'), 4),
#  (('KoalaSwagBamboo', 'NBA'), 4),
#  (('EmbiidBetting', 'StefanosBetting'), 4),
#  (('McGuireTipping', 'NBA'), 4),
#  (('newscommentary1', 'WinWithMalliard'), 4),
#  (('aazteamfc5', 'FirstTeam101'), 4),
#  (('Dagaustin2000', 'AlexKennedyNBA'), 4),
#  (('dfsnbabros', 'FantasyLabsNBA'), 4),
#  (('MtbLawson', 'vinnythibeault'), 4),
#  (('MtbLawson', 'antonin_org'), 4),
#  (('KABBFOX29', 'JeffGSpursZone'), 4),
#  (('News4SA', 'JeffGSpursZone'), 4),
#  (('CocosGist', 'OlumideAkpata'), 4),
#  (('Ferryr_7', 'Ballislife'), 4),
#  (('billyarnie', 'JeffGSpursZone'), 4),
#  (('stephenc67', 'Roc4EvaEva'), 4),
#  (('ElApostador16', '1'), 4),
#  (('RokRoule', 'FirstTeam101'), 4),
#  (('DemaurisaAdnam', 'ParlonsNBA'), 4),
#  (('jamees50724946', 'PronoLikes'), 4),
#  (('Fstxkh', 'PronoLikes'), 4),
#  (('ParlayQueen', 'Covers'), 4),
#  (('MrLoveisLove', 'SheaSerrano'), 4),
#  (('jkendrick1367', 'NBA'), 4),
#  (('beltrancarlos6', 'theo69prono'), 4),
#  (('E_TooSaucyy', 'Ballislife'), 4),
#  (('nestadu27', 'PronoLikes'), 4),
#  (('DerSchattenwolf', 'MLS_Germany'), 4),
#  (('jaysansan', 'SheaSerrano'), 4),
#  (('num1broncofan18', 'NBA'), 4),
#  (('onlinelisting', 'canadalisting1'), 4),
#  (('sportskarley', 'lastwordonsport'), 4),
#  (('Tom_RR_', 'RotoRadarRiemer'), 4),
#  (('JamesW91183', 'Charlottean28'), 4),
#  (('Alexin_Garcia', 'WeLovePhila'), 4),
#  (('SRKsChampion', 'TheLakersReview'), 4),
#  (('canadalisting1', 'canadalisting1'), 4),
#  (('clausubra', 'NBA'), 4),
#  (('WinWithMalliard', 'MichaelKnotts20'), 4),
#  (('PronosRipper', 'PronosRipper'), 4),
#  (('amaneko1108', 'NBAJPN'), 4),
#  (('PayetZinedine', 'PronoLikes'), 4),
#  (('jesussuarezgome', 'Multipickss'), 4),
#  (('nthonythegreat', 'J_UNDFTD'), 4),
#  (('_10SZD', 'NBA'), 4),
#  (('HUSTLEnSTACK', 'Ballislife'), 4),
#  (('dailysportpickz', 'FantasyLabsNBA'), 4),
#  (('JeremiahTrevi13', 'Ballislife'), 4),
#  (('_MarioHector_', 'NBA'), 4),
#  (('MalliardReport', 'WinWithMalliard'), 4),
#  (('AwesemoNBA', 'AwesemoDFS'), 4),
#  (('BigX84', 'NBA'), 4),
#  (('LuanwonderII', 'betchanger'), 4),
#  (('cboyd304', 'tmac36daexpert'), 4),
#  (('omouralinho', 'diogoosequeira'), 4),
#  (('riyane_s', 'TR_Pronos'), 4),
#  (('WitnessMurda', 'troybwai'), 4),
#  (('allsweaty', 'PlayLine'), 4),
#  (('dfsgustii', 'RotoRadarRiemer'), 4),
#  (('jrloading', 'hornets'), 4),
#  (('Jon49Jon', 'J_UNDFTD'), 4),
#  (('jesussuarezgome', 'SuperDatosVip'), 4),
#  (('TysonMurdockt', 'locher27'), 4),
#  (('AndrewMartinBet', 'BackAftaThis'), 4),
#  (('WagerDrop', 'WagerDrop'), 4),
#  (('Misanthrope75', 'Misanthrope75'), 4),
#  (('MiamiMemeKing', 'Krisplashed'), 4),
#  (('MiamiMemeKing', 'NYDailyNews'), 4),
#  (('MiamiMemeKing', 'NYDNSports'), 4),
#  (('CejeroTomas', 'riquiardo12'), 4),
#  (('malliardcom', 'WinWithMalliard'), 4),
#  (('jkendrick1367', 'wojespn'), 4),
#  (('DarrenAbenstein', 'ZackTeitel'), 4),
#  (('RotoRadarSox', 'OnTheRotoRadar'), 4),
#  (('Suebird00565589', 'KUHoops'), 4),
#  (('24Kobe_fan8', 'NBA'), 4),
#  (('DBZPronos', '1'), 4),
#  (('Elrond9_9', 'JuniorEbong'), 4),
#  (('LUFC_JMC', 'NBA'), 4),
#  (('ramreport4u', 'MattWerry'), 4),
#  (('Gianni_Tenori', 'MarcaBasket'), 4),
#  (('quent1marhadour', 'DEER0Z'), 4),
#  (('MarkOneSports', 'Money_LineDFS'), 4),
#  (('MaruHiroReiwa', 'PiaWurtzbach'), 4),
#  (('PronosBpm', 'PronosBpm'), 4),
#  (('DanieleTanedo', 'NBA'), 4),
#  (('ejioforkel', 'RotoRadarCEO'), 4),
#  (('ejioforkel', 'OnTheRotoRadar'), 4),
#  (('KamaX_PSG', 'DEER0Z'), 4),
#  (('iKoudy', 'ACSRuda'), 4),
#  (('DiKStark', 'Money_LineDFS'), 4),
#  (('zachtaylor98', 'Ballislife'), 4),
#  (('Jason', 'WhereByUs'), 4),
#  (('pronos_ones', 'DEER0Z'), 4),
#  (('SantiagoNunezC', 'ElPerimetroNBA'), 4),
#  (('ramreport4u', 'DOgemade'), 4),
#  (('Mati_Rosales', 'NBALatam'), 4),
#  (('dajosc11', 'ESPNStatsInfo'), 4),
#  (('LouissBluess', 'DEER0Z'), 4),
#  (('19jcerda', 'J_UNDFTD'), 4),
#  (('ACSRuda', 'iKoudy'), 4),
#  (('Maanuf96', 'ElPerimetroNBA'), 4),
#  (('ScHoolboy_Y', 'ESPNNBA'), 4),
#  (('GabrielManpig', 'JimmyTheBag'), 4),
#  (('6AKINGNYC', 'Jumpahoo'), 4),
#  (('sahinnn0941', 'magnesei'), 4),
#  (('VMuric91', 'magnesei'), 4),
#  (('NLLTweets', 'DUNOTS'), 4),
#  (('TheBlakeBeckham', 'SheaSerrano'), 4),
#  (('charliessports', 'charliessports'), 4),
#  (('MrLexLuthor', 'undisputed'), 4),
#  (('ak_19030', 'magnesei'), 4),
#  (('duko1954', 'bahisicerde'), 4),
#  (('BoldPilot22622', 'magnesei'), 4),
#  (('JesusCorral19', 'MovistarNBA'), 4),
#  (('wata1615', 'nbawordandmovie'), 4),
#  (('Bahistasyonu', 'bahisicerde'), 4),
#  (('MayumiLoveD', 'LAClippers'), 4),
#  (('Kevvvbaby', 'J_UNDFTD'), 4),
#  (('triggerhappy972', 'SharpSportsINC'), 4),
#  (('MattWithAMouth', 'seanqatnight'), 4),
#  (('TheJoeChiazza', 'JSJZBEY'), 4),
#  (('ultimatum_shop', 'NBA'), 4),
#  (('NerdNumbers', 'GreekGodofStats'), 4),
#  (('MayumiLoveD4', 'LAClippers'), 4),
#  (('cmvm1964', 'FantasyLabsNBA'), 4),
#  (('tjbey2000', 'Chris_Broussard'), 4),
#  (('PERFHEKTOR_BEAT', 'HelianHdz'), 4),
#  (('Daigo08443435', 'NBAJPN'), 4),
#  (('ChiefJerm', 'Ballislife'), 4),
#  (('tuseliot', 'jkylemann'), 4),
#  (('Chef_FEZ', 'TheLakersReview'), 4),
#  (('JAYY_WSP', 'NBA'), 4),
#  (('YamilRomanPSN', 'k014c'), 4),
#  (('melanieangeb', 'FirstTeam101'), 4),
#  (('Neoksiss__', 'LightPronos'), 4),
#  (('ItSG_Sn0w', 'JeffEisenband'), 4),
#  (('deeblock847', 'stanwawrinka'), 4),
#  (('nylle18', 'NBA'), 4),
#  (('Nandojose271', 'PuntajeIdealPE'), 4),
#  (('FastbreakOfsayt', 'FastbreakBh'), 4),
#  (('dribble_god16', 'Ballislife'), 4),
#  (('Dn4ZYy2TWFfdSwS', 'NBAJPN'), 4),
#  (('rudyglove27', 'PlayLine'), 4),
#  (('ruel_4745', 'undisputed'), 4),
#  (('LAKERS_224', 'BobbyMarks42'), 4),
#  (('MellyLive415', 'Ballislife'), 4),
#  (('tdot2117', 'NBA'), 4),
#  (('SaikoRanger', 'gigipicks'), 4),
#  (('TROTWAM', 'FantasyLabsNBA'), 4),
#  (('makatia', 'PuntajeIdealPE'), 4),
#  (('DEVON4L', 'J_UNDFTD'), 4),
#  (('702_dylan', 'SheaSerrano'), 4),
#  (('Real_Tyone', 'NBA'), 4),
#  (('allenisaballer', 'Nolan_Smith7'), 4),
#  (('KyiraPorch', 'J_UNDFTD'), 4),
#  (('oghtgod', 'J_UNDFTD'), 4),
#  (('UndisputdGOAT', 'LA_Goat_'), 4),
#  (('billfish2020', 'NBAJPN'), 4),
#  (('HpyCsPz', 'ESPNNBA'), 4),
#  (('Gavaaaaaa', 'Gavaaaaaa'), 4),
#  (('GRARDGra', 'CafedesParieurs'), 4),
#  (('BrumAxe', 'Bucks'), 4),
#  (('ES_Cristiano7', 'Bucks'), 4),
#  (('FLAVORFLAV50', 'NBAItalia'), 4),
#  (('AMPARADOXXX', 'J_UNDFTD'), 4),
#  (('davidwon4206', 'PelicansNBA'), 4),
#  (('TEAMDAR', 'PodcastDemand'), 4),
#  (('Champagne_Lo', 'OhMrWilson314'), 4),
#  (('_bubu3', 'NBAJPN'), 4),
#  (('BayramGabsi', 'NBA'), 4),
#  (('Jethroalicious', 'BleacherReport'), 4),
#  (('Ndbrown19', 'AustintOgden'), 4),
#  (('lautreec2', 'PronosRush'), 4),
#  (('DrrPower', 'NBA'), 4),
#  (('_voy6', 'NBA'), 4),
#  (('JesusShuttlew12', 'howboutthemsox'), 4),
#  (('tomiryuryu', 'NBA'), 4),
#  (('JesusShuttlew12', 'justkurt76'), 4),
#  (('Inesgaspar14', 'NBA'), 4),
#  (('XavierSamuels8', 'DaAnsahonSports'), 4),
#  (('Steve_Oster1', 'FlavioPogboum10'), 4),
#  (('amprokaka1', 'MavsPR'), 4),
#  (('c4ndym4n13', 'BleacherReport'), 4),
#  (('c4ndym4n13', 'NBA'), 4),
#  (('blakpearl68', 'warriors'), 4),
#  (('gballer115', 'BleacherReport'), 4),
#  (('Wavepapi64', 'NBA'), 4),
#  (('ferlopezhervas', 'vamos'), 4),
#  (('Hugo24494856', 'ElMundoNBA'), 4),
#  (('DavideFuma', 'NBA'), 4),
#  (('Erickfusili', 'NBA'), 4),
#  (('THP2411', 'SOTO_ud'), 4),
#  (('zsJv6FejKgxoqPh', 'NBAJPN'), 4),
#  (('LoveFox9', 'NBAJPN'), 4),
#  (('PacoVera17', 'celtics'), 4),
#  (('stefblackgenx', 'FABNEWYORK'), 4),
#  (('Nottocini', 'NBA'), 4),
#  (('SWilliacy', 'buffalospurs'), 4),
#  (('JaysonCDimaano2', 'celtics'), 4),
#  (('LeBron_AD_xoxo', 'NBA'), 4),
#  (('Imoad2', 'WarriorNationCP'), 4),
#  (('USAback_', 'CanalApuesta'), 4),
#  (('YuridjSantos', 'NBAdoPovo'), 4),
#  (('enriquemoscat', 'Rscm12'), 4),
#  (('JouannetFlorian', 'PronosRush'), 4),
#  (('gaetanomaisto', 'RassegnaZampa'), 4),
#  (('tomy2875', 'NBA'), 4),
#  (('lucas11hen', 'NBAdoPovo'), 4),
#  (('hahaxiaowen', 'NBA'), 4),
#  (('pixaim111', 'BleacherReport'), 4),
#  (('einvest_', 'jkubatko'), 4),
#  (('michihiyou', 'NBA'), 4),
#  (('RastaAsim', 'Its_karishma'), 4),
#  (('H6zq6syFy87qLi4', 'NBAJPN'), 4),
#  (('Emerson79092373', 'theBballarena'), 4),
#  (('Emerson79092373', 'IncredibleFEMI'), 4),
#  (('freztch', 'BleacherReport'), 4),
#  (('s0ul0H03', 'NBA'), 4),
#  (('Big3OnFirePod', 'hoopshype'), 4),
#  (('sportsAllnews_', 'MavsPR'), 4),
#  (('QChanet', 'lequipe'), 4),
#  (('kawym', 'NBA'), 4),
#  (('E13Flores', 'DimesFromRose'), 4),
#  (('TUnit97698487', 'NBA'), 4),
#  (('yungdomdom', '9OneTwo11'), 4),
#  (('jere_aucaruri', 'demas6Basket'), 4),
#  (('SiyawadyaReford', 'BleacherReport'), 4),
#  (('2798Aviz', 'BleacherReport'), 4),
#  (('shadow52jp', 'NBAJPN'), 4),
#  (('LetsTalk_NBA', 'NBA'), 4),
#  (('falcongreix', 'BleacherReport'), 4),
#  (('ticjboy', 'NBA'), 4),
#  (('johnnueno_', 'Ballislife'), 4),
#  (('Dyspo98529138', 'BleacherReport'), 4),
#  (('ChristiamSabal1', 'BleacherReport'), 4),
#  (('RocheVince', 'NBA'), 4),
#  (('crownmelitty_', 'KanePitman'), 4),
#  (('furtado_51', 'B24PT'), 4),
#  (('harvey_AE', 'NBA'), 4),
#  (('Ste_Gualdoni', 'luka7doncic'), 4),
#  (('Ste_Gualdoni', 'kporzee'), 4),
#  (('JeffBigDreamerH', 'BbqSmoka'), 4),
#  (('fordarnold', 'ESPNNBA'), 4),
#  (('Leonar18374668', 'NBALatam'), 4),
#  (('karoo55', 'dchinellato'), 4),
#  (('DtjRoto', 'RotoRadarRiemer'), 3),
#  (('mohammedtandia', 'NBA'), 3),
#  (('mohammedtandia', 'KristineLeahy'), 3),
#  (('mohammedtandia', 'KristenLedlow'), 3),
#  (('mohammedtandia', 'InesLabou'), 3),
#  (('mohammedtandia', 'SHAQ'), 3),
#  (('mohammedtandia', 'DR34M'), 3),
#  (('mohammedtandia', 'KDTrey5'), 3),
#  (('mohammedtandia', 'kawhileonard'), 3),
#  (('mohammedtandia', 'NazrMohammed'), 3),
#  (('mohammedtandia', 'IsiahThomas'), 3),
#  (('PhilippeBhanna', 'ParlonsNBA'), 3),
#  (('DJHollaMann', 'PercentBets'), 3),
#  (('pedrofd4', 'facucampazzo'), 3),
#  (('MischkeTyler', 'OriginalFunko'), 3),
#  (('PercentBets', 'PercentBets'), 3),
#  (('bcsalvador', 'Lakers'), 3),
#  (('king_mcnary', 'J_UNDFTD'), 3),
#  (('sergiorraial', 'globoesportecom'), 3),
#  (('Chris93Soto', 'evboogie'), 3),
#  (('Sharkytank', 'JoshEngleman'), 3),
#  (('MoonEmperor77', 'WeBeatTheSpread'), 3),
#  (('DonniAriele', 'TheUndefeated'), 3),
#  (('issac1823', 'J_UNDFTD'), 3),
#  (('KkingKosa', 'J_UNDFTD'), 3),
#  (('OJGF0929', 'RexChapman'), 3),
#  (('BurkoDallas', 'KobeTakes'), 3),
#  (('Ben237123', 'BleacherReport'), 3),
#  (('Tsumpterr', 'J_UNDFTD'), 3),
#  (('RevengeOfMyLs', 'timelesssports_'), 3),
#  (('Rhs_310', 'DetPistonsFR'), 3),
#  (('HP_917', 'IlianPronos'), 3),
#  (('raydanaj', 'J_UNDFTD'), 3),
#  (('dheath3180', 'OriginalFunko'), 3),
#  (('KingLarronidis_', 'J_UNDFTD'), 3),
#  (('thepodfather_', 'Dmac_DaDon'), 3),
#  (('Gavaaaaaa', 'NBA'), 3),
#  (('emoorez15', 'J_UNDFTD'), 3),
#  (('Hooperholic_10', 'J_UNDFTD'), 3),
#  (('YRPN____', 'J_UNDFTD'), 3),
#  (('Prime_Boogie', 'PrimeJA242'), 3),
#  (('SelfMade_JayDee', 'Ballislife'), 3),
#  (('Bevlin19', 'Ravens525520575'), 3),
#  (('og_dstaytrill', 'J_UNDFTD'), 3),
#  (('MEstibenHernan1', '4LogrosParley'), 3),
#  (('RexChapman', 'BleacherReport'), 3),
#  (('lilcharbz', 'ParlonsNBA'), 3),
#  (('C2_Cooper', 'C2_Cooper'), 3),
#  (('BobHarvey53', 'stevecarp56'), 3),
#  (('BobHarvey53', 'GamingTodayNews'), 3),
#  (('Trisity_', 'JADubin5'), 3),
#  (('EdmundWilliamC3', 'EdmundWilliamC3'), 3),
#  (('ivanssjgss', 'J_UNDFTD'), 3),
#  (('SSSSensei', 'J_UNDFTD'), 3),
#  (('3hristgian1', 'J_UNDFTD'), 3),
#  (('RoseGoldOK', 'NorthboundFL'), 3),
#  (('_Just_Ant', 'J_UNDFTD'), 3),
#  (('twoshotspodcast', 'JeffGSpursZone'), 3),
#  (('smaggpope2', 'Ballislife'), 3),
#  (('LUCIDJEFF', 'J_UNDFTD'), 3),
#  (('Sam_B5', 'Casadesparieurs'), 3),
#  (('ekow_Sarkcess', 'shattawalegh'), 3),
#  (('lashaguyia', 'BdlDom'), 3),
#  (('Irizarry_Cortes', 'J_UNDFTD'), 3),
#  (('ojedaaavictorrr', 'madeforthew_'), 3),
#  (('AdamowiczKurt', 'JayMoneyIsMoney'), 3),
#  (('ThatGuyTipp_', 'Ballislife'), 3),
#  (('IAmAaronLino', 'MURMANthaGOAT'), 3),
#  (('Jack_Rod_52', 'OriginalFunko'), 3),
#  (('NEBRON46', 'KingJames'), 3),
#  (('JamesW91183', 'NBA'), 3),
#  (('NEdegenerate', 'markbizmark'), 3),
#  (('MissTecii3', 'iAmTerrace'), 3),
#  (('Diego434Va', 'J_UNDFTD'), 3),
#  (('DJ_Ward_9', 'J_UNDFTD'), 3),
#  (('dr3amchaser1', 'Ballislife'), 3),
#  (('FantasyProsNBA', 'alexburnshoops'), 3),
#  (('RotoRadar', 'OnTheRotoRadar'), 3),
#  (('rotoradarmrktng', 'RotoRadar'), 3),
#  (('Swptoydolfan', '5ReasonsSports'), 3),
#  (('amprokaka1', 'NBA'), 3),
#  (('king6kong23', 'stanwawrinka'), 3),
#  (('AngeloOwens1', 'J_UNDFTD'), 3),
#  (('py_ball_', 'JADubin5'), 3),
#  (('sterling_hines', 'WeBeatTheSpread'), 3),
#  (('Pro_Des_Pronos', '1'), 3),
#  (('LA_Madridista23', 'JADubin5'), 3),
#  (('BrycenMcclurken', 'DimesFromRose'), 3),
#  (('xela751', 'StefanosBetting'), 3),
#  (('xela751', 'EmbiidBetting'), 3),
#  (('RodimusPrimeSA', 'JeffGSpursZone'), 3),
#  (('KoolKiddSh4n', 'TheNBACentral'), 3),
#  (('EllaCoreleone', 'ChrissyFireWat1'), 3),
#  (('BallScrawl', 'Ballislife'), 3),
#  (('BTDelaney', 'WeBeatTheSpread'), 3),
#  (('Splashxgod', 'J_UNDFTD'), 3),
#  (('knarsu3', 'JADubin5'), 3),
#  (('mari_zou', 'Jumbokun_GOJETS'), 3),
#  (('MtbLawson', 'Kevinharlan'), 3),
#  (('Insert_USN_Here', 'NBA'), 3),
#  (('detroit_chill', 'J_UNDFTD'), 3),
#  (('keflocc8x', 'J_UNDFTD'), 3),
#  (('IAmHarrison317', 'J_UNDFTD'), 3),
#  (('yungsace1', 'bgksubi'), 3),
#  (('TheKitchensHeat', 'BostonKemba'), 3),
#  (('Hunta512', 'FantasyLabsNBA'), 3),
#  (('SantaDel43', 'OriginalFunko'), 3),
#  (('davidiwan1', 'JADubin5'), 3),
#  (('RotoRadarRiemer', 'RotoRadarRiemer'), 3),
#  (('Treyspo', 'Ballislife'), 3),
#  (('rafaello_blau', 'NBAMEX'), 3),
#  (('MichaelKnotts20', 'CivilRights'), 3),
#  (('Nbanks7142', 'BenDuBose'), 3),
#  (('JD_Donalson18', 'KamoWidDaLocks'), 3),
#  (('WolvesGotNext', 'ESPNNBA'), 3),
#  (('devilspeakss', 'J_UNDFTD'), 3),
#  (('FantasyProsNBA', 'Beerad30'), 3),
#  (('LilDaDon_', 'SportsCenter'), 3),
#  (('TrubiskyisMVP', 'nyknicks'), 3),
#  (('JBunn10', 'wojespn'), 3),
#  (('joshade12', 'AKISNBA'), 3),
#  (('mvplamar8', 'mvplamar8'), 3),
#  (('Germ2301', 'J_UNDFTD'), 3),
#  (('Rcrump684', 'J_UNDFTD'), 3),
#  (('dede_wanders', 'AndrewDBailey'), 3),
#  (('Northmoorking', 'eBay'), 3),
#  (('Ali39_', 'J_UNDFTD'), 3),
#  (('KingHiestThe1st', 'J_UNDFTD'), 3),
#  (('EbediyetY', 'Multeci1i'), 3),
#  (('oldirtyboya', 'J_UNDFTD'), 3),
#  (('IamHighHefner', 'J_UNDFTD'), 3),
#  (('MannyNeva77', 'Lamentedtraffic'), 3),
#  (('iamChristian__', 'J_UNDFTD'), 3),
#  (('nathaniel_32', 'J_UNDFTD'), 3),
#  (('Jermayne_Gordon', 'WeBeatTheSpread'), 3),
#  (('DtjRoto', 'RotoRadar'), 3),
#  (('Jzizzzle_', 'J_UNDFTD'), 3),
#  (('AB_Spice', 'J_UNDFTD'), 3),
#  (('ClampGodDre', 'OKCTHUNDERAlex'), 3),
#  (('mar_cusr', 'J_UNDFTD'), 3),
#  (('Blame_TheSteph', 'J_UNDFTD'), 3),
#  (('bradleylizamajr', 'xKingTk'), 3),
#  (('ZFlizoyd23', 'J_UNDFTD'), 3),
#  (('betchanger', 'betchanger'), 3),
#  (('redsmith1', 'ColinCowherd'), 3),
#  (('iiliahuh', 'J_UNDFTD'), 3),
#  (('Dmarcus22', 'NBA'), 3),
#  (('SandyHuggins1', 'RotoRadar'), 3),
#  (('BasedFacts', 'J_UNDFTD'), 3),
#  (('Lomeli_24', 'Ballislife'), 3),
#  (('jrobb4real', 'J_UNDFTD'), 3),
#  (('Cuffyofee', 'J_UNDFTD'), 3),
#  (('RotoRadarSox', 'RotoRadar'), 3),
#  (('HawaiianCurls', 'J_UNDFTD'), 3),
#  (('ProDamasceno', 'CavsQuebrada'), 3),
#  (('KTaylormade_', 'J_UNDFTD'), 3),
#  (('PerezPiooo', 'J_UNDFTD'), 3),
#  (('boss_ror', 'NBAMEX'), 3),
#  (('rippleofhope', 'SainAsylum'), 3),
#  (('nba_opinioes', 'SeeRed_Br'), 3),
#  (('410Quise', 'J_UNDFTD'), 3),
#  (('bigjaime13', 'locks_time'), 3),
#  (('KaiFinesse_', 'J_UNDFTD'), 3),
#  (('jetttman', 'J_UNDFTD'), 3),
#  (('BSpiveS', 'J_UNDFTD'), 3),
#  (('RaphaelJeffers3', 'WeBeatTheSpread'), 3),
#  (('philobrainiac1', 'Tony_Pesta'), 3),
#  (('troybwai', 'WitnessMurda'), 3),
#  (('AnthonyNotEarl', 'AmicoHoops'), 3),
#  (('FantasyProsNBA', 'smooth1074'), 3),
#  (('BeenADrill', 'Ballislife'), 3),
#  (('only1armaun', 'J_UNDFTD'), 3),
#  (('ludachrist0pher', 'iAmTerrace'), 3),
#  (('JoshPosh__', 'J_UNDFTD'), 3),
#  (('rablack77', 'Ballislife'), 3),
#  (('Dansan88', 'RotoRadarCEO'), 3),
#  (('joshwills0', 'J_UNDFTD'), 3),
#  (('victoriaaalxo', 'TangerineHoops'), 3),
#  (('Fobajae1', 'WeBeatTheSpread'), 3),
#  (('MaxMarcusComedy', 'ThisLeaguenet'), 3),
#  (('Scoo73r', 'DHAhole'), 3),
#  (('Bk4ever306', 'NBA'), 3),
#  (('AlexLaDue41', 'OnTheRotoRadar'), 3),
#  (('leonida41481101', 'PistonsFR'), 3),
#  (('Jollofricejim', 'Jollofricejim'), 3),
#  (('reeseynem', 'J_UNDFTD'), 3),
#  (('jdawg0913', 'WeBeatTheSpread'), 3),
#  (('BasedWizdom', 'J_UNDFTD'), 3),
#  (('bocajoes', 'FZucchi'), 3),
#  (('SPORTWORLDORDER', 'TheLakeShowLife'), 3),
#  (('Mvnny4', 'J_UNDFTD'), 3),
#  (('IironFoster', 'J_UNDFTD'), 3),
#  (('iherring0597', 'J_UNDFTD'), 3),
#  (('simpsonart', 'WeBeatTheSpread'), 3),
#  (('joshua1eo', 'joshua1eo'), 3),
#  (('LineSniperHQ', '1NBAInsidr'), 3),
#  (('Stuk_On_Stupid', 'ESPNNBA'), 3),
#  (('FTWPicks', 'FTWPicks'), 3),
#  (('tommyk415', 'RotoRadarCEO'), 3),
#  (('mochiku78896', 'OnTheRotoRadar'), 3),
#  (('zibucketts', 'J_UNDFTD'), 3),
#  (('nappyheaddre', 'J_UNDFTD'), 3),
#  (('Z_Herbo', 'J_UNDFTD'), 3),
#  (('Ak3ch_2k19', 'J_UNDFTD'), 3),
#  (('drylgz', 'J_UNDFTD'), 3),
#  (('AhmedMo30280852', 'Alito_NBA'), 3),
#  (('keem_48', 'WeBeatTheSpread'), 3),
#  (('AJTheManChild', 'JerrelXL'), 3),
#  (('AJTheManChild', '0oty_Mac'), 3),
#  (('max_made_', 'J_UNDFTD'), 3),
#  (('RotoRadarCEO', 'RotoRadarCEO'), 3),
#  (('jarvyjarvNOW', 'J_UNDFTD'), 3),
#  (('ikadmos_', 'OnTheRotoRadar'), 3),
#  (('HTXSportsGod', 'MikePradaSBN'), 3),
#  (('Hank_Allen34', 'A_S12'), 3),
#  (('_FlyyTai', 'J_UNDFTD'), 3),
#  (('JeniMakesTweets', 'SharpNickel'), 3),
#  (('DeePlumbaRy', 'SharpNickel'), 3),
#  (('otgbasketball', 'OTG_NICK'), 3),
#  (('TedFMC', 'Casadesparieurs'), 3),
#  (('aboogiemars', 'Ballislife'), 3),
#  (('WJB_27', 'RotoRadar'), 3),
#  (('de_Milo33', 'SainAsylum'), 3),
#  (('ecosdeportivos', 'NBAMEX'), 3),
#  (('KouassiShimon', 'madeforthew_'), 3),
#  (('BalloutBabyy_', 'J_UNDFTD'), 3),
#  (('debmffl', 'NBA'), 3),
#  (('Rhadium', 'OriginalFunko'), 3),
#  (('BeckyHammoon', 'BeckyHammon'), 3),
#  (('cbrreezy', 'J_UNDFTD'), 3),
#  (('CHAMP_ZOE', 'J_UNDFTD'), 3),
#  (('l2w_zai', 'J_UNDFTD'), 3),
#  (('John32193769', 'NBA'), 3),
#  (('Kaelob23', 'DimesFromRose'), 3),
#  (('SavijShah', 'espn'), 3),
#  (('BoyMamaCyn', 'SportsWLoveIndy'), 3),
#  (('Rw_moe', 'J_UNDFTD'), 3),
#  (('ECSportsInvest', 'badpeatmoss'), 3),
#  (('MattWithAMouth', 'Lemilli_Lemilli'), 3),
#  (('MattWithAMouth', 'WrestlingCWO'), 3),
#  (('MattWithAMouth', 'RRSterling'), 3),
#  (('MattWithAMouth', 'NBA'), 3),
#  (('Sigi_Sabe', 'J_UNDFTD'), 3),
#  (('_JasonLT', '_kinabii'), 3),
#  (('CantankerusFemi', 'ClarenceGaines2'), 3),
#  (('lebren23james', 'smodelanalytics'), 3),
#  (('itsStackk', 'AndrewDBailey'), 3),
#  (('Theactualhashmi', 'J_UNDFTD'), 3),
#  (('nemo_atl', 'J_UNDFTD'), 3),
#  (('kirklandXxX', 'J_UNDFTD'), 3),
#  (('dorianwaller02', 'BenDuBose'), 3),
#  (('Kowalsky2', 'unesceptico'), 3),
#  (('raremar_', 'J_UNDFTD'), 3),
#  (('ZanolettiA', 'Lakers'), 3),
#  (('YeahDasDion', 'J_UNDFTD'), 3),
#  (('Jschorr121', 'OriginalFunko'), 3),
#  (('CaashCartii', 'J_UNDFTD'), 3),
#  (('Terrell_444', 'J_UNDFTD'), 3),
#  (('ShelbyTMitchell', 'announcerskeds'), 3),
#  (('UhOhSpaghettiJo', 'nbastats'), 3),
#  (('UhOhSpaghettiJo', 'AndrewDBailey'), 3),
#  (('laemory', 'ESPNNBA'), 3),
#  (('theyhatelild', 'J_UNDFTD'), 3),
#  (('Nephew_Shaunie', 'J_UNDFTD'), 3),
#  (('luismar33898895', 'EnsaDeportiva'), 3),
#  (('Bump4Dayzz', 'J_UNDFTD'), 3),
#  (('coryoo4', 'PointSourceDFS'), 3),
#  (('OrigHue', 'J_UNDFTD'), 3),
#  (('_WarrenDwyer', 'Betside_'), 3),
#  (('StephWRLD', 'HenryTheBlasian'), 3),
#  (('almxghtybee', 'SainAsylum'), 3),
#  (('jhaas1986', 'WeBeatTheSpread'), 3),
#  (('eakhead', 'TravelKing711'), 3),
#  (('christverita', 'indeselsalvador'), 3),
#  (('torandtp', 'PlayoffCurry'), 3),
#  (('Deli_Fresh_', 'J_UNDFTD'), 3),
#  (('Prada_Gee_', 'J_UNDFTD'), 3),
#  (('nyama_ks', 'FullPressRadio'), 3),
#  (('nyama_ks', 'FPC_FantasyPod'), 3),
#  (('romani_jean', 'dailysportpickz'), 3),
#  (('swavey_spence07', 'HoodieCurry'), 3),
#  (('ClevelandGod', 'ClevelandGod'), 3),
#  (('baccwoodsurgeon', 'J_UNDFTD'), 3),
#  (('jake_schaffer15', '_jon____'), 3),
#  (('NOTLIMITS1996', 'NOTLIMITS1996'), 3),
#  (('_a2na', 'TrashTalk_fr'), 3),
#  (('210shifty', 'J_UNDFTD'), 3),
#  (('Rickycarius', 'J_UNDFTD'), 3),
#  (('BossMeech_', 'J_UNDFTD'), 3),
#  (('_diegolegend', 'J_UNDFTD'), 3),
#  (('MrClutch__', 'TommyBeer'), 3),
#  (('kosho711', 'Jumbokun_GOJETS'), 3),
#  (('PolarbearRalf', 'J_UNDFTD'), 3),
#  (('motu_tabe', 'Jumbokun_GOJETS'), 3),
#  (('DorothyJGentry', 'DorothyJGentry'), 3),
#  (('itzz_nice', 'J_UNDFTD'), 3),
#  (('realLouEtemi', 'podpicks1'), 3),
#  (('FinSports2', 'YouSlvmpedYT'), 3),
#  (('B_JEFEner', 'J_UNDFTD'), 3),
#  (('DannyFlacco', 'J_UNDFTD'), 3),
#  (('pickemorfade', 'WeBeatTheSpread'), 3),
#  (('Jae_Tha_Truth', 'SeanCunningham'), 3),
#  (('scottman86', 'OfficialNBARefs'), 3),
#  (('LasherBrian', 'WeBeatTheSpread'), 3),
#  (('iamahmadc_10', 'J_UNDFTD'), 3),
#  (('LescamJames_', 'J_UNDFTD'), 3),
#  (('jacobyo91087006', 'OriginalFunko'), 3),
#  (('MikeZeuss', 'Coolguy55510'), 3),
#  (('kamsims3', 'J_UNDFTD'), 3),
#  (('TyMenefee2', 'J_UNDFTD'), 3),
#  (('RealShiive', 'J_UNDFTD'), 3),
#  (('Trill_Aust0', 'J_UNDFTD'), 3),
#  (('giosenzapaura', 'J_UNDFTD'), 3),
#  (('connor_lipton', 'ProPelsTalk'), 3),
#  (('JnapPPT', 'ProPelsTalk'), 3),
#  (('_lifewithlai', 'TheUndefeated'), 3),
#  (('itsDieselbitch', 'J_UNDFTD'), 3),
#  (('RaikageTooCold', 'J_UNDFTD'), 3),
#  (('sour_faced', 'El_Chapo33'), 3),
#  (('RoyaltyLineups', 'RoyaltyLineups'), 3),
#  (('bioniclegamer', 'AndrewDBailey'), 3),
#  (('VenezuelanNyan', 'Ballislife'), 3),
#  (('BrumAxe', 'NBA'), 3),
#  (('IlRegglI', 'Bucks'), 3),
#  (('TDSportspodcast', 'TyDelbridge'), 3),
#  (('KanJayW3st', 'J_UNDFTD'), 3),
#  (('NickJohnson_100', 'BooneGage'), 3),
#  (('TheCoolMikey40', 'wojespn'), 3),
#  (('PodcastDemand', 'PodcastDemand'), 3),
#  (('Culdy_', 'J_UNDFTD'), 3),
#  (('_RobTheDon_', 'J_UNDFTD'), 3),
#  (('TheGloEra', 'J_UNDFTD'), 3),
#  (('deliohvillacis', 'NBAMEX'), 3),
#  (('Grimmy33', 'SportsCenter'), 3),
#  (('YouMattOrNahh3', 'J_UNDFTD'), 3),
#  (('moneym4rcus', 'J_UNDFTD'), 3),
#  (('rlackstn', 'exposinglines'), 3),
#  (('_veedubsss', 'J_UNDFTD'), 3),
#  (('patrickbuzzell', 'SeanGrandePBP'), 3),
#  (('deezylowe', 'J_UNDFTD'), 3),
#  (('estadistico77', 'ESPNDatos'), 3),
#  (('patrickbuzzell', 'KeithSmithNBA'), 3),
#  (('RealRiyanBadMon', 'BenStinar'), 3),
#  (('Sixaxis_92', 'Campanasixers'), 3),
#  (('RealizeRSports', 'Roc4EvaEva'), 3),
#  (('Flyy333', 'DimesFromRose'), 3),
#  (('officialiisaac2', 'HLNinEngeland'), 3),
#  (('JesusShuttlew12', 'NBA'), 3),
#  (('JesusShuttlew12', 'Bucks'), 3),
#  (('ebou11', 'HLNinEngeland'), 3),
#  (('Ahmed0Salihu', 'BleacherReport'), 3),
#  (('stef60160', 'DEER0Z'), 3),
#  (('dnpngnbn', 'warriors'), 3),
#  (('reddakuroro', 'NBA'), 3),
#  (('liightskiiiin', 'NBA'), 3),
#  (('treant30', 'warriors'), 3),
#  (('ManuAlder', 'ShamsCharania'), 3),
#  (('KoobaRS6', 'ObetNz'), 3),
#  (('raulc_1', 'ESPNNBA'), 3),
#  (('Woedieman', 'HLNinEngeland'), 3),
#  (('slam52', 'bbking_jp'), 3),
#  (('ara306991', 'Djosua4'), 3),
#  (('jjoyy_r', 'abscbnsports'), 3),
#  (('TalkTheTalkcast', 'SBNationRadio'), 3),
#  (('SandeepSalmon', 'verge'), 3),
#  (('Tiago_AVC', 'NBA'), 3),
#  (('Scrixx', 'DimesFromRose'), 3),
#  (('k1ZM7eQ3af9PIyS', 'warriors'), 3),
#  (('ItachiwaM', 'ObetNz'), 3),
#  (('Watanabe0041005', 'NBAJPN'), 3),
#  (('utrilla1902', 'ESPNNBA'), 3),
#  (('canteiro_hugo', 'luka7doncic'), 3),
#  (('omindo_harry', 'NBA'), 3),
#  (('svinteli', 'NBA'), 3),
#  (('ligayaaaaajo', 'NBA'), 3),
#  (('tom_san9', 'TAC_pronos'), 3),
#  (('sanchesvx', 'warriors_bra'), 3),
#  (('elvisfan05', 'NBA'), 3),
#  (('SinoRoyale', 'SinoRoyale'), 3),
#  (('SuegartJorge', 'MeridianoTV'), 3),
#  (('karlbubi', 'de_trillest'), 3),
#  (('karlbubi', 'Ms_West___'), 3),
#  (('rickbanchez', 'rickbanchez'), 3),
#  (('EnricoSandalo', 'NBA'), 3),
#  (('carlitos__1970', 'Herniaxx'), 3),
#  (('Raulvalencia00', 'partidazocope'), 3),
#  (('sadalll8', 'Jumbokun_GOJETS'), 3),
#  (('rutnyy', 'TAC_pronos'), 3),
#  (('myway17_25', 'DT_prosports'), 3),
#  (('manwith0606', 'ct_nba'), 3),
#  (('Guillom311', 'ObetNz'), 3),
#  (('yuukiogu0221', 'DT_prosports'), 3),
#  (('Mell1453', 'luka7doncic'), 3),
#  (('Ezedelbueno', 'Pickandrollweb'), 3),
#  (('Emerson79092373', 'CarisLeVert'), 3),
#  (('Emerson79092373', 'BrooklynNets'), 3),
#  (('Emerson79092373', 'KDTrey5'), 3),
#  (('Emerson79092373', 'KyrieIrving'), 3),
#  (('Emerson79092373', 'StephenCurry30'), 3),
#  (('Christhee_B', 'RealGomezRM'), 3),
#  (('TimoCTB', 'MiamiHEAT'), 3),
#  (('AxelFreshPrince', 'J_UNDFTD'), 3),
#  (('ata__mert', 'thesameoldarca'), 3),
#  (('ata__mert', 'baglandeniz'), 3),
#  (('OhrscarO', 'HLNinEngeland'), 3),
#  (('mitsuhiko_NBA', 'mitsuhiko_NBA'), 3),
#  (('teyiadzufehh', 'NBA'), 3),
#  (('ThomasPsg6', 'DEER0Z'), 3),
#  (('rhuan_boeira2', 'NBA'), 3),
#  (('Thomsko__', 'AmphiBet'), 3),
#  (('VictorSharma12', 'ESPNNBA'), 3),
#  (('Alpha_salt', 'HLNinEngeland'), 3),
#  (('mtwana_mwatsama', 'J_UNDFTD'), 3),
#  (('Kimyasseverus13', 'Basketbol_Bet'), 3),
#  (('javisnok', 'Ballislife'), 3),
#  (('oz4ry', 'binksesteban'), 3),
#  (('vipalmo', 'CrayziJordan'), 3),
#  (('ohmyjeddy', 'NBA'), 3),
#  (('bgeLYDsmCr4acLf', 'CarisLeVert'), 3),
#  (('bgeLYDsmCr4acLf', 'BrooklynNets'), 3),
#  (('CRISTYYYY', 'warriors'), 3),
#  (('pascara_', 'HLNinEngeland'), 3),
#  (('StephBrun41', 'ParisRMC'), 3),
#  (('DarkEvEin', 'PandaKingss'), 3),
#  (('azndrwhng', 'zo_arroyo'), 3),
#  (('bgeLYDsmCr4acLf', 'celtics'), 3),
#  (('evil_liz', 'RexChapman'), 3),
#  (('Hadrien55048142', 'AKLIM49'), 3),
#  (('SexionMolle', 'NBA'), 3),
#  (('SwannyFR', 'SwannyBetting'), 2),
#  (('rashad1of1', 'KING_Addi1'), 2),
#  (('SantanaCabana', 'J_UNDFTD'), 2),
#  (('__d_tae34', 'thejonswag'), 2),
#  (('Brandon73944697', 'J_UNDFTD'), 2),
#  (('HOLLOWTIPS16', 'J_UNDFTD'), 2),
#  (('hnsldrch', 'Ballislife'), 2),
#  (('RubensFaria8', 'NBAdoPovo'), 2),
#  (('sadcowboysfan42', 'BrandonDoooooo'), 2),
#  (('Rafaaaa__77', 'tonechrist_'), 2),
#  (('RustyMathews', 'Ballislife'), 2),
#  (('KenLand22', 'TodayInSports3'), 2),
#  (('2_fez', 'NBABet5'), 2),
#  (('MysteriousE98', 'NBA'), 2),
#  (('LaYungBrownSkin', 'J_UNDFTD'), 2),
#  (('iLikeSportsHD', 'Dexerto'), 2),
#  (('volleyball00051', 'nbawordandmovie'), 2),
#  (('RobbieLyell', 'Collin_Summers'), 2),
#  (('stylesE', 'Rachel__Nichols'), 2),
#  (('cologneloring', 'KeithSmithNBA'), 2),
#  (('SaltyyFries', 'J_UNDFTD'), 2),
#  (('SirSavagee_', 'J_UNDFTD'), 2),
#  (('MarcMazeRemy414', 'ESPNNBA'), 2),
#  (('MicahPhillipss', 'J_UNDFTD'), 2),
#  (('MessyMeli', 'Yamscasino'), 2),
#  (('JaredDa79368581', 'ClayTravis'), 2),
#  (('Guttuhmook', 'J_UNDFTD'), 2),
#  (('SwannyFR', 'B_SportsUS7'), 2),
#  (('recipe2indulge4', 'thezosh0w'), 2),
#  (('ContentCorey', 'J_UNDFTD'), 2),
#  (('loteuryy', 'jaaakob_NA'), 2),
#  (('Alexflores_29', 'espn'), 2),
#  (('BatistutaWin', 'magnesei'), 2),
#  (('Sharkryan5', 'MovesMutual'), 2),
#  (('Tugrii1', 'magnesei'), 2),
#  (('DerrickAustinD', 'J_UNDFTD'), 2),
#  (('AlexisFaulknor', 'DarienJ4'), 2),
#  (('_kresteyn2', 'warriors'), 2),
#  (('macabi1307', 'odaskal'), 2),
#  (('cgabrieljacob', 'J_UNDFTD'), 2),
#  (('ThanelR', 'Ballislife'), 2),
#  (('_angiee_01', 'J_UNDFTD'), 2),
#  (('yuvalbason1', 'daniel93707328'), 2),
#  (('badousebastien', 'J_UNDFTD'), 2),
#  (('thabrogod', 'J_UNDFTD'), 2),
#  (('PChampgne', 'J_UNDFTD'), 2),
#  (('SweetJazzCandy_', 'J_UNDFTD'), 2),
#  (('Meka_Lullaby', 'ESPNNBA'), 2),
#  (('mohammedtandia', 'RanaAyyub'), 2),
#  (('WTFksUpKYLE', 'J_UNDFTD'), 2),
#  (('theoreis34', 'magnesei'), 2),
#  (('Kazm53674515', 'magnesei'), 2),
#  (('SLMJaeRock', 'DimesFromRose'), 2),
#  (('kenny_951', 'J_UNDFTD'), 2),
#  (('Fy_Bucks', 'J_UNDFTD'), 2),
#  (('snc_emir', 'magnesei'), 2),
#  (('Giovanni_Angel1', 'JSJZBEY'), 2),
#  (('toylauren', 'KeithSmithNBA'), 2),
#  (('TB_4Lifeee', 'J_UNDFTD'), 2),
#  (('mansa_movement', 'Ballislife'), 2),
#  (('The_Chosen_Plug', 'J_UNDFTD'), 2),
#  (('Mightyyyk', 'J_UNDFTD'), 2),
#  (('apakastan', 'wojespn'), 2),
#  (('AldidaBonkara', 'DragonflyJonez'), 2),
#  (('Riv_Chapo', 'PrimePG13'), 2),
#  (('Zeyv_', 'PronoLikes'), 2),
#  (('AntonioFletes11', 'NBA'), 2),
#  (('DjakaridjYeo', 'NtkPronos'), 2),
#  (('CJTrey8', 'BleacherReport'), 2),
#  (('irlweeknd', 'J_UNDFTD'), 2),
#  (('ThreeCard_Monte', 'DimesFromRose'), 2),
#  (('rollcage76', 'jo19N26'), 2),
#  (('tr3dition', 'J_UNDFTD'), 2),
#  (('willtylermartin', 'BleacherReport'), 2),
#  (('Hobby_Connect', 'CardsMarshall'), 2),
#  (('AmAustinClark', 'DimesFromRose'), 2),
#  (('ryancashh', 'J_UNDFTD'), 2),
#  (('FanTeamOfficial', 'WolfofInplay'), 2),
#  (('Yadier_03', 'TheHoopCentral'), 2),
#  (('InstaReaction', 'sixers'), 2),
#  (('jairuskenyanboy', 'J_UNDFTD'), 2),
#  (('thabxfish', 'prunerjim'), 2),
#  (('jackk_attackk', 'KateeForbis'), 2),
#  (('RoxanaReyes0114', 'NBAMEX'), 2),
#  (('JBushara92', 'wojespn'), 2),
#  (('PissedNewYorker', 'ClarenceGaines2'), 2),
#  (('Jugic888', 'NBA'), 2),
#  (('ThaBrody_CA', 'DetroitMBB'), 2),
#  (('WalterFalls', 'awfulannouncing'), 2),
#  (('Jiron_03', 'Super70sSports'), 2),
#  (('dominicvargas55', 'J_UNDFTD'), 2),
#  (('btibbl2', 'J_UNDFTD'), 2),
#  (('DwavY', 'timelesssports_'), 2),
#  (('acehndrxxx', 'J_UNDFTD'), 2),
#  (('talk_nyc', 'YouTube'), 2),
#  (('nwa_flow', 'ParlonsNBA'), 2),
#  (('CraftinStudios', 'JamieHudsonNBCS'), 2),
#  (('FilipSutic', 'NBCSWizards'), 2),
#  (('LegendaryLKing', 'DITQ15'), 2),
#  (('haleel_abdul', 'Ballislife'), 2),
#  (('benvoelliger', 'SportsCenter'), 2),
#  (('MtvTone', 'Nick_Argue'), 2),
#  (('IgorMarkovicg', 'NBA'), 2),
#  (('TheTamilore', 'Ballislife'), 2),
#  (('_nate_g', 'J_UNDFTD'), 2),
#  (('Xbox_One_Mad', 'es_movimiento'), 2),
#  (('realtaliarivera', 'J_UNDFTD'), 2),
#  (('monicakbernardo', 'J_UNDFTD'), 2),
#  (('mitchy_badazz', 'J_UNDFTD'), 2),
#  (('CharlyC_04', 'J_UNDFTD'), 2),
#  (('BiggJonas', 'J_UNDFTD'), 2),
#  (('itsShemar', 'J_UNDFTD'), 2),
#  (('Alihikm50839378', 'magnesei'), 2),
#  (('MattEderer', 'OperationSports'), 2),
#  (('betodahandyman', 'J_UNDFTD'), 2),
#  (('dahviiii', 'SheaSerrano'), 2),
#  (('abnel_capestany', 'TheHoopCentral'), 2),
#  (('ALBall75', 'JSJZBEY'), 2),
#  (('ChrisDonoyan11', 'SportsCenter'), 2),
#  (('ANDRESA50946949', 'rafarenteria11'), 2),
#  (('ANDRESA50946949', 'Lakers'), 2),
#  (('ANDRESA50946949', 'CH14_'), 2),
#  (('ANDRESA50946949', 'LAGalaxy'), 2),
#  (('ItaloGaribaldi', 'J_UNDFTD'), 2),
#  (('blxckambition', 'J_UNDFTD'), 2),
#  (('cashwithflash', 'windailydfs'), 2),
#  ...]

# %% [markdown]
# ### generate graph to analyze network measures

# %%
general_network = nx.DiGraph()

# %%
for edge in edges:
    general_network.add_edge(edge[0],edge[1],weight=edges[edge])

# %%
# Out:
# {'003': 1315775380986,
#  '012': 409911012,
#  '021C': 7201,
#  '021D': 11512,
#  '021U': 18765830,
#  '030C': 0,
#  '030T': 1136,
#  '102': 3105013,
#  '111D': 876,
#  '111U': 149,
#  '120C': 1,
#  '120D': 79,
#  '120U': 118,
#  '201': 75,
#  '210': 9,
#  '300': 8}

# %% [markdown]
# ### generate hashtag coocurence graph for general data

# %% [markdown]
# ##### find most used hashtags

# %%
hashtags = list()

for tweet in collection.find():
    try:
        for hashtag in tweet['entities']['hashtags']:
            hashtags.append(hashtag['text'])
    except:
        pass
hashes = pd.DataFrame(hashtags,columns=['hashtags'])
hashes['hashtags'].value_counts().head(10)
# Out:
# NBA            1339
# nba             146
# PS4live         125
# NBATwitter      121
# DFS              88
# NBAjp            83
# 꽁머니              66
# TeamParieur      63
# PhantomCam       59
# Celtics          54
# Name: hashtags, dtype: int64

# %% [markdown]
# ##### generate tuples of coocuring hashtags

# %%
general_hashtags = Counter()

# %%
for tweet in collection.find():
    try:
        for pair in itertools.combinations(tweet['entities']['hashtags'],2):
            general_hashtags[frozenset([pair[0]['text'],pair[1]['text']])]+=1
    except:
        pass

# %%
general_hashtags.most_common()
# Out:
# [(frozenset({'NBA', 'NBATwitter'}), 109),
#  (frozenset({'DFS', 'NBA'}), 85),
#  (frozenset({'NBA', 'NBAjp'}), 83),
#  (frozenset({'꽁머니', '프로토'}), 60),
#  (frozenset({'가입꽁머니', '꽁머니'}), 60),
#  (frozenset({'꽁머니', '꽁머니홍보'}), 60),
#  (frozenset({'꽁머니', '꽁머니공유사이'}), 60),
#  (frozenset({'가입꽁1만', '꽁머니'}), 60),
#  (frozenset({'꽁머니', '메이저'}), 60),
#  (frozenset({'꽁머니', '스포츠픽'}), 60),
#  (frozenset({'꽁머니', '매일지급되는가족방2만'}), 60),
#  (frozenset({'NBA', 'TeamParieur'}), 41),
#  (frozenset({'GrindCity', 'NBA'}), 40),
#  (frozenset({'Basketball', 'NBA'}), 34),
#  (frozenset({'가입꽁머니', '프로토'}), 30),
#  (frozenset({'꽁머니홍보', '프로토'}), 30),
#  (frozenset({'꽁머니공유사이', '프로토'}), 30),
#  (frozenset({'가입꽁1만', '프로토'}), 30),
#  (frozenset({'메이저', '프로토'}), 30),
#  (frozenset({'스포츠픽', '프로토'}), 30),
#  (frozenset({'매일지급되는가족방2만', '프로토'}), 30),
#  (frozenset({'가입꽁머니', '꽁머니홍보'}), 30),
#  (frozenset({'가입꽁머니', '꽁머니공유사이'}), 30),
#  (frozenset({'가입꽁1만', '가입꽁머니'}), 30),
#  (frozenset({'가입꽁머니', '메이저'}), 30),
#  (frozenset({'가입꽁머니', '스포츠픽'}), 30),
#  (frozenset({'가입꽁머니', '매일지급되는가족방2만'}), 30),
#  (frozenset({'꽁머니공유사이', '꽁머니홍보'}), 30),
#  (frozenset({'가입꽁1만', '꽁머니홍보'}), 30),
#  (frozenset({'꽁머니홍보', '메이저'}), 30),
#  (frozenset({'꽁머니홍보', '스포츠픽'}), 30),
#  (frozenset({'꽁머니홍보', '매일지급되는가족방2만'}), 30),
#  (frozenset({'가입꽁1만', '꽁머니공유사이'}), 30),
#  (frozenset({'꽁머니공유사이', '메이저'}), 30),
#  (frozenset({'꽁머니공유사이', '스포츠픽'}), 30),
#  (frozenset({'꽁머니공유사이', '매일지급되는가족방2만'}), 30),
#  (frozenset({'꽁머니'}), 30),
#  (frozenset({'가입꽁1만', '메이저'}), 30),
#  (frozenset({'가입꽁1만', '스포츠픽'}), 30),
#  (frozenset({'가입꽁1만', '매일지급되는가족방2만'}), 30),
#  (frozenset({'메이저', '스포츠픽'}), 30),
#  (frozenset({'매일지급되는가족방2만', '메이저'}), 30),
#  (frozenset({'매일지급되는가족방2만', '스포츠픽'}), 30),
#  (frozenset({'NBA', 'Warriors'}), 28),
#  (frozenset({'MLB', 'NBA'}), 28),
#  (frozenset({'Celtics', 'NBA'}), 27),
#  (frozenset({'GrindCity', 'NBAjp'}), 27),
#  (frozenset({'expertpicks', 'guaranteedpick'}), 26),
#  (frozenset({'nba', 'nfl'}), 26),
#  (frozenset({'NBA'}), 25),
#  (frozenset({'NBA', 'RepTheDistrict'}), 23),
#  (frozenset({'mlb', 'nba'}), 23),
#  (frozenset({'mlb', 'nfl'}), 23),
#  (frozenset({'NBA', 'NHL'}), 22),
#  (frozenset({'NBATwitter', 'Warriors'}), 22),
#  (frozenset({'Claflin_RYS20'}), 21),
#  (frozenset({'NBA', 'OTRR'}), 20),
#  (frozenset({'DFS', 'OTRR'}), 20),
#  (frozenset({'NBAjp', 'RepTheDistrict'}), 20),
#  (frozenset({'NBATwitter', 'nba'}), 20),
#  (frozenset({'EuroLeague', 'NBA'}), 20),
#  (frozenset({'basketball', 'nba'}), 19),
#  (frozenset({'EuroLeague', 'MLB'}), 19),
#  (frozenset({'NBA', 'NCAAB'}), 18),
#  (frozenset({'NBATwitter', 'Nbatwitter'}), 18),
#  (frozenset({'NBATwitter', 'Nfltwitter'}), 18),
#  (frozenset({'NBATwitter', 'nfl'}), 18),
#  (frozenset({'NBATwitter', 'mlb'}), 18),
#  (frozenset({'Nbatwitter', 'Nfltwitter'}), 18),
#  (frozenset({'Nbatwitter', 'nba'}), 18),
#  (frozenset({'Nbatwitter', 'nfl'}), 18),
#  (frozenset({'Nbatwitter', 'mlb'}), 18),
#  (frozenset({'NBA', 'Nbatwitter'}), 18),
#  (frozenset({'Nfltwitter', 'nba'}), 18),
#  (frozenset({'Nfltwitter', 'nfl'}), 18),
#  (frozenset({'Nfltwitter', 'mlb'}), 18),
#  (frozenset({'NBA', 'Nfltwitter'}), 18),
#  (frozenset({'NBA', 'nba'}), 18),
#  (frozenset({'NBA', 'nfl'}), 18),
#  (frozenset({'NBA', 'mlb'}), 18),
#  (frozenset({'NBA', 'cheatsheet'}), 18),
#  (frozenset({'NBA', 'RT'}), 18),
#  (frozenset({'RT', 'cheatsheet'}), 18),
#  (frozenset({'GirlDad', 'WomensHistoryMonth'}), 17),
#  (frozenset({'NBA', 'バスケ'}), 17),
#  (frozenset({'NBA', 'basketball'}), 16),
#  (frozenset({'MFFL', 'NBA'}), 15),
#  (frozenset({'DubNation', 'NBA'}), 15),
#  (frozenset({'DubNation', 'NBAjp'}), 15),
#  (frozenset({'lakers', 'learnfromthebest'}), 14),
#  (frozenset({'guaranteedpick', 'marchmadness'}), 14),
#  (frozenset({'NBA', 'バスケットボール'}), 13),
#  (frozenset({'expertpicks', 'marchmadness'}), 13),
#  (frozenset({'nba', 'nhl'}), 12),
#  (frozenset({'LakeShow', 'NBA'}), 12),
#  (frozenset({'Coronavirus', 'NBA'}), 11),
#  (frozenset({'バスケ', 'バスケットボール'}), 11),
#  (frozenset({'CBB', 'NBA'}), 11),
#  (frozenset({'NBA', 'Thunder'}), 11),
#  (frozenset({'ESPN', 'NBA'}), 10),
#  (frozenset({'Lakers', 'NBA'}), 10),
#  (frozenset({'MFFL', 'NBAnaESPN'}), 10),
#  (frozenset({'NBA', 'NCAA'}), 9),
#  (frozenset({'DraftKings', 'NBA'}), 9),
#  (frozenset({'FearTheDeer', 'NBA'}), 9),
#  (frozenset({'NBA', 'RegalosDeSuperDatosVip'}), 9),
#  (frozenset({'Bulls', 'Cubs'}), 9),
#  (frozenset({'Bears', 'Bulls'}), 9),
#  (frozenset({'Bears', 'Cubs'}), 9),
#  (frozenset({'FanDuel', 'NBA'}), 9),
#  (frozenset({'NBA', 'WeGoHard'}), 8),
#  (frozenset({'2k20', 'nba'}), 8),
#  (frozenset({'nba', 'nba2k20'}), 8),
#  (frozenset({'2k20', 'nba2k20'}), 8),
#  (frozenset({'Fanduel', 'NBA'}), 8),
#  (frozenset({'JDE', 'NBA'}), 8),
#  (frozenset({'Bucks', 'Pacers'}), 8),
#  (frozenset({'Bulls', 'Chicago'}), 8),
#  (frozenset({'MLB', 'NFL'}), 8),
#  (frozenset({'NBA', 'NFL'}), 8),
#  (frozenset({'Blue', 'Thunder'}), 8),
#  (frozenset({'NBATwitter', 'Thunder'}), 8),
#  (frozenset({'Blue', 'NBA'}), 8),
#  (frozenset({'Blue', 'NBATwitter'}), 8),
#  (frozenset({'ECCC', 'Funko'}), 7),
#  (frozenset({'ECCC', 'FunkoPop'}), 7),
#  (frozenset({'ECCC', 'Giveaway'}), 7),
#  (frozenset({'Funko', 'FunkoPop'}), 7),
#  (frozenset({'Funko', 'Giveaway'}), 7),
#  (frozenset({'FunkoPop', 'Giveaway'}), 7),
#  (frozenset({'BasketballCards', 'NBA'}), 7),
#  (frozenset({'NBA', 'WontBowDown'}), 7),
#  (frozenset({'GIVEAWAY', 'NBA'}), 7),
#  (frozenset({'はんニャリン', 'ハンナリーズ'}), 7),
#  (frozenset({'chibajets', 'はんニャリン'}), 7),
#  (frozenset({'はんニャリン', 'ジャンボくん'}), 7),
#  (frozenset({'はんニャリン', 'レバンガ北海道'}), 7),
#  (frozenset({'はんニャリン', '多嶋朝飛'}), 7),
#  (frozenset({'chibajets', 'ハンナリーズ'}), 7),
#  (frozenset({'ジャンボくん', 'ハンナリーズ'}), 7),
#  (frozenset({'ハンナリーズ', 'レバンガ北海道'}), 7),
#  (frozenset({'ハンナリーズ', '多嶋朝飛'}), 7),
#  (frozenset({'chibajets', 'ジャンボくん'}), 7),
#  (frozenset({'chibajets', 'レバンガ北海道'}), 7),
#  (frozenset({'chibajets', '多嶋朝飛'}), 7),
#  (frozenset({'ジャンボくん', 'レバンガ北海道'}), 7),
#  (frozenset({'ジャンボくん', '多嶋朝飛'}), 7),
#  (frozenset({'レバンガ北海道', '多嶋朝飛'}), 7),
#  (frozenset({'GamblingTwitter', 'NBA'}), 7),
#  (frozenset({'NBA', 'ParionsSport'}), 7),
#  (frozenset({'ParionsSport', 'TeamParieur'}), 7),
#  (frozenset({'NBA', 'ThunderUp'}), 7),
#  (frozenset({'fanduel', 'nba'}), 7),
#  (frozenset({'DFS', 'FanDuel'}), 7),
#  (frozenset({'guaranteedpick', 'sportspicks'}), 7),
#  (frozenset({'expertpicks', 'sportspicks'}), 7),
#  (frozenset({'Basketball', 'バスケットボール'}), 7),
#  (frozenset({'Basketball', 'バスケ'}), 7),
#  (frozenset({'NBA', '八村塁'}), 7),
#  (frozenset({'NBA', '꽁머니'}), 6),
#  (frozenset({'Basketball', 'Betting'}), 6),
#  (frozenset({'Betting', 'NBA'}), 6),
#  (frozenset({'NCAA', 'NHL'}), 6),
#  (frozenset({'NBA', 'Nuggets'}), 6),
#  (frozenset({'GOJoe', 'MightyJoeBiden'}), 6),
#  (frozenset({'GoArmy', 'MightyJoeBiden'}), 6),
#  (frozenset({'GoNavy', 'MightyJoeBiden'}), 6),
#  (frozenset({'DelawareState', 'MightyJoeBiden'}), 6),
#  (frozenset({'MightyJoeBiden', 'Princeton'}), 6),
#  (frozenset({'GOJoe', 'GoArmy'}), 6),
#  (frozenset({'GOJoe', 'GoNavy'}), 6),
#  (frozenset({'DelawareState', 'GOJoe'}), 6),
#  (frozenset({'GOJoe', 'Princeton'}), 6),
#  (frozenset({'GoArmy', 'GoNavy'}), 6),
#  (frozenset({'DelawareState', 'GoArmy'}), 6),
#  (frozenset({'GoArmy', 'Princeton'}), 6),
#  (frozenset({'DelawareState', 'GoNavy'}), 6),
#  (frozenset({'GoNavy', 'Princeton'}), 6),
#  (frozenset({'DelawareState', 'Princeton'}), 6),
#  (frozenset({'BeTheFight', 'NBA'}), 6),
#  (frozenset({'FreePicks', 'NBA'}), 6),
#  (frozenset({'TrumpTrain2020', 'trumptrain'}), 6),
#  (frozenset({'TrumpTrain2020', 'trump'}), 6),
#  (frozenset({'TrumpTariffs', 'TrumpTrain2020'}), 6),
#  (frozenset({'TrumpTrain2020', 'maga'}), 6),
#  (frozenset({'GOP', 'TrumpTrain2020'}), 6),
#  (frozenset({'RNC', 'TrumpTrain2020'}), 6),
#  (frozenset({'REPUBS', 'TrumpTrain2020'}), 6),
#  (frozenset({'DEMS', 'TrumpTrain2020'}), 6),
#  (frozenset({'DNC', 'TrumpTrain2020'}), 6),
#  (frozenset({'FBI', 'TrumpTrain2020'}), 6),
#  (frozenset({'DOJ', 'TrumpTrain2020'}), 6),
#  (frozenset({'Q', 'TrumpTrain2020'}), 6),
#  (frozenset({'trump', 'trumptrain'}), 6),
#  (frozenset({'TrumpTariffs', 'trumptrain'}), 6),
#  (frozenset({'maga', 'trumptrain'}), 6),
#  (frozenset({'GOP', 'trumptrain'}), 6),
#  (frozenset({'RNC', 'trumptrain'}), 6),
#  (frozenset({'REPUBS', 'trumptrain'}), 6),
#  (frozenset({'DEMS', 'trumptrain'}), 6),
#  (frozenset({'DNC', 'trumptrain'}), 6),
#  (frozenset({'FBI', 'trumptrain'}), 6),
#  (frozenset({'DOJ', 'trumptrain'}), 6),
#  (frozenset({'Q', 'trumptrain'}), 6),
#  (frozenset({'TrumpTariffs', 'trump'}), 6),
#  (frozenset({'maga', 'trump'}), 6),
#  (frozenset({'GOP', 'trump'}), 6),
#  (frozenset({'RNC', 'trump'}), 6),
#  (frozenset({'REPUBS', 'trump'}), 6),
#  (frozenset({'DEMS', 'trump'}), 6),
#  (frozenset({'DNC', 'trump'}), 6),
#  (frozenset({'FBI', 'trump'}), 6),
#  (frozenset({'DOJ', 'trump'}), 6),
#  (frozenset({'Q', 'trump'}), 6),
#  (frozenset({'TrumpTariffs', 'maga'}), 6),
#  (frozenset({'GOP', 'TrumpTariffs'}), 6),
#  (frozenset({'RNC', 'TrumpTariffs'}), 6),
#  (frozenset({'REPUBS', 'TrumpTariffs'}), 6),
#  (frozenset({'DEMS', 'TrumpTariffs'}), 6),
#  (frozenset({'DNC', 'TrumpTariffs'}), 6),
#  (frozenset({'FBI', 'TrumpTariffs'}), 6),
#  (frozenset({'DOJ', 'TrumpTariffs'}), 6),
#  (frozenset({'Q', 'TrumpTariffs'}), 6),
#  (frozenset({'GOP', 'maga'}), 6),
#  (frozenset({'RNC', 'maga'}), 6),
#  (frozenset({'REPUBS', 'maga'}), 6),
#  (frozenset({'DEMS', 'maga'}), 6),
#  (frozenset({'DNC', 'maga'}), 6),
#  (frozenset({'FBI', 'maga'}), 6),
#  (frozenset({'DOJ', 'maga'}), 6),
#  (frozenset({'Q', 'maga'}), 6),
#  (frozenset({'GOP', 'RNC'}), 6),
#  (frozenset({'GOP', 'REPUBS'}), 6),
#  (frozenset({'DEMS', 'GOP'}), 6),
#  (frozenset({'DNC', 'GOP'}), 6),
#  (frozenset({'FBI', 'GOP'}), 6),
#  (frozenset({'DOJ', 'GOP'}), 6),
#  (frozenset({'GOP', 'Q'}), 6),
#  (frozenset({'REPUBS', 'RNC'}), 6),
#  (frozenset({'DEMS', 'RNC'}), 6),
#  (frozenset({'DNC', 'RNC'}), 6),
#  (frozenset({'FBI', 'RNC'}), 6),
#  (frozenset({'DOJ', 'RNC'}), 6),
#  (frozenset({'Q', 'RNC'}), 6),
#  (frozenset({'DEMS', 'REPUBS'}), 6),
#  (frozenset({'DNC', 'REPUBS'}), 6),
#  (frozenset({'FBI', 'REPUBS'}), 6),
#  (frozenset({'DOJ', 'REPUBS'}), 6),
#  (frozenset({'Q', 'REPUBS'}), 6),
#  (frozenset({'DEMS', 'DNC'}), 6),
#  (frozenset({'DEMS', 'FBI'}), 6),
#  (frozenset({'DEMS', 'DOJ'}), 6),
#  (frozenset({'DEMS', 'Q'}), 6),
#  (frozenset({'DNC', 'FBI'}), 6),
#  (frozenset({'DNC', 'DOJ'}), 6),
#  (frozenset({'DNC', 'Q'}), 6),
#  (frozenset({'DOJ', 'FBI'}), 6),
#  (frozenset({'FBI', 'Q'}), 6),
#  (frozenset({'DOJ', 'Q'}), 6),
#  (frozenset({'art', 'basketball'}), 6),
#  (frozenset({'DubNation', 'NBABDAY'}), 6),
#  (frozenset({'nba', 'ncaa'}), 6),
#  (frozenset({'DetroitBasketball', 'NBA'}), 6),
#  (frozenset({'4Mar', 'NBA'}), 6),
#  (frozenset({'NFL', 'guaranteedpick'}), 6),
#  (frozenset({'NFL', 'expertpicks'}), 6),
#  (frozenset({'NFL', 'sportspicks'}), 6),
#  (frozenset({'NBA', 'RipCity'}), 6),
#  (frozenset({'NBA', 'Timberwolves'}), 6),
#  (frozenset({'feedly', 'sports'}), 6),
#  (frozenset({'NBA', 'Roadto500'}), 6),
#  (frozenset({'Basket', 'Nba'}), 6),
#  (frozenset({'NBA', 'UFC'}), 5),
#  (frozenset({'Bulls', 'NBA'}), 5),
#  (frozenset({'Lakeshow', 'NBA'}), 5),
#  (frozenset({'Free', 'NBA'}), 5),
#  (frozenset({'Draftkings', 'Fanduel'}), 5),
#  (frozenset({'DFS', 'Fanduel'}), 5),
#  (frozenset({'NBA', 'Pelicans'}), 5),
#  (frozenset({'NBA', 'NBATWITTER'}), 5),
#  (frozenset({'NBA', 'TeamParieurs'}), 5),
#  (frozenset({'Grizzlies', 'NBA'}), 5),
#  (frozenset({'NBA', 'News'}), 5),
#  (frozenset({'Chicago', 'MichaelJordan'}), 5),
#  (frozenset({'Bulls', 'MichaelJordan'}), 5),
#  (frozenset({'AUCTION', 'MichaelJordan'}), 5),
#  (frozenset({'AUCTION', 'Chicago'}), 5),
#  (frozenset({'AUCTION', 'Bulls'}), 5),
#  (frozenset({'dfs', 'fanduel'}), 5),
#  (frozenset({'dfs', 'nba'}), 5),
#  (frozenset({'MLB', 'guaranteedpick'}), 5),
#  (frozenset({'MLB', 'expertpicks'}), 5),
#  (frozenset({'MLB', 'sportspicks'}), 5),
#  (frozenset({'FREEPICKS', 'NBA'}), 5),
#  (frozenset({'NBA', 'WTA'}), 5),
#  (frozenset({'FreePick', 'NBA'}), 5),
#  (frozenset({'nba', 'nbatv'}), 5),
#  (frozenset({'fashion', 'poshmark'}), 5),
#  (frozenset({'NBA', 'pronos'}), 5),
#  (frozenset({'football', 'nba'}), 5),
#  (frozenset({'Cavs', 'NBA'}), 5),
#  (frozenset({'Transparent', 'Verfied'}), 4),
#  (frozenset({'Streaker', 'Verfied'}), 4),
#  (frozenset({'SportsBetting', 'Verfied'}), 4),
#  (frozenset({'Secure', 'Verfied'}), 4),
#  (frozenset({'FreePicks', 'Verfied'}), 4),
#  (frozenset({'Members', 'Verfied'}), 4),
#  (frozenset({'LowPrice', 'Verfied'}), 4),
#  (frozenset({'Streaker', 'Transparent'}), 4),
#  (frozenset({'SportsBetting', 'Transparent'}), 4),
#  (frozenset({'Secure', 'Transparent'}), 4),
#  (frozenset({'FreePicks', 'Transparent'}), 4),
#  (frozenset({'Members', 'Transparent'}), 4),
#  (frozenset({'LowPrice', 'Transparent'}), 4),
#  (frozenset({'SportsBetting', 'Streaker'}), 4),
#  (frozenset({'Secure', 'Streaker'}), 4),
#  (frozenset({'FreePicks', 'Streaker'}), 4),
#  (frozenset({'Members', 'Streaker'}), 4),
#  (frozenset({'LowPrice', 'Streaker'}), 4),
#  (frozenset({'Secure', 'SportsBetting'}), 4),
#  (frozenset({'FreePicks', 'SportsBetting'}), 4),
#  (frozenset({'Members', 'SportsBetting'}), 4),
#  (frozenset({'LowPrice', 'SportsBetting'}), 4),
#  (frozenset({'FreePicks', 'Secure'}), 4),
#  (frozenset({'Members', 'Secure'}), 4),
#  (frozenset({'LowPrice', 'Secure'}), 4),
#  (frozenset({'FreePicks', 'Members'}), 4),
#  (frozenset({'FreePicks', 'LowPrice'}), 4),
#  (frozenset({'LowPrice', 'Members'}), 4),
#  (frozenset({'Celtics', 'GrindCity'}), 4),
#  (frozenset({'NBABDAY', 'PhilaUnite'}), 4),
#  (frozenset({'Mavs', 'NBA'}), 4),
#  (frozenset({'Gambling', 'NBA'}), 4),
#  (frozenset({'NBA', 'Pacers'}), 4),
#  (frozenset({'lakers', 'nba'}), 4),
#  (frozenset({'Pronos', 'TeamParieur'}), 4),
#  (frozenset({'ThisIsWhyWePlay', 'WH9'}), 4),
#  (frozenset({'NBA', 'REDsportsTV'}), 4),
#  (frozenset({'Chicharito', 'EPN'}), 4),
#  (frozenset({'Spurs', 'SpursNation'}), 4),
#  (frozenset({'Kings', 'NBA'}), 4),
#  (frozenset({'Expert', 'NBA'}), 4),
#  (frozenset({'NBA', 'Odds'}), 4),
#  (frozenset({'Basketball', 'Free'}), 4),
#  (frozenset({'Basketball', 'Expert'}), 4),
#  (frozenset({'Basketball', 'Odds'}), 4),
#  (frozenset({'Expert', 'Free'}), 4),
#  (frozenset({'Betting', 'Free'}), 4),
#  (frozenset({'Free', 'Odds'}), 4),
#  (frozenset({'Betting', 'Expert'}), 4),
#  (frozenset({'Expert', 'Odds'}), 4),
#  (frozenset({'Betting', 'Odds'}), 4),
#  (frozenset({'nba', 'nbabet'}), 4),
#  (frozenset({'live', 'nba'}), 4),
#  (frozenset({'livebet', 'nba'}), 4),
#  (frozenset({'inplay', 'nba'}), 4),
#  (frozenset({'canlıbahis', 'nba'}), 4),
#  (frozenset({'live', 'nbabet'}), 4),
#  (frozenset({'livebet', 'nbabet'}), 4),
#  (frozenset({'inplay', 'nbabet'}), 4),
#  (frozenset({'canlıbahis', 'nbabet'}), 4),
#  (frozenset({'live', 'livebet'}), 4),
#  (frozenset({'inplay', 'live'}), 4),
#  (frozenset({'canlıbahis', 'live'}), 4),
#  (frozenset({'inplay', 'livebet'}), 4),
#  (frozenset({'canlıbahis', 'livebet'}), 4),
#  (frozenset({'canlıbahis', 'inplay'}), 4),
#  (frozenset({'NBAPicks', 'NBATwitter'}), 4),
#  (frozenset({'2kCommunity', 'nba'}), 4),
#  (frozenset({'2kCommunity', 'xbox'}), 4),
#  (frozenset({'2k20', '2kCommunity'}), 4),
#  (frozenset({'2kCommunity', 'nba2k20'}), 4),
#  (frozenset({'2kCommunity', 'goat'}), 4),
#  (frozenset({'2kCommunity', 'powerdf'}), 4),
#  (frozenset({'2kCommunity', 'nadext'}), 4),
#  (frozenset({'nba', 'xbox'}), 4),
#  (frozenset({'goat', 'nba'}), 4),
#  (frozenset({'nba', 'powerdf'}), 4),
#  (frozenset({'nadext', 'nba'}), 4),
#  (frozenset({'2k20', 'xbox'}), 4),
#  (frozenset({'nba2k20', 'xbox'}), 4),
#  (frozenset({'goat', 'xbox'}), 4),
#  (frozenset({'powerdf', 'xbox'}), 4),
#  (frozenset({'nadext', 'xbox'}), 4),
#  (frozenset({'2k20', 'goat'}), 4),
#  (frozenset({'2k20', 'powerdf'}), 4),
#  (frozenset({'2k20', 'nadext'}), 4),
#  (frozenset({'goat', 'nba2k20'}), 4),
#  (frozenset({'nba2k20', 'powerdf'}), 4),
#  (frozenset({'nadext', 'nba2k20'}), 4),
#  (frozenset({'goat', 'powerdf'}), 4),
#  (frozenset({'goat', 'nadext'}), 4),
#  (frozenset({'nadext', 'powerdf'}), 4),
#  (frozenset({'nba', 'nbatwitter'}), 4),
#  (frozenset({'IndianaStyle', 'NBA'}), 4),
#  (frozenset({'RepTheDistrict', 'RipCity'}), 4),
#  (frozenset({'Miercoles', 'NBA'}), 4),
#  (frozenset({'FearTheDeer', 'Miercoles'}), 4),
#  (frozenset({'DFS', 'DraftKings'}), 4),
#  (frozenset({'FantasyBasketball', 'NBA'}), 4),
#  (frozenset({'nba', 'portland'}), 4),
#  (frozenset({'NBA', 'sportspicks'}), 4),
#  (frozenset({'NCAAB', 'NHL'}), 4),
#  (frozenset({'Chicago', 'NBA'}), 4),
#  (frozenset({'art', 'artist'}), 4),
#  (frozenset({'2kfreeagent', 'nba2k20'}), 4),
#  (frozenset({'2k', '2k20'}), 4),
#  (frozenset({'2k', 'nba'}), 4),
#  (frozenset({'2k', 'nba2k20'}), 4),
#  (frozenset({'LakeShow', 'NBAjp'}), 4),
#  (frozenset({'MFFL', 'WontBowDown'}), 4),
#  (frozenset({'GrindCity', 'WeGoHard'}), 4),
#  (frozenset({'Grizzlies', 'Nets'}), 4),
#  (frozenset({'gospursgo', 'nba'}), 4),
#  (frozenset({'bet', 'betting'}), 4),
#  (frozenset({'NBA', 'Parley'}), 4),
#  (frozenset({'Bucks', 'NBA'}), 4),
#  (frozenset({'NBA', 'eBayAffiliate'}), 4),
#  (frozenset({'BasketballCards', 'eBayAffiliate'}), 4),
#  (frozenset({'CBB', 'NHL'}), 4),
#  (frozenset({'Knicks', 'NBA'}), 4),
#  (frozenset({'TeamParieur', 'TeamParieurs'}), 4),
#  (frozenset({'NBA', 'Sixers'}), 4),
#  (frozenset({'FreePicks', 'SenseiSam'}), 4),
#  (frozenset({'Thunder', 'ThunderUp'}), 4),
#  (frozenset({'NBA', 'dormiresdecobardes'}), 4),
#  (frozenset({'NBATwitter', 'dormiresdecobardes'}), 4),
#  (frozenset({'nba', 'sportsbetting'}), 4),
#  (frozenset({'NBA', 'TheBasketballFans'}), 4),
#  (frozenset({'nfl', 'nhl'}), 4),
#  (frozenset({'mlb', 'nhl'}), 4),
#  (frozenset({'poshmark', 'style'}), 4),
#  (frozenset({'poshmark', 'shopmycloset'}), 4),
#  (frozenset({'fashion', 'style'}), 4),
#  (frozenset({'fashion', 'shopmycloset'}), 4),
#  (frozenset({'shopmycloset', 'style'}), 4),
#  (frozenset({'Biodiversity', 'Insects'}), 4),
#  (frozenset({'Malliard', 'NBA'}), 4),
#  (frozenset({'Celtics', 'Tatum'}), 4),
#  (frozenset({'baseball', 'nba'}), 4),
#  (frozenset({'football', 'nhl'}), 4),
#  (frozenset({'baseball', 'nhl'}), 4),
#  (frozenset({'baseball', 'football'}), 4),
#  (frozenset({'bahis', 'iddaa'}), 4),
#  (frozenset({'Cavs', 'NBATwitter'}), 4),
#  (frozenset({'NHL', 'UFC'}), 3),
#  (frozenset({'NHL', '챔피언스리그'}), 3),
#  (frozenset({'NHL', 'UEFA'}), 3),
#  (frozenset({'NHL', '유로파'}), 3),
#  (frozenset({'NHL', '에이미'}), 3),
#  (frozenset({'NHL', '황재균'}), 3),
#  (frozenset({'NHL', '꽁머니'}), 3),
#  (frozenset({'NBA', '챔피언스리그'}), 3),
#  (frozenset({'NBA', 'UEFA'}), 3),
#  (frozenset({'NBA', '유로파'}), 3),
#  (frozenset({'NBA', '에이미'}), 3),
#  (frozenset({'NBA', '황재균'}), 3),
#  (frozenset({'UFC', '챔피언스리그'}), 3),
#  (frozenset({'UEFA', 'UFC'}), 3),
#  (frozenset({'UFC', '유로파'}), 3),
#  (frozenset({'UFC', '에이미'}), 3),
#  (frozenset({'UFC', '황재균'}), 3),
#  (frozenset({'UFC', '꽁머니'}), 3),
#  (frozenset({'UEFA', '챔피언스리그'}), 3),
#  (frozenset({'유로파', '챔피언스리그'}), 3),
#  (frozenset({'에이미', '챔피언스리그'}), 3),
#  (frozenset({'챔피언스리그', '황재균'}), 3),
#  (frozenset({'꽁머니', '챔피언스리그'}), 3),
#  (frozenset({'UEFA', '유로파'}), 3),
#  (frozenset({'UEFA', '에이미'}), 3),
#  (frozenset({'UEFA', '황재균'}), 3),
#  (frozenset({'UEFA', '꽁머니'}), 3),
#  (frozenset({'에이미', '유로파'}), 3),
#  (frozenset({'유로파', '황재균'}), 3),
#  (frozenset({'꽁머니', '유로파'}), 3),
#  (frozenset({'에이미', '황재균'}), 3),
#  (frozenset({'꽁머니', '에이미'}), 3),
#  (frozenset({'꽁머니', '황재균'}), 3),
#  (frozenset({'최시원', '한일관'}), 3),
#  (frozenset({'최시원', '패혈증'}), 3),
#  (frozenset({'최시원', '프렌치불독'}), 3),
#  (frozenset({'정수민', '최시원'}), 3),
#  (frozenset({'최시원', '플레이오프'}), 3),
#  (frozenset({'박세혁', '최시원'}), 3),
#  (frozenset({'최기호', '최시원'}), 3),
#  (frozenset({'두산', '최시원'}), 3),
#  (frozenset({'NC', '최시원'}), 3),
#  (frozenset({'NBA', '최시원'}), 3),
#  (frozenset({'느바', '최시원'}), 3),
#  (frozenset({'골든스테이트', '최시원'}), 3),
#  (frozenset({'꽁머니', '최시원'}), 3),
#  (frozenset({'패혈증', '한일관'}), 3),
#  (frozenset({'프렌치불독', '한일관'}), 3),
#  (frozenset({'정수민', '한일관'}), 3),
#  (frozenset({'플레이오프', '한일관'}), 3),
#  (frozenset({'박세혁', '한일관'}), 3),
#  (frozenset({'최기호', '한일관'}), 3),
#  (frozenset({'두산', '한일관'}), 3),
#  (frozenset({'NC', '한일관'}), 3),
#  (frozenset({'NBA', '한일관'}), 3),
#  (frozenset({'느바', '한일관'}), 3),
#  (frozenset({'골든스테이트', '한일관'}), 3),
#  (frozenset({'꽁머니', '한일관'}), 3),
#  (frozenset({'패혈증', '프렌치불독'}), 3),
#  (frozenset({'정수민', '패혈증'}), 3),
#  (frozenset({'패혈증', '플레이오프'}), 3),
#  (frozenset({'박세혁', '패혈증'}), 3),
#  (frozenset({'최기호', '패혈증'}), 3),
#  (frozenset({'두산', '패혈증'}), 3),
#  (frozenset({'NC', '패혈증'}), 3),
#  (frozenset({'NBA', '패혈증'}), 3),
#  (frozenset({'느바', '패혈증'}), 3),
#  (frozenset({'골든스테이트', '패혈증'}), 3),
#  (frozenset({'꽁머니', '패혈증'}), 3),
#  (frozenset({'정수민', '프렌치불독'}), 3),
#  (frozenset({'프렌치불독', '플레이오프'}), 3),
#  (frozenset({'박세혁', '프렌치불독'}), 3),
#  (frozenset({'최기호', '프렌치불독'}), 3),
#  (frozenset({'두산', '프렌치불독'}), 3),
#  (frozenset({'NC', '프렌치불독'}), 3),
#  (frozenset({'NBA', '프렌치불독'}), 3),
#  (frozenset({'느바', '프렌치불독'}), 3),
#  (frozenset({'골든스테이트', '프렌치불독'}), 3),
#  (frozenset({'꽁머니', '프렌치불독'}), 3),
#  (frozenset({'정수민', '플레이오프'}), 3),
#  (frozenset({'박세혁', '정수민'}), 3),
#  (frozenset({'정수민', '최기호'}), 3),
#  (frozenset({'두산', '정수민'}), 3),
#  (frozenset({'NC', '정수민'}), 3),
#  (frozenset({'NBA', '정수민'}), 3),
#  (frozenset({'느바', '정수민'}), 3),
#  (frozenset({'골든스테이트', '정수민'}), 3),
#  (frozenset({'꽁머니', '정수민'}), 3),
#  (frozenset({'박세혁', '플레이오프'}), 3),
#  (frozenset({'최기호', '플레이오프'}), 3),
#  (frozenset({'두산', '플레이오프'}), 3),
#  (frozenset({'NC', '플레이오프'}), 3),
#  (frozenset({'NBA', '플레이오프'}), 3),
#  (frozenset({'느바', '플레이오프'}), 3),
#  (frozenset({'골든스테이트', '플레이오프'}), 3),
#  (frozenset({'꽁머니', '플레이오프'}), 3),
#  (frozenset({'박세혁', '최기호'}), 3),
#  (frozenset({'두산', '박세혁'}), 3),
#  (frozenset({'NC', '박세혁'}), 3),
#  (frozenset({'NBA', '박세혁'}), 3),
#  (frozenset({'느바', '박세혁'}), 3),
#  (frozenset({'골든스테이트', '박세혁'}), 3),
#  (frozenset({'꽁머니', '박세혁'}), 3),
#  (frozenset({'두산', '최기호'}), 3),
#  (frozenset({'NC', '최기호'}), 3),
#  (frozenset({'NBA', '최기호'}), 3),
#  (frozenset({'느바', '최기호'}), 3),
#  (frozenset({'골든스테이트', '최기호'}), 3),
#  (frozenset({'꽁머니', '최기호'}), 3),
#  (frozenset({'NC', '두산'}), 3),
#  (frozenset({'NBA', '두산'}), 3),
#  (frozenset({'느바', '두산'}), 3),
#  (frozenset({'골든스테이트', '두산'}), 3),
#  (frozenset({'꽁머니', '두산'}), 3),
#  (frozenset({'NBA', 'NC'}), 3),
#  (frozenset({'NC', '느바'}), 3),
#  (frozenset({'NC', '골든스테이트'}), 3),
#  (frozenset({'NC', '꽁머니'}), 3),
#  (frozenset({'NBA', '느바'}), 3),
#  (frozenset({'NBA', '골든스테이트'}), 3),
#  (frozenset({'골든스테이트', '느바'}), 3),
#  (frozenset({'꽁머니', '느바'}), 3),
#  (frozenset({'골든스테이트', '꽁머니'}), 3),
#  (frozenset({'NBA', 'Teamparieur'}), 3),
#  (frozenset({'NBA', 'Sports'}), 3),
#  (frozenset({'NBATwitter', 'TeamParieur'}), 3),
#  (frozenset({'NBA', 'NBA2k20'}), 3),
#  (frozenset({'AMLO', 'Chicharito'}), 3),
#  (frozenset({'AMLO', 'EPN'}), 3),
#  (frozenset({'FreePicks', 'GamblingTwitter'}), 3),
#  (frozenset({'Denver', 'Nuggets'}), 3),
#  (frozenset({'Denver', 'NBA'}), 3),
#  (frozenset({'okc', 'oklahoma'}), 3),
#  (frozenset({'GoPacers', 'NBA'}), 3),
#  (frozenset({'GoSpursGo', 'NBA'}), 3),
#  (frozenset({'NBATwitter', 'WontBowDown'}), 3),
#  (frozenset({'PronosNBA', 'TeamParieurs'}), 3),
#  (frozenset({'freepicks', 'nba'}), 3),
#  (frozenset({'CHIvsMIN', 'NBA'}), 3),
#  (frozenset({'GamblingTwitter', 'bettingtips'}), 3),
#  (frozenset({'MIA', 'NBA'}), 3),
#  (frozenset({'BOS', 'MIA'}), 3),
#  (frozenset({'Mavericks', 'NBA'}), 3),
#  (frozenset({'NBA', 'SportsBetting'}), 3),
#  (frozenset({'TeamParieur', 'nba'}), 3),
#  (frozenset({'NBATwitter', 'Nba'}), 3),
#  (frozenset({'NIKE', 'ナイキ'}), 3),
#  (frozenset({'シカゴブルズ', 'ナイキ'}), 3),
#  (frozenset({'Chicago', 'ナイキ'}), 3),
#  (frozenset({'BULLS', 'ナイキ'}), 3),
#  (frozenset({'ナイキ', 'バーシティ'}), 3),
#  (frozenset({'ナイキ', 'メルカリ'}), 3),
#  (frozenset({'NIKE', 'シカゴブルズ'}), 3),
#  (frozenset({'Chicago', 'NIKE'}), 3),
#  (frozenset({'BULLS', 'NIKE'}), 3),
#  (frozenset({'NIKE', 'バーシティ'}), 3),
#  (frozenset({'NIKE', 'メルカリ'}), 3),
#  (frozenset({'Chicago', 'シカゴブルズ'}), 3),
#  (frozenset({'BULLS', 'シカゴブルズ'}), 3),
#  (frozenset({'シカゴブルズ', 'バーシティ'}), 3),
#  (frozenset({'シカゴブルズ', 'メルカリ'}), 3),
#  (frozenset({'BULLS', 'Chicago'}), 3),
#  (frozenset({'Chicago', 'バーシティ'}), 3),
#  (frozenset({'Chicago', 'メルカリ'}), 3),
#  (frozenset({'BULLS', 'バーシティ'}), 3),
#  (frozenset({'BULLS', 'メルカリ'}), 3),
#  (frozenset({'バーシティ', 'メルカリ'}), 3),
#  (frozenset({'arkansas', 'auburn'}), 3),
#  (frozenset({'auburn', 'ncaa'}), 3),
#  (frozenset({'auburn', 'collegebasketball'}), 3),
#  (frozenset({'auburn', 'basketball'}), 3),
#  (frozenset({'auburn', 'mockdraft2020'}), 3),
#  (frozenset({'auburn', 'nba'}), 3),
#  (frozenset({'auburn', 'nbamockdraft'}), 3),
#  (frozenset({'auburn', 'austinwiley'}), 3),
#  (frozenset({'auburn', 'samirdoughty'}), 3),
#  (frozenset({'arkansas', 'ncaa'}), 3),
#  (frozenset({'arkansas', 'collegebasketball'}), 3),
#  (frozenset({'arkansas', 'basketball'}), 3),
#  (frozenset({'arkansas', 'mockdraft2020'}), 3),
#  (frozenset({'arkansas', 'nba'}), 3),
#  (frozenset({'arkansas', 'nbamockdraft'}), 3),
#  (frozenset({'arkansas', 'austinwiley'}), 3),
#  (frozenset({'arkansas', 'samirdoughty'}), 3),
#  (frozenset({'collegebasketball', 'ncaa'}), 3),
#  (frozenset({'basketball', 'ncaa'}), 3),
#  (frozenset({'mockdraft2020', 'ncaa'}), 3),
#  (frozenset({'nbamockdraft', 'ncaa'}), 3),
#  (frozenset({'austinwiley', 'ncaa'}), 3),
#  (frozenset({'ncaa', 'samirdoughty'}), 3),
#  (frozenset({'basketball', 'collegebasketball'}), 3),
#  (frozenset({'collegebasketball', 'mockdraft2020'}), 3),
#  (frozenset({'collegebasketball', 'nba'}), 3),
#  (frozenset({'collegebasketball', 'nbamockdraft'}), 3),
#  (frozenset({'austinwiley', 'collegebasketball'}), 3),
#  (frozenset({'collegebasketball', 'samirdoughty'}), 3),
#  (frozenset({'basketball', 'mockdraft2020'}), 3),
#  (frozenset({'basketball', 'nbamockdraft'}), 3),
#  (frozenset({'austinwiley', 'basketball'}), 3),
#  (frozenset({'basketball', 'samirdoughty'}), 3),
#  (frozenset({'mockdraft2020', 'nba'}), 3),
#  (frozenset({'mockdraft2020', 'nbamockdraft'}), 3),
#  (frozenset({'austinwiley', 'mockdraft2020'}), 3),
#  (frozenset({'mockdraft2020', 'samirdoughty'}), 3),
#  (frozenset({'nba', 'nbamockdraft'}), 3),
#  (frozenset({'austinwiley', 'nba'}), 3),
#  (frozenset({'nba', 'samirdoughty'}), 3),
#  (frozenset({'austinwiley', 'nbamockdraft'}), 3),
#  (frozenset({'nbamockdraft', 'samirdoughty'}), 3),
#  (frozenset({'austinwiley', 'samirdoughty'}), 3),
#  (frozenset({'WednesdayMotivation', 'art'}), 3),
#  (frozenset({'art', 'blazers'}), 3),
#  (frozenset({'art', 'nba'}), 3),
#  (frozenset({'art', 'trailblazers'}), 3),
#  (frozenset({'art', 'portland'}), 3),
#  (frozenset({'WednesdayMotivation', 'artist'}), 3),
#  (frozenset({'artist', 'blazers'}), 3),
#  (frozenset({'artist', 'basketball'}), 3),
#  (frozenset({'artist', 'nba'}), 3),
#  (frozenset({'artist', 'trailblazers'}), 3),
#  (frozenset({'artist', 'portland'}), 3),
#  (frozenset({'WednesdayMotivation', 'blazers'}), 3),
#  (frozenset({'WednesdayMotivation', 'basketball'}), 3),
#  (frozenset({'WednesdayMotivation', 'nba'}), 3),
#  (frozenset({'WednesdayMotivation', 'trailblazers'}), 3),
#  (frozenset({'WednesdayMotivation', 'portland'}), 3),
#  (frozenset({'basketball', 'blazers'}), 3),
#  (frozenset({'blazers', 'nba'}), 3),
#  (frozenset({'blazers', 'trailblazers'}), 3),
#  (frozenset({'blazers', 'portland'}), 3),
#  (frozenset({'basketball', 'trailblazers'}), 3),
#  (frozenset({'basketball', 'portland'}), 3),
#  (frozenset({'nba', 'trailblazers'}), 3),
#  (frozenset({'portland', 'trailblazers'}), 3),
#  (frozenset({'QANON', 'TrumpTrain2020'}), 3),
#  (frozenset({'QANON', 'trumptrain'}), 3),
#  (frozenset({'QANON', 'trump'}), 3),
#  (frozenset({'QANON', 'TrumpTariffs'}), 3),
#  (frozenset({'QANON', 'maga'}), 3),
#  (frozenset({'GOP', 'QANON'}), 3),
#  (frozenset({'QANON', 'RNC'}), 3),
#  (frozenset({'QANON', 'REPUBS'}), 3),
#  (frozenset({'DEMS', 'QANON'}), 3),
#  (frozenset({'DNC', 'QANON'}), 3),
#  (frozenset({'FBI', 'QANON'}), 3),
#  (frozenset({'DOJ', 'QANON'}), 3),
#  (frozenset({'Q', 'QANON'}), 3),
#  (frozenset({'2k', '2kfreeagent'}), 3),
#  (frozenset({'2k20', '2kfreeagent'}), 3),
#  (frozenset({'2kfreeagent', 'nba'}), 3),
#  (frozenset({'FayettevilleState', 'MightyJoeBiden'}), 3),
#  (frozenset({'FayettevilleState', 'GOJoe'}), 3),
#  (frozenset({'FayettevilleState', 'GoArmy'}), 3),
#  (frozenset({'FayettevilleState', 'GoNavy'}), 3),
#  (frozenset({'DelawareState', 'FayettevilleState'}), 3),
#  (frozenset({'FayettevilleState', 'Princeton'}), 3),
#  (frozenset({'NBA', 'WeTheNorth'}), 3),
#  (frozenset({'スラムダンク', 'バスケ'}), 3),
#  (frozenset({'あひるの空', 'バスケ'}), 3),
#  (frozenset({'basketball', 'バスケ'}), 3),
#  (frozenset({'スラムダンク', 'バスケットボール'}), 3),
#  (frozenset({'あひるの空', 'バスケットボール'}), 3),
#  (frozenset({'basketball', 'バスケットボール'}), 3),
#  (frozenset({'NBA', 'スラムダンク'}), 3),
#  (frozenset({'NBA', 'あひるの空'}), 3),
#  (frozenset({'あひるの空', 'スラムダンク'}), 3),
#  (frozenset({'basketball', 'スラムダンク'}), 3),
#  (frozenset({'basketball', 'あひるの空'}), 3),
#  (frozenset({'LeBronJames', 'NBA'}), 3),
#  (frozenset({'3Mar', 'NBA'}), 3),
#  (frozenset({'MEMvsBKN', 'NBA'}), 3),
#  (frozenset({'betting', 'bettingtips'}), 3),
#  (frozenset({'betting', 'nba'}), 3),
#  (frozenset({'betting', 'tipster'}), 3),
#  (frozenset({'bettingtips', 'nba'}), 3),
#  (frozenset({'bet', 'bettingtips'}), 3),
#  (frozenset({'bettingtips', 'tipster'}), 3),
#  (frozenset({'bet', 'tipster'}), 3),
#  (frozenset({'DraftKings', 'FanDuel'}), 3),
#  (frozenset({'NHL', 'Parley'}), 3),
#  (frozenset({'NCAA', 'Parley'}), 3),
#  (frozenset({'Oklahoma', 'Parley'}), 3),
#  (frozenset({'Parley', 'Piston'}), 3),
#  (frozenset({'CalgaryFlames', 'Parley'}), 3),
#  (frozenset({'NBA', 'Oklahoma'}), 3),
#  (frozenset({'NBA', 'Piston'}), 3),
#  (frozenset({'CalgaryFlames', 'NBA'}), 3),
#  (frozenset({'NHL', 'Oklahoma'}), 3),
#  (frozenset({'NHL', 'Piston'}), 3),
#  (frozenset({'CalgaryFlames', 'NHL'}), 3),
#  (frozenset({'NCAA', 'Oklahoma'}), 3),
#  (frozenset({'NCAA', 'Piston'}), 3),
#  (frozenset({'CalgaryFlames', 'NCAA'}), 3),
#  (frozenset({'Oklahoma', 'Piston'}), 3),
#  (frozenset({'CalgaryFlames', 'Oklahoma'}), 3),
#  (frozenset({'CalgaryFlames', 'Piston'}), 3),
#  (frozenset({'MLB', 'NHL'}), 3),
#  (frozenset({'CFB', 'guaranteedpick'}), 3),
#  (frozenset({'CFB', 'expertpicks'}), 3),
#  (frozenset({'CFB', 'sportspicks'}), 3),
#  (frozenset({'CFB', 'NFL'}), 3),
#  (frozenset({'NCAAB', 'NFL'}), 3),
#  (frozenset({'CFB', 'MLB'}), 3),
#  (frozenset({'NBATwitter', 'RipCity'}), 3),
#  (frozenset({'PRONOCHTIC', 'RT'}), 3),
#  (frozenset({'Basketball', 'Chicago'}), 3),
#  (frozenset({'Chicago', 'Free'}), 3),
#  (frozenset({'Chicago', 'Expert'}), 3),
#  (frozenset({'Betting', 'Chicago'}), 3),
#  (frozenset({'Chicago', 'Odds'}), 3),
#  (frozenset({'Basketball', 'Bulls'}), 3),
#  (frozenset({'Bulls', 'Free'}), 3),
#  (frozenset({'Bulls', 'Expert'}), 3),
#  (frozenset({'Betting', 'Bulls'}), 3),
#  (frozenset({'Bulls', 'Odds'}), 3),
#  (frozenset({'MarchMadness', 'NBA'}), 3),
#  (frozenset({'Cavaliers', 'NBA'}), 3),
#  (frozenset({'Cavaliers', 'Celtics'}), 3),
#  (frozenset({'CBB', 'FREEPICKS'}), 3),
#  (frozenset({'MagicAboveAll', 'NBA'}), 3),
#  (frozenset({'Lakers', 'Nuggets'}), 3),
#  (frozenset({'BeTheFight', 'Celtics'}), 3),
#  (frozenset({'LakeShaw', 'NBA'}), 3),
#  (frozenset({'LakeShaw', 'NBAjp'}), 3),
#  (frozenset({'FearTheDeer', 'IndianaStyle'}), 3),
#  (frozenset({'mambamentality', 'nba'}), 3),
#  (frozenset({'basketball', 'nbatv'}), 3),
#  (frozenset({'NBA', 'PhilaUnite'}), 3),
#  (frozenset({'PhilaUnite', 'Sixers'}), 3),
#  (frozenset({'MileHighBasketball', 'NBA'}), 3),
#  (frozenset({'ncaa', 'nfl'}), 3),
#  (frozenset({'757sc', 'nfl'}), 3),
#  (frozenset({'mlb', 'ncaa'}), 3),
#  (frozenset({'757sc', 'mlb'}), 3),
#  (frozenset({'757sc', 'nba'}), 3),
#  (frozenset({'ncaa', 'nhl'}), 3),
#  (frozenset({'757sc', 'nhl'}), 3),
#  (frozenset({'757sc', 'ncaa'}), 3),
#  (frozenset({'GrindCity', 'Grizzlies'}), 3),
#  (frozenset({'Draftkings', 'NBA'}), 3),
#  (frozenset({'ClaisersFreePicks', 'NBA'}), 3),
#  (frozenset({'Celtics', 'ClaisersFreePicks'}), 3),
#  (frozenset({'ClaisersFreePicks', 'UltimaHora'}), 3),
#  (frozenset({'ClaisersFreePicks', 'FelizMiercolesATodos'}), 3),
#  (frozenset({'NBA', 'UltimaHora'}), 3),
#  (frozenset({'FelizMiercolesATodos', 'NBA'}), 3),
#  (frozenset({'Celtics', 'UltimaHora'}), 3),
#  (frozenset({'Celtics', 'FelizMiercolesATodos'}), 3),
#  (frozenset({'FelizMiercolesATodos', 'UltimaHora'}), 3),
#  (frozenset({'ProJohnnies', 'SJUBB'}), 3),
#  (frozenset({'Kings', 'NBATwitter'}), 3),
#  (frozenset({'FACup', 'NBA'}), 3),
#  (frozenset({'canlibahis', 'iddaa'}), 3),
#  (frozenset({'bet', 'iddaa'}), 3),
#  (frozenset({'iddaa', 'papara'}), 3),
#  (frozenset({'iddaa', 'para'}), 3),
#  (frozenset({'escort', 'iddaa'}), 3),
#  (frozenset({'iddaa', 'nakit'}), 3),
#  (frozenset({'bonus', 'iddaa'}), 3),
#  (frozenset({'bahis', 'canlibahis'}), 3),
#  (frozenset({'bahis', 'bet'}), 3),
#  (frozenset({'bahis', 'papara'}), 3),
#  (frozenset({'bahis', 'para'}), 3),
#  (frozenset({'bahis', 'escort'}), 3),
#  (frozenset({'bahis', 'nakit'}), 3),
#  (frozenset({'bahis', 'bonus'}), 3),
#  (frozenset({'bet', 'canlibahis'}), 3),
#  (frozenset({'canlibahis', 'papara'}), 3),
#  (frozenset({'canlibahis', 'para'}), 3),
#  (frozenset({'canlibahis', 'escort'}), 3),
#  (frozenset({'canlibahis', 'nakit'}), 3),
#  (frozenset({'bonus', 'canlibahis'}), 3),
#  (frozenset({'bet', 'papara'}), 3),
#  (frozenset({'bet', 'para'}), 3),
#  (frozenset({'bet', 'escort'}), 3),
#  (frozenset({'bet', 'nakit'}), 3),
#  (frozenset({'bet', 'bonus'}), 3),
#  (frozenset({'papara', 'para'}), 3),
#  (frozenset({'escort', 'papara'}), 3),
#  (frozenset({'nakit', 'papara'}), 3),
#  (frozenset({'bonus', 'papara'}), 3),
#  (frozenset({'escort', 'para'}), 3),
#  (frozenset({'nakit', 'para'}), 3),
#  (frozenset({'bonus', 'para'}), 3),
#  (frozenset({'escort', 'nakit'}), 3),
#  (frozenset({'bonus', 'escort'}), 3),
#  (frozenset({'bonus', 'nakit'}), 3),
#  (frozenset({'NBA', 'はてなブログ'}), 3),
#  (frozenset({'Doncic', 'NBA'}), 3),
#  (frozenset({'NBARooks', 'PhantomCam'}), 3),
#  (frozenset({'フォローしてね', '固定RT企画'}), 3),
#  (frozenset({'固定RT', '固定RT企画'}), 3),
#  (frozenset({'固定RT企画', '固定ツイートいいね'}), 3),
#  (frozenset({'固定RTします', '固定RT企画'}), 3),
#  (frozenset({'フォロバ・固定RT', '固定RT企画'}), 3),
#  (frozenset({'フォローしてね', '固定RT'}), 3),
#  (frozenset({'フォローしてね', '固定ツイートいいね'}), 3),
#  (frozenset({'フォローしてね', '固定RTします'}), 3),
#  (frozenset({'フォロバ・固定RT', 'フォローしてね'}), 3),
#  (frozenset({'固定RT', '固定ツイートいいね'}), 3),
#  (frozenset({'固定RT', '固定RTします'}), 3),
#  (frozenset({'フォロバ・固定RT', '固定RT'}), 3),
#  (frozenset({'固定RTします', '固定ツイートいいね'}), 3),
#  (frozenset({'フォロバ・固定RT', '固定ツイートいいね'}), 3),
#  (frozenset({'フォロバ・固定RT', '固定RTします'}), 3),
#  (frozenset({'NBA', 'SkyNBA'}), 3),
#  (frozenset({'NBA', 'NBAMVP'}), 3),
#  (frozenset({'MFFL', 'NBAMVP'}), 3),
#  (frozenset({'NBAjp', '八村塁'}), 3),
#  (frozenset({'RepTheDistrict', '八村塁'}), 3),
#  (frozenset({'BU', 'GÜN'}), 3),
#  (frozenset({'GoSpursGo', 'nba'}), 2),
#  (frozenset({'TeamParieur', 'winamax'}), 2),
#  (frozenset({'FUBOTV', 'NBA'}), 2),
#  (frozenset({'FUBOTV', 'NoCreditCheck'}), 2),
#  (frozenset({'FUBOTV', 'NoDeposit'}), 2),
#  (frozenset({'FUBOTV', 'WatchNow'}), 2),
#  (frozenset({'DontGetCabled', 'FUBOTV'}), 2),
#  (frozenset({'NBA', 'NoCreditCheck'}), 2),
#  (frozenset({'NBA', 'NoDeposit'}), 2),
#  (frozenset({'NBA', 'WatchNow'}), 2),
#  (frozenset({'DontGetCabled', 'NBA'}), 2),
#  (frozenset({'NoCreditCheck', 'NoDeposit'}), 2),
#  (frozenset({'NoCreditCheck', 'WatchNow'}), 2),
#  (frozenset({'DontGetCabled', 'NoCreditCheck'}), 2),
#  (frozenset({'NoDeposit', 'WatchNow'}), 2),
#  (frozenset({'DontGetCabled', 'NoDeposit'}), 2),
#  (frozenset({'DontGetCabled', 'WatchNow'}), 2),
#  (frozenset({'Pistons', 'Suns'}), 2),
#  (frozenset({'la', 'nba'}), 2),
#  (frozenset({'lakeshow', 'nba'}), 2),
#  (frozenset({'lebronjames', 'nba'}), 2),
#  (frozenset({'lebron', 'nba'}), 2),
#  (frozenset({'lakers', 'losangeles'}), 2),
#  (frozenset({'la', 'lakers'}), 2),
#  (frozenset({'lakers', 'lebronjames'}), 2),
#  (frozenset({'lakers', 'lebron'}), 2),
#  (frozenset({'lebron', 'lebronjames'}), 2),
#  (frozenset({'Betting', 'Gambling'}), 2),
#  (frozenset({'Gambling', 'Gorilla'}), 2),
#  (frozenset({'Degenerate', 'Gambling'}), 2),
#  (frozenset({'Gambling', 'Sports'}), 2),
#  (frozenset({'Gambling', 'NCAA'}), 2),
#  (frozenset({'Basketball', 'Gambling'}), 2),
#  (frozenset({'Gambling', 'NHL'}), 2),
#  (frozenset({'Betting', 'Gorilla'}), 2),
#  (frozenset({'Betting', 'Degenerate'}), 2),
#  (frozenset({'Betting', 'Sports'}), 2),
#  (frozenset({'Betting', 'NCAA'}), 2),
#  (frozenset({'Betting', 'NHL'}), 2),
#  (frozenset({'Degenerate', 'Gorilla'}), 2),
#  (frozenset({'Gorilla', 'Sports'}), 2),
#  (frozenset({'Gorilla', 'NCAA'}), 2),
#  (frozenset({'Basketball', 'Gorilla'}), 2),
#  (frozenset({'Gorilla', 'NBA'}), 2),
#  (frozenset({'Gorilla', 'NHL'}), 2),
#  (frozenset({'Degenerate', 'Sports'}), 2),
#  (frozenset({'Degenerate', 'NCAA'}), 2),
#  (frozenset({'Basketball', 'Degenerate'}), 2),
#  (frozenset({'Degenerate', 'NBA'}), 2),
#  (frozenset({'Degenerate', 'NHL'}), 2),
#  (frozenset({'NCAA', 'Sports'}), 2),
#  (frozenset({'Basketball', 'Sports'}), 2),
#  (frozenset({'NHL', 'Sports'}), 2),
#  (frozenset({'Basketball', 'NCAA'}), 2),
#  (frozenset({'Basketball', 'NHL'}), 2),
#  (frozenset({'NBA', 'unibet'}), 2),
#  (frozenset({'PARIS', 'unibet'}), 2),
#  (frozenset({'NBA', 'PARIS'}), 2),
#  (frozenset({'NBA2k20', 'badges'}), 2),
#  (frozenset({'NBA', 'badges'}), 2),
#  (frozenset({'deals', 'freebies'}), 2),
#  (frozenset({'deal', 'freebies'}), 2),
#  (frozenset({'freebies', 'moneysaver'}), 2),
#  (frozenset({'deal', 'deals'}), 2),
#  (frozenset({'deals', 'moneysaver'}), 2),
#  (frozenset({'deal', 'moneysaver'}), 2),
#  (frozenset({'Celtics', 'WeGoHard'}), 2),
#  (frozenset({'NBA', 'NBAPicks'}), 2),
#  (frozenset({'InsideTheNBA', 'NBA'}), 2),
#  (frozenset({'NBA', 'Shaq'}), 2),
#  (frozenset({'InsideTheNBA', 'Shaq'}), 2),
#  (frozenset({'NBA', 'OKC'}), 2),
#  (frozenset({'nhl', 'nhlpicks'}), 2),
#  (frozenset({'nba', 'nhlpicks'}), 2),
#  (frozenset({'nba', 'rolling'}), 2),
#  (frozenset({'nbabet', 'rolling'}), 2),
#  (frozenset({'live', 'rolling'}), 2),
#  (frozenset({'livebet', 'rolling'}), 2),
#  (frozenset({'inplay', 'rolling'}), 2),
#  (frozenset({'canlıbahis', 'rolling'}), 2),
#  (frozenset({'DraftKingsCheatsheet', 'NBA'}), 2),
#  (frozenset({'NBA', 'SacramentoProud'}), 2),
#  (frozenset({'DFS', 'NBATwitter'}), 2),
#  (frozenset({'Fanduel', 'NBATwitter'}), 2),
#  (frozenset({'NBATwitter', 'Pelicans'}), 2),
#  (frozenset({'NBA', 'SportsPicks'}), 2),
#  (frozenset({'NCAA', 'NCAAB'}), 2),
#  (frozenset({'DFS', 'FantasyBasketball'}), 2),
#  (frozenset({'nba', 'xfl'}), 2),
#  (frozenset({'NBA', 'pension'}), 2),
#  (frozenset({'pension', 'retirement'}), 2),
#  (frozenset({'NBA', 'retirement'}), 2),
#  (frozenset({'NBATwitter', 'NBAonTNT'}), 2),
#  (frozenset({'Draftkings', 'NBADFS'}), 2),
#  (frozenset({'Fanduel', 'NBADFS'}), 2),
#  (frozenset({'DFS', 'NHL'}), 2),
#  (frozenset({'nba', 'nbapicks'}), 2),
#  (frozenset({'freepicks', 'nbapicks'}), 2),
#  (frozenset({'SoundCloud', 'np'}), 2),
#  (frozenset({'JDE'}), 2),
#  (frozenset({'nba', 'warriors'}), 2),
#  (frozenset({'DreamHustleWin', 'GamblingTwitter'}), 2),
#  (frozenset({'DreamHustleWin', 'sportspicks'}), 2),
#  (frozenset({'DreamHustleWin', 'bettingtips'}), 2),
#  (frozenset({'DreamHustleWin', 'NBA'}), 2),
#  (frozenset({'GamblingTwitter', 'sportspicks'}), 2),
#  (frozenset({'bettingtips', 'sportspicks'}), 2),
#  (frozenset({'NBA', 'bettingtips'}), 2),
#  (frozenset({'BOS', 'NBA'}), 2),
#  (frozenset({'CLE', 'NBA'}), 2),
#  (frozenset({'NBA', 'ORL'}), 2),
#  (frozenset({'BOS', 'CLE'}), 2),
#  (frozenset({'BOS', 'ORL'}), 2),
#  (frozenset({'CLE', 'ORL'}), 2),
#  (frozenset({'CLE', 'MIA'}), 2),
#  (frozenset({'MIA', 'ORL'}), 2),
#  (frozenset({'NBA', 'sports'}), 2),
#  (frozenset({'Mavericks', 'Pelicans'}), 2),
#  (frozenset({'betting', 'sports'}), 2),
#  (frozenset({'Magic', 'NBA'}), 2),
#  (frozenset({'nba', 'parlay'}), 2),
#  (frozenset({'houston', 'rockets'}), 2),
#  (frozenset({'AGanar', 'NBA'}), 2),
#  (frozenset({'2K20', 'NBA'}), 2),
#  (frozenset({'NBATwitter', 'NFLTwitter'}), 2),
#  (frozenset({'NBATwitter', 'Nfl'}), 2),
#  (frozenset({'NFLTwitter', 'Nba'}), 2),
#  (frozenset({'NFLTwitter', 'Nfl'}), 2),
#  (frozenset({'Nba', 'Nfl'}), 2),
#  (frozenset({'design', 'tshirt'}), 2),
#  (frozenset({'graphic', 'tshirt'}), 2),
#  (frozenset({'art', 'tshirt'}), 2),
#  (frozenset({'basketball', 'tshirt'}), 2),
#  (frozenset({'street', 'tshirt'}), 2),
#  (frozenset({'NBA', 'tshirt'}), 2),
#  (frozenset({'JBA', 'tshirt'}), 2),
#  (frozenset({'design', 'graphic'}), 2),
#  (frozenset({'art', 'design'}), 2),
#  (frozenset({'basketball', 'design'}), 2),
#  (frozenset({'design', 'street'}), 2),
#  (frozenset({'NBA', 'design'}), 2),
#  (frozenset({'JBA', 'design'}), 2),
#  (frozenset({'art', 'graphic'}), 2),
#  (frozenset({'basketball', 'graphic'}), 2),
#  ...]

# %% [markdown]
# ### generate user interaction network for main cluster

# %%
#find users with highest number of mentions
tweets = collection.find({ "retweeted_status" : { "$exists" : False },'lang':'en' })
mentions = list()

for tweet,cluster in zip(tweets,clusterizer.labels_):
    #only consider tweets in main cluster
    if(cluster==153):
        try:
            for user in tweet['entities']['user_mentions']:
                mentions.append(user['screen_name'])
        except:
            pass

mentions = pd.DataFrame(mentions,columns=['mentioned'])

mentions['mentioned'].value_counts().head(10)
# Out:
# NBA              161
# Bucks             29
# YouTube           29
# KingJames         20
# nyknicks          17
# espn              16
# dallasmavs        16
# PelicansNBA       14
# unitedmasters     13
# Lakers            13
# Name: mentioned, dtype: int64

# %%
#find most retweeted users
#since retweets were removed in clustering there are no retweets in the cluster and therefore we cant find users
#with most retweets since there arent any

# %%
#find most replied to users
tweets = collection.find({ "retweeted_status" : { "$exists" : False },'lang':'en' })
replies = list()

for tweet,cluster in zip(tweets,clusterizer.labels_):
    if(cluster==153):
        if tweet['in_reply_to_screen_name'] is not None:
            replies.append(tweet['in_reply_to_screen_name'])

replies = pd.DataFrame(replies,columns=['replied'])

replies['replied'].value_counts().head(10)
# Out:
# NBA                48
# EASPORTSNBALM       7
# barstoolsports      6
# undisputed          6
# BleacherReport      5
# espn                5
# Bucks               4
# tonyfinaugolf       4
# Chris_Broussard     4
# JCMacriNBA          3
# Name: replied, dtype: int64

# %%
#find most quoted users
tweets = collection.find({ "retweeted_status" : { "$exists" : False },'lang':'en' })
quoted = list()

for tweet,cluster in zip(tweets,clusterizer.labels_):
    if(cluster == 153):
        try: 
            quoted.append(tweet['quoted_status']['user']['screen_name'])
        except:
            pass

quoted = pd.DataFrame(quoted,columns=['quoted'])

quoted['quoted'].value_counts().head(10)
# Out:
# J_UNDFTD          696
# Ballislife         81
# ESPNNBA            55
# NBA                36
# wojespn            28
# BleacherReport     23
# JosephhT12         23
# undisputed         21
# DimesFromRose      20
# NYG_4_LIFE         19
# Name: quoted, dtype: int64

# %% [markdown]
# ### generate edges for graph with python counter

# %%
edges = Counter()

# %%
for tweet,cluster in zip(collection.find({ "retweeted_status" : { "$exists" : False },'lang':'en' }),clusterizer.labels_):
    if (cluster == 153):
        user = tweet['user']['screen_name']

        if tweet['in_reply_to_screen_name'] is not None:
            edges[tuple([user,tweet['in_reply_to_screen_name']])]+=1
        try: 
            edges[tuple([user,tweet['retweeted_status']['user']['screen_name']])]+=1
        except:
            pass
        try: 
            edges[tuple([user,tweet['quoted_status']['user']['screen_name']])]+=1
        except:
            pass
        try:
            for mention in tweet['entities']['user_mentions']:
                edges[tuple([user,mention['screen_name']])]+=1
        except:
            pass

# %%
edges.most_common()
# Out:
# [(('redsmith1', 'TheHerd'), 6),
#  (('bettingresource', 'dquanpicks'), 6),
#  (('tmac36daexpert', 'cboyd304'), 6),
#  (('Almightyspace', '_lamar3'), 6),
#  (('Lonzoyeng3', 'NBA'), 5),
#  (('MattWithAMouth', 'FinkMark1'), 5),
#  (('NotAirid', '_rockrob'), 5),
#  (('MrNBA16', 'NBA'), 4),
#  (('Bevlin19', 'madewitlean'), 4),
#  (('Bevlin19', 'RandomHopJunkie'), 4),
#  (('edb288', 'cparrottSQUAWK'), 4),
#  (('PhillyAnimal6', 'kornhauser22'), 4),
#  (('ClataroJames', 'kvng_matt29'), 4),
#  (('KoalaSwagBamboo', 'NBA'), 4),
#  (('MtbLawson', 'vinnythibeault'), 4),
#  (('MtbLawson', 'antonin_org'), 4),
#  (('BigX84', 'NBA'), 4),
#  (('LuanwonderII', 'betchanger'), 4),
#  (('cboyd304', 'tmac36daexpert'), 4),
#  (('TysonMurdockt', 'locher27'), 4),
#  (('AndrewMartinBet', 'BackAftaThis'), 4),
#  (('DarrenAbenstein', 'ZackTeitel'), 4),
#  (('Suebird00565589', 'KUHoops'), 4),
#  (('NLLTweets', 'DUNOTS'), 4),
#  (('MattWithAMouth', 'seanqatnight'), 4),
#  (('ultimatum_shop', 'NBA'), 4),
#  (('tjbey2000', 'Chris_Broussard'), 4),
#  (('ruel_4745', 'undisputed'), 4),
#  (('allenisaballer', 'Nolan_Smith7'), 4),
#  (('HpyCsPz', 'ESPNNBA'), 4),
#  (('BrumAxe', 'Bucks'), 4),
#  (('Champagne_Lo', 'OhMrWilson314'), 4),
#  (('Ndbrown19', 'AustintOgden'), 4),
#  (('JesusShuttlew12', 'howboutthemsox'), 4),
#  (('JesusShuttlew12', 'justkurt76'), 4),
#  (('NotAirid', 'nqstril'), 4),
#  (('SWilliacy', 'buffalospurs'), 4),
#  (('LetsTalk_NBA', 'NBA'), 4),
#  (('JeffBigDreamerH', 'BbqSmoka'), 4),
#  (('BurkoDallas', 'KobeTakes'), 3),
#  (('thepodfather_', 'Dmac_DaDon'), 3),
#  (('Bevlin19', 'Ravens525520575'), 3),
#  (('EdmundWilliamC3', 'EdmundWilliamC3'), 3),
#  (('ekow_Sarkcess', 'shattawalegh'), 3),
#  (('NEdegenerate', 'markbizmark'), 3),
#  (('MissTecii3', 'iAmTerrace'), 3),
#  (('Pro_Des_Pronos', '1'), 3),
#  (('MtbLawson', 'Kevinharlan'), 3),
#  (('FantasyProsNBA', 'Beerad30'), 3),
#  (('TrubiskyisMVP', 'nyknicks'), 3),
#  (('MannyNeva77', 'Lamentedtraffic'), 3),
#  (('redsmith1', 'ColinCowherd'), 3),
#  (('ramreport4u', 'MattWerry'), 3),
#  (('victoriaaalxo', 'TangerineHoops'), 3),
#  (('Scoo73r', 'DHAhole'), 3),
#  (('John32193769', 'NBA'), 3),
#  (('MattWithAMouth', 'Lemilli_Lemilli'), 3),
#  (('MattWithAMouth', 'WrestlingCWO'), 3),
#  (('MattWithAMouth', 'RRSterling'), 3),
#  (('MattWithAMouth', 'NBA'), 3),
#  (('_JasonLT', '_kinabii'), 3),
#  (('LegendaryJMFT', 'Jumpahoo'), 3),
#  (('UhOhSpaghettiJo', 'nbastats'), 3),
#  (('UhOhSpaghettiJo', 'AndrewDBailey'), 3),
#  (('eakhead', 'TravelKing711'), 3),
#  (('realLouEtemi', 'podpicks1'), 3),
#  (('scottman86', 'OfficialNBARefs'), 3),
#  (('MikeZeuss', 'Coolguy55510'), 3),
#  (('sour_faced', 'El_Chapo33'), 3),
#  (('RoyaltyLineups', 'RoyaltyLineups'), 3),
#  (('BrumAxe', 'NBA'), 3),
#  (('PodcastDemand', 'PodcastDemand'), 3),
#  (('Grimmy33', 'SportsCenter'), 3),
#  (('JesusShuttlew12', 'NBA'), 3),
#  (('JesusShuttlew12', 'Bucks'), 3),
#  (('SandeepSalmon', 'verge'), 3),
#  (('elvisfan05', 'NBA'), 3),
#  (('karlbubi', 'de_trillest'), 3),
#  (('karlbubi', 'Ms_West___'), 3),
#  (('2_fez', 'NBABet5'), 2),
#  (('MysteriousE98', 'NBA'), 2),
#  (('iLikeSportsHD', 'Dexerto'), 2),
#  (('RobbieLyell', 'Collin_Summers'), 2),
#  (('stylesE', 'Rachel__Nichols'), 2),
#  (('JaredDa79368581', 'ClayTravis'), 2),
#  (('recipe2indulge4', 'thezosh0w'), 2),
#  (('apakastan', 'wojespn'), 2),
#  (('FanTeamOfficial', 'WolfofInplay'), 2),
#  (('InstaReaction', 'sixers'), 2),
#  (('thabxfish', 'prunerjim'), 2),
#  (('jackk_attackk', 'KateeForbis'), 2),
#  (('WalterFalls', 'awfulannouncing'), 2),
#  (('Jiron_03', 'Super70sSports'), 2),
#  (('Bevlin19', 'cooler2394'), 2),
#  (('brettm73', 'JazzUniTracker'), 2),
#  (('TRE_Advisors', 'tonyfinaugolf'), 2),
#  (('GreeneMckinzie', 'NBA'), 2),
#  (('Basketballniice', 'BASJOE'), 2),
#  (('RichKingston73', 'WalkerMehl'), 2),
#  (('BooneGage', 'wristmotion'), 2),
#  (('BGrant_10', 'addison0g'), 2),
#  (('doitallwalker', 'KendricD_Jones'), 2),
#  (('MichaelATorrez3', 'bridgetmmulcahy'), 2),
#  (('hock_17', 'SheaSerrano'), 2),
#  (('AJyanksatlas', 'barstoolsports'), 2),
#  (('twtbb_yt', 'NBA'), 2),
#  (('AlishaRobinso19', 'StephenCurry30'), 2),
#  (('SpyrosVelentzas', 'PhilaPhilosophy'), 2),
#  (('suga_ray_nathan', 'Oldskoolbball1'), 2),
#  (('MrNBA16', 'nbaballinfo'), 2),
#  (('forumbluegold', 'TrueHoop'), 2),
#  (('KingVeetutu', 'tonyfinaugolf'), 2),
#  (('ckoester39', 'tLLoyD199'), 2),
#  (('patbeverIey', 'therandom58'), 2),
#  (('Brian_P_33', 'NBA'), 2),
#  (('Bevlin19', 'Broward_Bounty'), 2),
#  (('SportsUpdater69', 'GoatAaronJones'), 2),
#  (('edb288', 'broncopack'), 2),
#  (('edb288', 'joeovies'), 2),
#  (('edb288', 'lebrownlow'), 2),
#  (('Tom69259252', 'Big_DT23'), 2),
#  (('coolhandTRU', 'bigbootybets'), 2),
#  (('swizardkelly0', 'NBA'), 2),
#  (('BBSportsss', 'BoogMoneyline'), 2),
#  (('tonymess25', 'awfulannouncing'), 2),
#  (('BMOK33', 'markbspiegel'), 2),
#  (('meccaimani', 'NBAonTNT'), 2),
#  (('Tubby_Welcher', '2KIntel'), 2),
#  (('ChildishBaiocco', 'Adumb_'), 2),
#  (('BlackPressureC1', 'JMeuvi76'), 2),
#  (('OJGF0929', 'RexChapman'), 2),
#  (('LukeOKC', 'MilliganNoah'), 2),
#  (('dj2x18', 'Beluba'), 2),
#  (('pnort13', 'rafidingstein'), 2),
#  (('ColeWeg', 'barstoolsports'), 2),
#  (('MufasaEvey', 'BVillono'), 2),
#  (('Kassiusz', 'CrypticJacknife'), 2),
#  (('kev___23', 'ESPNNBA'), 2),
#  (('allwevelearned', 'thetrillbillies'), 2),
#  (('MrNBA16', 'nbastats'), 2),
#  (('Jay_Nice_305', 'guardian'), 2),
#  (('tylersorayori89', 'philkelly96'), 2),
#  (('johnnybezgood', 'hoopguru24_33'), 2),
#  (('Bel_Aviateur', 'NerdNomadMom'), 2),
#  (('tworsandtwols', 'SheaSerrano'), 2),
#  (('rans4runr', 'tonyfinaugolf'), 2),
#  (('dilgert', 'BrianSwane'), 2),
#  (('megFather', '1halaamudathir'), 2),
#  (('HoodieCurry', 'ash_sixx1'), 2),
#  (('RIPAK2020', 'Ronnie2K'), 2),
#  (('Black__Jeff', 'NBA'), 2),
#  (('Jason_Ragland', 'EllesShelly'), 2),
#  (('Quintssential', 'HiMyNamesJasonn'), 2),
#  (('RIPAK2020', 'NBA2K'), 2),
#  (('alexfonCK14', 'NoDunksInc'), 2),
#  (('YoungBullSZN', 'UMFanAugdahl'), 2),
#  (('CamDancy', 'Bkmiller15'), 2),
#  (('KingLarronidis_', 'NBA2K'), 2),
#  (('PhillyAnimal6', 'LukeDunham77'), 2),
#  (('PhillyAnimal6', 'kuzzzii'), 2),
#  (('ker08', '_Iain_Roberts'), 2),
#  (('pw253', 'KateeForbis'), 2),
#  (('Bevlin19', 'KronkNoah'), 2),
#  (('Bevlin19', 'jayfirstshot'), 2),
#  (('theblacktshirt0', 'SheaSerrano'), 2),
#  (('etetet40261292', 'yofernan24'), 2),
#  (('paxthetruth', 'Hype_Tha_King'), 2),
#  (('OCCraig', 'Caliboy1212_'), 2),
#  (('vvv23063101', '280robin'), 2),
#  (('Gstrag', 'KyIelow_'), 2),
#  (('justinquinnn', 'HunterFelt'), 2),
#  (('StoneyMMA', 'TheRealNichBuns'), 2),
#  (('TJ4Hundred', 'KissMyAdidas'), 2),
#  (('RoundRockTim', 'mdeschpac'), 2),
#  (('LeBronSZN__', 'PrimeJA242'), 2),
#  (('AydianAhmad_', 'WorldWideWob'), 2),
#  (('Nichola71100787', 'lefraud_exposed'), 2),
#  (('KrisNiemi', 'Poliver04'), 2),
#  (('wkwII_', 'Justin08__'), 2),
#  (('DellStarX', 'Dom_2k'), 2),
#  (('PassPassRun', 'RossThevPPT'), 2),
#  (('TyHicks_13', 'Thereal_Red21'), 2),
#  (('SemirX3', 'KawhiJordan'), 2),
#  (('DETfootball_88', 'everybody313'), 2),
#  (('ITweetHere_823', 'VitaminLBJ'), 2),
#  (('iso_like', 'NYG_4_LIFE'), 2),
#  (('SportsJensen', 'BleacherReport'), 2),
#  (('TammyJParadis', 'LoyolaTrue'), 2),
#  (('jack_hamilton', 'loumoore12'), 2),
#  (('Fast2626', 'Rocketqt'), 2),
#  (('ClataroJames', 'Marmollena'), 2),
#  (('ClataroJames', 'Tyrell61484879'), 2),
#  (('ClataroJames', 'KendrickPerkins'), 2),
#  (('Glolimitira', 'jtfromtexas'), 2),
#  (('rob8cake', 'espn700bill'), 2),
#  (('NBACobwebs', 'NBACobwebs'), 2),
#  (('maurcoy', 'chicagobulls'), 2),
#  (('Keith_Langlois', 'wojespn'), 2),
#  (('feeling3000', 'urkle9'), 2),
#  (('jlex15', 'JakeNudd'), 2),
#  (('KerwoodBBall', 'NekiasNBA'), 2),
#  (('natedog034', 'venezianrey'), 2),
#  (('BlackCat6666666', 'AroundtheHorn'), 2),
#  (('knickityknick', 'JCMacriNBA'), 2),
#  (('AdamowiczKurt', 'JayMoneyIsMoney'), 2),
#  (('Kenricward', 'mkf'), 2),
#  (('RellingerScott', 'espn'), 2),
#  (('omartalib', 'NBA'), 2),
#  (('GTSDistribution', 'collectsuper'), 2),
#  (('TylerMadeIt_', 'undisputed'), 2),
#  (('FooRogFtM21', 'WillCainShow'), 2),
#  (('FooRogFtM21', 'NBA'), 2),
#  (('ChrisMcMillan29', 'JakeRobinson519'), 2),
#  (('ali_safa10', 'Curryfromthreee'), 2),
#  (('Rybrad10', 'logan_holl1'), 2),
#  (('ThurgoDatman41', 'JTFOz'), 2),
#  (('billyrazzle', 'Journaling4Life'), 2),
#  (('NEdegenerate', 'NEdegenerate'), 2),
#  (('NEdegenerate', 'Benfreakbody'), 2),
#  (('fIash2x', 'Dubs408'), 2),
#  (('JakeNudd', 'jlex15'), 2),
#  (('astro_engineer', 'NoticentroWAPA'), 2),
#  (('gOd_smitty', 'PointGuardLife8'), 2),
#  (('Josh_Dunville', 'timandsid'), 2),
#  (('ashy_kneez', 'Dgriff1000'), 2),
#  (('apgibson42', 'NWIOren'), 2),
#  (('pollomuller', 'trukarackta4u'), 2),
#  (('IshanHindocha', 'StockRanks'), 2),
#  (('samesfandiari', 'urkle9'), 2),
#  (('philrsquared', 'FactsKevin'), 2),
#  (('ChiefsBoogie', 'DAZN_USA'), 2),
#  (('CoverKingDude', 'PaperChaser_P'), 2),
#  (('AustinGrimes99', 'cpenn4thewin'), 2),
#  (('MyNextSeat1', 'Hyundai'), 2),
#  (('dolo21_', 'DajuanHill'), 2),
#  (('dr3amchaser1', 'KingJames'), 2),
#  (('BruceWa97688379', 'frank_seravalli'), 2),
#  (('keithartois', 'ringer'), 2),
#  (('757IA', 'e_knifongTV'), 2),
#  (('Ravens525520575', 'FauItIy'), 2),
#  (('KoalaSwagBamboo', 'DdaGOAT_19'), 2),
#  (('KoalaSwagBamboo', 'PelicansNBA'), 2),
#  (('KoalaSwagBamboo', 'dallasmavs'), 2),
#  (('JoaquinDead3', 'JRSmith2126'), 2),
#  (('YoungMace22', 'BooneGage'), 2),
#  (('Moe75561933', 'CJC9BOSS'), 2),
#  (('TruePG718', 'AJTheManChild'), 2),
#  (('dyeward24', 'BleacherReport'), 2),
#  (('SailorTurnee', 'wetbuckets88'), 2),
#  (('keideberry3', 'azariahw36'), 2),
#  (('LongArmMelo', 'acct_stan'), 2),
#  (('NotACasualMMA', 'UndercOvereem'), 2),
#  (('CupofJoeintheD2', 'TrubiskyisMVP'), 2),
#  (('Wstrickland1997', 'WorldWideWob'), 2),
#  (('daddylongleg200', 'miya90094826'), 2),
#  (('FlyHigh_Dre', 'DevinBook'), 2),
#  (('MSchkolnick3', 'markcranston5'), 2),
#  (('KoalaSwagBamboo', 'urososke'), 2),
#  (('KingWarren3rd', 'chestersbuckets'), 2),
#  (('_paythepiper_', '1057FMTheFan'), 2),
#  (('slivian04', 'spidadmitchell'), 2),
#  (('BooneGage', 'jimmy_cutajar'), 2),
#  (('JulianBeckwith', 'NYG_4_LIFE'), 2),
#  (('HarperNation24', 'TimmyDaleTaylor'), 2),
#  (('91rec', 'knickspls'), 2),
#  (('virus25003', 'oldschoolhawk99'), 2),
#  (('dmb415', 'tonyfinaugolf'), 2),
#  (('BDifronzo', 'ajacobson0552'), 2),
#  (('DrewNukem', 'Norman_AG'), 2),
#  (('_Kagistian07', 'FantasyLabsNBA'), 2),
#  (('SoundDoggyBoy', 'PlayStationFR'), 2),
#  (('allenrfarmer', 'BobbyRosinski'), 2),
#  (('SportStackRich', 'WolfofInplay'), 2),
#  (('Volforlife3', 'DKGotNext'), 2),
#  (('StephMVPSZN', 'RealTKoBoston'), 2),
#  (('drewbreezy_22', 'dylanfredericks'), 2),
#  (('Oohlavale', 'SportsCenter'), 2),
#  (('denverrefugee', 'adammares'), 2),
#  (('AnasAlazzawi7', 'MeyersLeonard'), 2),
#  (('gelobased', 'DripSoup_'), 2),
#  (('andysantosbball', 'chibbs_1'), 2),
#  (('jaylaw22', 'Chris_Cwik'), 2),
#  (('alanshow', 'GreekGodofStats'), 2),
#  (('herfavstuff', 'NBA'), 2),
#  (('enteng3rd', 'Raptors'), 2),
#  (('billohoops', 'WhosNextHS'), 2),
#  (('Kyng_Marco', 'ItsT_HO_MAS'), 2),
#  (('connorofthepure', 'NateDuncanNBA'), 2),
#  (('NotsotinyTimBer', 'patbeverIey'), 2),
#  (('Fred66x', 'Jumpshot8'), 2),
#  (('LakerPrimeTime', 'KDQueseCC32'), 2),
#  (('Treyspo', 'BTOWN512'), 2),
#  (('SoAmbitiousTv22', '22thaKid'), 2),
#  (('YarikYarik92', 'EASPORTSNBALM'), 2),
#  (('JMotenIII', 'KevinRudc'), 2),
#  (('lukafan77', '_DutchMace'), 2),
#  (('Clbprodigy25', 'FroMagnum__'), 2),
#  (('WashedLeGod', 'RTNBA'), 2),
#  (('TrellSkyWalka', 'NBA'), 2),
#  (('grun_powa_rangr', 'EASPORTSNBALM'), 2),
#  (('benaqui', 'TrubiskyisMVP'), 2),
#  (('valens_awon', '2K'), 2),
#  (('flobahh', 'andrewsahawneh1'), 2),
#  (('CyndeSunshine', 'joeybagovdonuts'), 2),
#  (('bdurocher08', 'IanBegley'), 2),
#  (('JarardJones', 'KoalaSwagBamboo'), 2),
#  (('Mike_Motown', 'jbursk10'), 2),
#  (('RockafellaTezz', 'ADIDASandLEAN'), 2),
#  (('mkharsh33', 'BrianTRobb'), 2),
#  (('tim14le', 'MoWhuutt'), 2),
#  (('LahaineBillet', 'LahaineBillet'), 2),
#  (('Aaron_330', 'AmicoHoops'), 2),
#  (('Pragmat1cOn3', 'HardKnicksLife'), 2),
#  (('YaMammysFav', 'budda_13'), 2),
#  (('JTKoop32', 'CheeseheaDuke'), 2),
#  (('TrubiskyisMVP', 'benaqui'), 2),
#  (('grimoren189', 'Gucci_Ochocinco'), 2),
#  (('randy_allen20', 'RandomHopJunkie'), 2),
#  (('JacobKniffen', 'lazchance'), 2),
#  (('realtruthkings', 'CBSLA'), 2),
#  (('kyhoudini', 'PCreighton1'), 2),
#  (('Spence_Scofield', 'rileysmith66'), 2),
#  (('negadelphia76', 'ThePhifthQ'), 2),
#  (('DezDi0r', 'nyknicks'), 2),
#  (('TheBlaqCulture', 'OkayAfrica'), 2),
#  (('MajorMarkB', 'ClayTravis'), 2),
#  (('bcerezo5', 'natemup'), 2),
#  (('nahgoee', 'HARDEN2MVP'), 2),
#  (('boshnots1', 'Silvers_XDark'), 2),
#  (('Coolguy55510', '_TheRolePlayer_'), 2),
#  (('BobcatAdams44', 'WillCainShow'), 2),
#  (('Ranryu', 'krlcolbert1'), 2),
#  (('Cuse3000', 'PaniniAmerica'), 2),
#  (('Tim_NBA', 'bobbyflaiben'), 2),
#  (('JOEAmazing_', 'FolarinTheGreat'), 2),
#  (('Greatergood33', 'dtheis10'), 2),
#  (('SpartansSZN', 'Spartysburner'), 2),
#  (('jbazoo', 'PeriwinkleRip'), 2),
#  (('MrLexLuthor', '1057FMTheFan'), 2),
#  (('blarkmamba', 'Lavarbigballer'), 2),
#  (('IsziYxng', 'YouTube'), 2),
#  (('BTBBlaze', 'NathNikash'), 2),
#  (('BKz00Best', 'YahooFantasyCC'), 2),
#  (('nbated', '620wtmj'), 2),
#  (('nbated', 'ESPNMadison'), 2),
#  (('KronkNoah', 'AlongThisPath'), 2),
#  (('AwesemoNBA', 'AwesemoDFS'), 2),
#  (('KyleBoo95192697', 'OnlyForTheTakin'), 2),
#  (('MannyNeva77', 'NBA'), 2),
#  (('MannyNeva77', 'PelicansNBA'), 2),
#  (('MannyNeva77', 'dallasmavs'), 2),
#  (('Charlie01053133', 'ExtendKenny97'), 2),
#  (('emrgncyp', 'DixieNormous06'), 2),
#  (('CLIPPERSwag', 'TahlilO'), 2),
#  (('MimiMungu', 'Chris_Broussard'), 2),
#  (('mlc93_', 'NBA'), 2),
#  (('ggTundra', 'FreeReplies'), 2),
#  (('ggTundra', 'espn'), 2),
#  (('ggTundra', 'KingJames'), 2),
#  (('ggTundra', 'NBA'), 2),
#  (('Soroosh_N', 'undisputed'), 2),
#  (('a11jokesaside', 'Cam_ATL'), 2),
#  (('theOfficialcjay', '_itsjustceedie'), 2),
#  (('BowenLeatham', 'LilSkies'), 2),
#  (('WitnessMurda', 'troybwai'), 2),
#  (('RFCapsMoustache', 'JapersRink'), 2),
#  (('MoeFloyd1', 'RoughRyder5'), 2),
#  (('AnishESPN', 'Turn_Rake13'), 2),
#  (('GabiPronos', 'xela751'), 2),
#  (('Shane2Phresh', 'SpursOfficial'), 2),
#  (('RickyJa62083310', 'TopRockey'), 2),
#  (('Nathan92743754', 'CareerMDFIFA'), 2),
#  (('ggTundra', 'WebHead416'), 2),
#  (('TysonMurdockt', 'haze507'), 2),
#  (('TysonMurdockt', 'TrevorFox3000'), 2),
#  (('TysonMurdockt', 'espn'), 2),
#  (('Darren_Martin23', 'NBA2K_MyTEAM'), 2),
#  (('JuanGar__', 'RealJayWilliams'), 2),
#  (('BrownBrownc26', 'BrownBrownc26'), 2),
#  (('_twoaas', 'nsgwk'), 2),
#  (('fgcromantic', 'SlackSlick'), 2),
#  (('Jlowe2836', 'The_Uncontested'), 2),
#  (('heisheisbaby', 'SouthwestAir'), 2),
#  (('5Tmonious', 'TheNBACentral'), 2),
#  (('OverlayDFS', 'FantasytipsRyan'), 2),
#  (('RichinNJ', 'alanhahn'), 2),
#  (('og_nfl', 'JerseyCapperNHL'), 2),
#  (('americanluka', 'torandtp'), 2),
#  (('Timgal2', 'keith_millhouse'), 2),
#  (('BDLeT', 'GuiltGaming'), 2),
#  (('cupofjoeinCali', 'AwkwardlyAisha'), 2),
#  (('shellielopez', 'ChrissyFireWat1'), 2),
#  (('COCoachCuevas', 'damanr'), 2),
#  (('PoloHammer1', 'forumbluegold'), 2),
#  (('Mictamac', 'CollinSexton02'), 2),
#  (('kpelton', 'andrewthehan'), 2),
#  (('DeckerKabana', 'NBAonTNT'), 2),
#  (('MtbLawson', '26ssn'), 2),
#  (('xoDNDxo', 'Complex'), 2),
#  (('1079thelink', 'RamonaHolloway'), 2),
#  (('1079thelink', 'mattharris1079'), 2),
#  (('1079thelink', 'LillyPulitzer'), 2),
#  (('EricRey90', 'NBA'), 2),
#  (('wurst_law', 'thelonghorns12'), 2),
#  (('petebraverman', 'straf78'), 2),
#  (('PenGriffeyJr97', 'ESPNNBA'), 2),
#  (('JasonMorrow270', 'ekulycats'), 2),
#  (('Purple2k8', '1'), 2),
#  (('JosaAllan', 'timandsid'), 2),
#  (('IsaBeans79', 'NY_KnicksPR'), 2),
#  (('AlekGoOttawa', 'brkicks'), 2),
#  (('uelmendrado', 'Alan_Dunne69'), 2),
#  (('NumberBallDFS', 'JeffKCollins'), 2),
#  (('NumberBallDFS', 'Jumpahoo'), 2),
#  (('WMTWVikesFan8', 'MaryCateMannion'), 2),
#  (('OKCTHUNDERAlex', 'OKCTHUNDERAlex'), 2),
#  (('ThreezusSeason', 'PlayoffVanVleet'), 2),
#  (('Joshledermann', 'datafox21'), 2),
#  (('DiggsvsWorld', '305DakV3'), 2),
#  (('DubsUnderdogSzn', 'GarrisonBall423'), 2),
#  (('IannelliAntonio', 'Ronnie2K'), 2),
#  (('dpwhite2', 'egoldie80'), 2),
#  (('tweetedstuff', 'Appleton4123'), 2),
#  (('cajunsaint88', '1037TheGame'), 2),
#  (('beards_james', 'JohnMiddlekauff'), 2),
#  (('aveowens_', 'CWagner70'), 2),
#  (('BidouMaxouu', '1'), 2),
#  (('BMitchell0121', 'jamesbhawkins'), 2),
#  (('OverlayDFS', 'WagerDrop'), 2),
#  (('amarinhonatal', 'BNODesk'), 2),
#  (('ZPAC3BOY', 'ImBrock'), 2),
#  (('JordanSwofford1', 'JChipmunky'), 2),
#  (('pbntrey', 'RTNBA'), 2),
#  (('wetbuckets88', '_willyJuanca_'), 2),
#  (('rick_bonnell', 'AschNBA'), 2),
#  (('evanstonceltfan', 'evanstonceltfan'), 2),
#  (('_kinabii', '_JasonLT'), 2),
#  (('prophetokounmpo', 'prophetokounmpo'), 2),
#  (('BoyHowdyESPN', 'DanGrazianoESPN'), 2),
#  (('Tha_HunterGames', 'cph12345'), 2),
#  (('mYant1k', 'Kcash_ballhard'), 2),
#  (('KingKev83210032', 'theericmoss'), 2),
#  (('KingJ_243', 'FA'), 2),
#  (('UrbanSportS_Ray', 'Armon_Lee'), 2),
#  (('KingJonesThe1st', 'NBA'), 2),
#  (('TravLyleCzech', 'B_HedtkeNBA'), 2),
#  (('BhavikUpadhya14', 'docKev_'), 2),
#  (('MarkOneSports', 'Money_LineDFS'), 2),
#  (('j_matuska', 'Decievxd'), 2),
#  (('wpNBA', 'dunkrugering'), 2),
#  (('Mister4thRow', 'RefAubrey'), 2),
#  (('2kdwightboy', 'dahandles792078'), 2),
#  (('betchanger', 'betchanger'), 2),
#  (('homiehar', 'Zionwilliamson'), 2),
#  (('lelz818', 'nytimes'), 2),
#  (('andykarns', 'cbefred'), 2),
#  (('wetbuckets88', 'beardjam'), 2),
#  (('ZioDedeRulez', 'EASPORTSNBALM'), 2),
#  (('diegovaMX', 'MarcoReyPicks'), 2),
#  (('DOAHITMAN', 'Captain_Algebra'), 2),
#  (('Grizzly_Shark', 'BrandonfrmNJ'), 2),
#  (('Mike_N_Ike93', 'Dunn_Did_It'), 2),
#  (('powadis', 'UNCUTOPINION1'), 2),
#  (('MrWar3_21', 'NBA'), 2),
#  (('nytrendc', 'Trevornoah'), 2),
#  (('NewYorkKingz', 'SactownKings23'), 2),
#  (('Scoo73r', 'Dallas_Hackers'), 2),
#  (('ak_square9', 'Ruptly'), 2),
#  (('metatoaster', 'SamAdlerBell'), 2),
#  (('Greatergood33', 'ColinSexton'), 2),
#  (('valem1962', 'KingDejounte'), 2),
#  (('JackRayWise317', 'bomani_jones'), 2),
#  (('GatorViking56', 'BarackObama'), 2),
#  (('lou_coach', 'JCMacriNBA'), 2),
#  (('youngneeno91', 'Lavarbigballer'), 2),
#  (('wetbuckets88', 'paulblartofwar'), 2),
#  (('RyanGrosman', 'NoDunksInc'), 2),
#  (('Mental_Mastodon', 'Journaling4Life'), 2),
#  (('OG_TrueBalla', 'bgard_21'), 2),
#  (('o_hoops', 'o_hoops'), 2),
#  (('wankunext', 'MulloSZNv4'), 2),
#  (('SznVibes', 'Deantree3'), 2),
#  (('SPORTWORLDORDER', 'LTJ81'), 2),
#  (('ThatGuyAlvin25', '_MikeLowrey1'), 2),
#  (('oth_basketball', 'tomtoowitty'), 2),
#  (('ekow_Sarkcess', 'Teye_Mensa'), 2),
#  (('i_am_dharyore', 'betchanger'), 2),
#  (('Jamal4Raps', 'yyzsportsmedia'), 2),
#  (('90z__Kidd', 'NBA'), 2),
#  (('tommyk415', 'RotoRadarRiemer'), 2),
#  (('SlimSparty', 'ItsAntWright'), 2),
#  (('ArchOfDimesSZN', 'YoungMace22'), 2),
#  (('SSGSSJLeo', 'PlayStationEU'), 2),
#  (('bozwhite', 'CDSXCalibur'), 2),
#  (('LOUDORETIRED829', 'RotoRadarRiemer'), 2),
#  (('DJG12345', 'barstoolsports'), 2),
#  (('thatsonly_dessy', '_travisdopeazz'), 2),
#  (('RuuWop', 'NBA'), 2),
#  (('mtw2615', '3hristgian1'), 2),
#  (('ChiTown1988', 'WaddleandSilvy'), 2),
#  (('YahooFantasyCC', 'BKz00Best'), 2),
#  (('PatreekyONeal', 'BackAftaThis'), 2),
#  (('IcyRowan', 'mvplamar8'), 2),
#  (('bovisss', 'emilsanchez33'), 2),
#  (('WilsonSy93', 'jimmycfields'), 2),
#  (('Lensonek', 'NBA'), 2),
#  (('SwaGrimeSwag', 'HoodieCurry'), 2),
#  (('Cehuff501', 'TamaraMAuthor'), 2),
#  (('Aliikuscu43', 'mobilbahisresmi'), 2),
#  (('SnowmanMcK', 'Yourpetcat'), 2),
#  (('detroit_wyso', 'NicolasHenkel'), 2),
#  (('DMVCoop301', 'FBGZeus_'), 2),
#  (('jssacramento', 'SpectrumSN'), 2),
#  (('OKCTHUNDERAlex', 'kylewagers_'), 2),
#  (('Jahslove8', 'dhm'), 2),
#  (('sue_bengi', 'raf_tyler'), 2),
#  (('EyeOfTru', 'forumbluegold'), 2),
#  (('JDoublEisMe', 'JMV1070'), 2),
#  (('CafedesParieurs', 'theo69prono'), 2),
#  (('joeytlax', 'epaschall'), 2),
#  (('Qamyasharahla', 'shamback7'), 2),
#  (('danielharvey13', 'Mental_Mastodon'), 2),
#  (('bradley08185329', 'messengerart'), 2),
#  (('juliehmatta', 'dbhostage'), 2),
#  (('FlashCadillac', 'RealChrisCal'), 2),
#  (('PatrickNFlorid1', 'MarcoCorleone23'), 2),
#  (('DaFuturMrKc', 'welplookathim'), 2),
#  (('Young_Mitch_', 'Troy_Smith4'), 2),
#  (('LantzounisNikos', 'EASPORTSNBALM'), 2),
#  (('tnice4250', 'JCMacriNBA'), 2),
#  (('YUMadBro808', 'nonstopsports12'), 2),
#  (('jcvelez9494', 'FantasyLabsNBA'), 2),
#  (('craig_gobbie', 'Stimpy870'), 2),
#  (('kondwani_k7', 'YoungNBA'), 2),
#  (('kingofda914', 'SureShotTD'), 2),
#  (('JJacksonSport', 'IronSportsCards'), 2),
#  (('2KSupport', 'TylerJ68712126'), 2),
#  (('Scoo73r', 'VernSix'), 2),
#  (('6AKINGNYC', 'Jumpahoo'), 2),
#  (('Dado3615', 'antune808'), 2),
#  (('meremazin', 'NBA1Hoops'), 2),
#  (('whataboutchris3', 'AkaashSingh'), 2),
#  (('FantasyProsNBA', 'smooth1074'), 2),
#  (('AdjustFirePolar', 'theStevenRuiz'), 2),
#  (('Nate_Tice', 'jjones9'), 2),
#  (('fergalicious97', 'lookatmyopinion'), 2),
#  (('VasilNadyaLove', 'kobebryant'), 2),
#  (('CollegeCapper4', 'CollegeCapper4'), 2),
#  (('MrLexLuthor', 'undisputed'), 2),
#  (('JustAcoxxx', 'FinnatWagerTalk'), 2),
#  (('DAveryM', 'dkirk528'), 2),
#  (('Respect0vaMoney', 'RussNRoses'), 2),
#  (('jc_penney13', 'Justin_Dyer10'), 2),
#  (('sambondyo', 'Nicholaswisco'), 2),
#  (('JimKotowski', 'BuRuSkEeE'), 2),
#  (('John32193769', 'nbagleague'), 2),
#  (('SpiritPilot', 'NotoriousLRC'), 2),
#  (('Clintb3astw00d1', '97Vercetti'), 2),
#  (('WordsByBartlett', 'newguymeltz'), 2),
#  (('WordsByBartlett', 'eauj2'), 2),
#  (('So_HTown', 'Walthaari'), 2),
#  (('Shoe_Gawd', '_Dreadh3ad'), 2),
#  (('Rumb3lly', 'NBA'), 2),
#  (('MikeTrozzo', 'sjordan1978'), 2),
#  (('AlyssaRunning', 'AhoyMeghan'), 2),
#  (('seanb410', 'swaveyquis'), 2),
#  (('SoccerIsArt', '7_Ft_Schnitzel'), 2),
#  (('Cortez72life', 'JHoov31'), 2),
#  (('Rw_moe', 'WorldWideWob'), 2),
#  (('nickiesmind', 'WiltFans13'), 2),
#  (('dex1dexter', 'christophclarey'), 2),
#  (('BoleslawWisnie1', 'JoeCanari'), 2),
#  (('shortkingko', 'levitatevhs'), 2),
#  (('LittleEarl4', 'JoeyKnish22'), 2),
#  (('MichaelGray319', 'Chris_Broussard'), 2),
#  (('SB_Mide', '7salmy'), 2),
#  (('CoachDonnieB', 'theericmoss'), 2),
#  (('KC1294', 'NBA'), 2),
#  (('Mgl_UTB', 'EASPORTSNBALM'), 2),
#  (('Greatergood33', 'Bam1of1'), 2),
#  (('tr_posts', 'ChiSportUpdates'), 2),
#  (('kyleludz', 'NBA2K_MyTEAM'), 2),
#  (('GhanasFinest__', 'tlobed_n'), 2),
#  (('DanLifshatz', 'cheeks7280'), 2),
#  (('therealtoddyg', 'rap_discussions'), 2),
#  (('detroitbadboys', 'rjcc'), 2),
#  (('BobbyShokri', 'aaronbruski'), 2),
#  (('buckshot221', 'MikeFromCLE'), 2),
#  (('Kinglam94', 'GrantNapearshow'), 2),
#  (('RaskinsThe', 'JavaJerry101'), 2),
#  (('TLSPanthersV2', '4ourmanrush'), 2),
#  (('Shyne649', 'MrWest25'), 2),
#  (('CoachFatal', 'MjsGoat'), 2),
#  (('franzh_yron', 'alexabrines'), 2),
#  (('_JasonLT', 'ThePackageJG'), 2),
#  (('barrypopik', 'NetsDaily'), 2),
#  (('TrubiskyisMVP', 'BooksbySelena'), 2),
#  (('TrubiskyisMVP', 'NY_KnicksPR'), 2),
#  (('TomGB13', 'TheCousinDarrel'), 2),
#  (('raremar_', 'Treeeeeee__'), 2),
#  (('theGar3bear', 'Stetsssss'), 2),
#  (('micahclark8594', 'AceBoogie_MVP'), 2),
#  (('the3els', 'SportsFan4Lif10'), 2),
#  (('UhOhSpaghettiJo', 'NBA'), 2),
#  (('ZIADinter', 'KaiserRossii'), 2),
#  (('juany3_', 'Kirkykirk11'), 2),
#  (('bballbreakdown', 'TwoWayGame'), 2),
#  (('nbafanLBJ', 'FTFonFS1'), 2),
#  (('AndrewDBailey', 'UhOhSpaghettiJo'), 2),
#  (('collinh_24', 'RealSkipBayless'), 2),
#  (('the2kmessiah', 'goknickstape'), 2),
#  (('therobertdunlap', 'dortmund281'), 2),
#  (('nik_bhatia', 'EASPORTSNBALM'), 2),
#  (('IVFreddyp', 'NBA'), 2),
#  (('stevedream7', 'pennys2pounds'), 2),
#  (('UnmanlyGrief', 'jazzypizzaz'), 2),
#  (('ramreport4u', 'DOgemade'), 2),
#  (('7c796f2ead6c4e1', 'EricRey90'), 2),
#  (('eakhead', 'legitrealnexx'), 2),
#  (('eakhead', 'DrGuru23'), 2),
#  (('eakhead', 'jordan6288363'), 2),
#  (('eakhead', 'TheNBACentral'), 2),
#  (('eakhead', 'Lakers'), 2),
#  (('MattyZychowski', 'justjarvon'), 2),
#  (('Kutz007', 'espn'), 2),
#  (('Losingtoagirl', 'shaneconnlly44'), 2),
#  (('Dom_2k', 'b_sutterer'), 2),
#  (('Blackphantom727', 'Ballislife'), 2),
#  (('kjstavely', 'EKANardini'), 2),
#  (('abz10i', 'Coutskill24'), 2),
#  (('YamilRomanPSN', 'k014c'), 2),
#  (('SportsGrouch', 'sigg20'), 2),
#  (('MattB_WOF', 'jglowaski'), 2),
#  (('jarrod48118284', 'aterry65'), 2),
#  (('brosNsoles', 'Cortez72life'), 2),
#  (('MrFroemming', 'USC1620'), 2),
#  (('Kevin_Wensing', 'MaggieStrong'), 2),
#  (('gtd123', 'WilsonSy93'), 2),
#  (('FloaterGodShai', 'SimmonsWRLDx3'), 2),
#  (('ItSG_Sn0w', 'JeffEisenband'), 2),
#  (('DenkerPark', 'SportsCenter'), 2),
#  (('BETS305', '1QGuru'), 2),
#  (('rebornbyksg', 'okcthunder'), 2),
#  (('SamuelDeckerT', 'SpectrumSN'), 2),
#  (('tylerccooper14', 'qshironalbertie'), 2),
#  (('aPointGod', 'TatumxMitchell'), 2),
#  (('BrettFrown', 'PhilaPhilosophy'), 2),
#  (('adoggNJ', 'TheRealCuzz'), 2),
#  (('GuiltyGamerz', 'majornelson'), 2),
#  (('DynastyLewis_', 'AugustineMLB'), 2),
#  (('JusMalik_', 'yates_dominick'), 2),
#  (('Michael59097217', 'haydenmc19'), 2),
#  (('_Pomasi', 'EyramAkaba'), 2),
#  (('NotMario05', 'simo_393'), 2),
#  (('PubRunSA', 'Mmelindalopez'), 2),
#  (('melanieangeb', 'FirstTeam101'), 2),
#  (('FreeKings3', 'kingtisemedia'), 2),
#  (('TrollSportsUSA', 'Knicks_Chatter'), 2),
#  (('nightmarenextd1', 'OfficialLdnAbz'), 2),
#  (('JamesBrousseau', 'maxkellerman'), 2),
#  (('Navetse89', 'anewmanofficial'), 2),
#  (('Anthony_parker5', 'Kendawwwg_'), 2),
#  (('jake_schaffer15', 'MaxONeile'), 2),
#  (('themightygwinn', 'ClayTravis'), 2),
#  (('CJsWorld23', 'PointGods'), 2),
#  (('mvankin', 'FriedgeHNIC'), 2),
#  (('ImtheCHIEF4', 'NBA'), 2),
#  (('mindiva68', 'BarstoolKU'), 2),
#  (('KevinPawell23', 'JDirty26'), 2),
#  (('MissDimples767', 'CaribbeanGunner'), 2),
#  (('NoJuiceDon', 'J_UNDFTD'), 2),
#  (('dredzborba', 'PedroR1998'), 2),
#  (('HeadbandKPJ', 'qshironalbertie'), 2),
#  (('the_Annelis', 'nysportsfan2015'), 2),
#  (('tracylampley', 'FranchiseTag_14'), 2),
#  (('HOFbarrybonds25', 'woodrgrant'), 2),
#  (('CharlieRode', 'Rosenbergradio'), 2),
#  (('PhenomenalMikes', 'BambJack'), 2),
#  (('NBANotMath', 'NewsOfTheNBA1'), 2),
#  (('mikeMIKE2315', 'mitchell_ness'), 2),
#  (('nyusteinhardt', 'juniorknicks'), 2),
#  (('PicksCity', 'ClePicks'), 2),
#  (('jdmannjd', 'BooneGage'), 2),
#  (('ScoutWithBryan', 'MikeMoody334'), 2),
#  (('swaveyquis', 'True_Rys'), 2),
#  (('JTrain07', 'mgoss88'), 2),
#  (('TimJohnEdwards', 'theScore'), 2),
#  (('ItsMuriMehn', 'hoopshype'), 2),
#  (('BanidoLuca', 'EdwardCavalier'), 2),
#  (('mertbizk', 'scottfunk0'), 2),
#  (('Pat5Mertz', 'espn'), 2),
#  (('GH0UL_v', 'KMaddify'), 2),
#  (('TylerDildine', 'utahjazzman47'), 2),
#  (('etetet40261292', 'revman312'), 2),
#  (('SportingPhil', 'DaveDuFourNBA'), 2),
#  (('70PercentClub', 'RookieWiseguy'), 2),
#  (('DannyBKBushwick', 'Ayalaj12'), 2),
#  (('_diegolegend', 'TMC_270'), 2),
#  (('RalphieTheRuler', 'JordyMac52'), 2),
#  (('VictorJrValdes1', 'XboxGamePass'), 2),
#  (('ruel_4745', 'Chris_Broussard'), 2),
#  (('ibz1acev6', 'darjascerbinina'), 2),
#  (('EvMclovin', 'undisputed'), 2),
#  (('mekhi804', 'BarkleyWRLD'), 2),
#  (('nbafanLBJ', 'NBAonTNT'), 2),
#  (('nysportsfan2015', 'the_Annelis'), 2),
#  (('therealjrodjr', 'KingJames'), 2),
#  (('francethel', 'imgrazel'), 2),
#  (('MannyNeva77', 'TillaAltaf'), 2),
#  (('timfairchild3', 'ShienksFN_'), 2),
#  (('PeterStormcast2', 'JakeMoo22377928'), 2),
#  (('BookOfJoshua19', 'Bevlin19'), 2),
#  (('SpartanMatt8497', 'EWOKinLA'), 2),
#  (('Jrodbad', 'LineStarApp'), 2),
#  (('crademacher2006', 'IraSilverMagic'), 2),
#  (('qshironalbertie', 'tylerccooper14'), 2),
#  (('Angle4U999', 'LVBookieKilla'), 2),
#  (('brettbensley', 'IndyWes'), 2),
#  (('TJ91734681', 'NBA'), 2),
#  (('Orangeman96', 'redkacheek'), 2),
#  (('Orangeman96', 'SiriusXMFantasy'), 2),
#  (('bwtjunior', 'jjones9'), 2),
#  (('kendraperr', 'Kameron_Hay'), 2),
#  (('AFlatCircle7', 'barstoolsports'), 2),
#  (('BransonOtis99', 'NBA'), 2),
#  (('RocketsPIsWin', 'KlawSZN'), 2),
#  (('LBJAMES242', 'NBA'), 2),
#  (('Coolguy55510', 'NBA'), 2),
#  (('VocalzIz', 'BSPN_NewOrleans'), 2),
#  (('dustinwill24', 'DavidMTodd'), 2),
#  (('Lebronston1', 'SportsHackCA'), 2),
#  (('DontArgueTM', 'AndrewDBailey'), 2),
#  (('AggieLarry', '975Hans'), 2),
#  (('ibelievein3', 'CHAMP_ZOE'), 2),
#  (('AndamoJoey', 'jrichardgoodman'), 2),
#  (('valenpronos', 'betivore'), 2),
#  (('beezus_fm', 'NBA'), 2),
#  (('willcollective', 'wglady'), 2),
#  (('MikeZeuss', 'NBA'), 2),
#  (('MikeZeuss', 'Bucks'), 2),
#  (('MikeZeuss', 'unitedmasters'), 2),
#  (('qshironalbertie', 'HeadbandKPJ'), 2),
#  (('sjthedon08', 'BigFellow_504'), 2),
#  (('Westbrook00MVP', 'NBA'), 2),
#  (('camp_ky', 'chris_cjg'), 2),
#  (('MasonGinsberg', 'BrettBersuder'), 2),
#  (('BugzBryant', 'Dtrotter11'), 2),
#  (('LogicalLoner13', 'BullsGotNext'), 2),
#  (('wesabraham', 'ShannonSharpe'), 2),
#  (('Odj0355', 'NBA'), 2),
#  (('jhackman11', 'bjarzomski'), 2),
#  (('TheWestbrookEra', 'KlawSZN'), 2),
#  (('srburgo2', 'Bucks'), 2),
#  (('InfamousDC_', 'barstoolsports'), 2),
#  (('allenisaballer', 'DfsRiches'), 2),
#  (('the_hodgepodge', 'MsPeters14'), 2),
#  (('Real_Tyone', 'NBA'), 2),
#  (('mjack704', 'XJF_11'), 2),
#  (('JSmithM30', 'TaySmith1021'), 2),
#  (('Reynald03003553', 'tonydombrowski'), 2),
#  (('trangbawdy', 'jxrviz'), 2),
#  (('nikolaivgrundie', 'sleean18'), 2),
#  (('Free__Mareo', 'uzitypebeat'), 2),
#  (('KFrxzier', 'BHall55__'), 2),
#  (('Travismilton7', 'BSPN_NewOrleans'), 2),
#  (('SenseiSigh', 'G_DonJuan'), 2),
#  (('UNCUTOPINION1', 'NBA'), 2),
#  (('Detcookieman74', 'BigDrewandJim'), 2),
#  (('BasketPronostic', 'SBRSportsPicks'), 2),
#  (('UndisputdGOAT', 'LA_Goat_'), 2),
#  (('Justice68234316', 'USSupremeCourt'), 2),
#  (('KhariMaxwell', 'HotTakeEmpire'), 2),
#  (('LonelySkip', 'KendrickPerkins'), 2),
#  (('jimmycfields', 'LakesBiggz'), 2),
#  (('johnrybow', 'TWaddle87'), 2),
#  (('gloomysmitty', 'mallee_chris_24'), 2),
#  (('GVEEZUS', 'krisdjor'), 2),
#  (('M_Valentine25', 'RealToniiioo'), 2),
#  (('MJoemal19', 'Julietknows1'), 2),
#  (('Jumpman901', 'Klow7'), 2),
#  (('vamonostendos', 'nacionapuestas'), 2),
#  (('dathaniel9', 'GSWFastBreak'), 2),
#  (('CassellJesse', 'catwithagat'), 2),
#  (('JoeCrypticc', 'IanCharles33'), 2),
#  (('LonTalkinBall', 'NBCSCeltics'), 2),
#  (('SwagDiddy5', 'warriors'), 2),
#  (('TrubiskyisMVP', 'Nomad_2414'), 2),
#  (('KorayDavulcu2', 'NBA'), 2),
#  (('BooksbySelena', 'TrubiskyisMVP'), 2),
#  (('iveyjanette_207', 'ForzaCorrado'), 2),
#  (('ThomasPWebster4', 'StormIsUponUs'), 2),
#  (('TheKingOfAlb', 'BobbyOnealGibbs'), 2),
#  (('DamnGho', 'DonkeyGreenn'), 2),
#  (('hammer41481', 'NBCSPhilly'), 2),
#  (('roycefor3', 'RocketsPIsWin'), 2),
#  (('FloaterGodShai', 'HerroWalkNBCKT'), 2),
#  (('TheRealFakeCoby', 'DimerWestbrook'), 2),
#  (('shawmilasdream_', 'salma74817605'), 2),
#  (('Woodshed_1914', 'BigFreezie'), 2),
#  (('_illminded__', 'LukeFredsell'), 2),
#  (('davwain1', 'davwain1'), 2),
#  (('davwain1', 'realtime28'), 2),
#  (('davwain1', 'lamegirldotcom'), 2),
#  (('davwain1', 'jacktodd46'), 2),
#  (('davwain1', 'MaynardM'), 2),
#  (('davwain1', 'LUFC'), 2),
#  (('davwain1', 'SkyBetChamp'), 2),
#  (('g_whan', 'warriorsworld'), 2),
#  (('TylerLopes', 'DParkOK'), 2),
#  (('mjack704', 'GreenBleed4'), 2),
#  (('Jayhawkman33', 'BelMOCards'), 2),
#  (('DubCThaDJ', 'ty_bradford18'), 2),
#  (('BrumAxe', 'Coolguy55510'), 2),
#  (('BrumAxe', 'unitedmasters'), 2),
#  (('MarkEddy17', 'chicagobulls'), 2),
#  (('godawgs_uga', 'NBA'), 2),
#  (('AZD7', 'Bucks'), 2),
#  (('lionsdepression', 'TheStarofPars'), 2),
#  (('T_Coin', 's_doo228'), 2),
#  (('BrumAxe', 'Westbrook00MVP'), 2),
#  (('Bobby_boy_Rick', 'cavs'), 2),
#  (('Javanzord', 'alkmerlin'), 2),
#  (('mattstankowski', 'z_HeHateMe_z'), 2),
#  (('MrDontPlay23', 'MichaelRyanRuiz'), 2),
#  (('MajorHealy1976', 'mgiannotto'), 2),
#  (('EditorParry', 'Makwolf317'), 2),
#  (('pisceze_95', 'NBADraftAddict'), 2),
#  (('GotPercsFoTha5', 'Ninja'), 2),
#  (('Pelozinho1', 'FTFonFS1'), 2),
#  (('Grimmy33', 'NBA'), 2),
#  (('rick_bonnell', 'KyleBaileyClub'), 2),
#  (('ColeLopez77', 'TribeAllDay'), 2),
#  (('Vasiliaspeaks16', 'joelix_'), 2),
#  (('jrod_murph', 'Jim_Eichenhofer'), 2),
#  (('Kendra87871', 'CSU_Basketball'), 2),
#  (('tahoereality', 'Bucks'), 2),
#  (('ADozier23', 'UNCLE_Traww'), 2),
#  (('DaYz7eD', 'BR_NBA'), 2),
#  (('Jfrie_', 'Complex'), 2),
#  (('djchrisvalencia', 'flyrodu'), 2),
#  (('heysarahgray', 'NoDunksInc'), 2),
#  (('Champagne_Lo', 'NoFrankOcean'), 2),
#  (('Champagne_Lo', 'DimesFromRose'), 2),
#  (('HunchoRf', '2KIntel'), 2),
#  (('sour_faced', 'hoddro'), 2),
#  (('SoCalLakerGuy', 'BruceDavion'), 2),
#  (('PhillyHotspur', 'thunderducks26'), 2),
#  (('OhtaniWRLD', 'Grifcanningpls'), 2),
#  (('jackie_peanuts', 'ForceOfWillby'), 2),
#  (('Grimmy33', 'DraylonWiggins'), 2),
#  (('YuTyREV', 'N5General'), 2),
#  (('TwoWayGame', 'bballbreakdown'), 2),
#  (('OsamaHarden', 'DanteLaSoul'), 2),
#  (('Jacksonw194', 'jessimarsh14'), 2),
#  (('SBRFlores', 'THE_MFLORES'), 2),
#  (('KingMvkY', 'OprahSide'), 2),
#  (('dammfool02', 'TripleRussell0'), 2),
#  (('jaganfan007', 'Dream11'), 2),
#  (('danntheshoota', 'thirdeyewydee'), 2),
#  (('Jewleeus_Erving', 'DonDoneItBizzle'), 2),
#  (('RealRiyanBadMon', 'mogetemz'), 2),
#  (('OhMrWilson314', 'Champagne_Lo'), 2),
#  (('BrandonCho20', 'balldontstop'), 2),
#  (('RedoneL', 'hoopshype'), 2),
#  (('UndergroundPixl', 'diddy2321'), 2),
#  (('Ndbrown19', 'Chaseschoeff9'), 2),
#  (('Ndbrown19', 'kuzzzii'), 2),
#  (('RubeOnRoundball', 'nbastats'), 2),
#  (('C__Morg', 'cap_alo'), 2),
#  (('Tats_NSnapbacks', 'ESPNNBA'), 2),
#  (('kingtisemedia', 'D25940'), 2),
#  (('NateGillespie20', 'barstoolsports'), 2),
#  (('VernielCutar', 'mb_1789'), 2),
#  (('Justacowpoke', 'LaloPicheco'), 2),
#  (('Primewire4', 'ivergoat'), 2),
#  (('sammy_exe', 'partenopeppe'), 2),
#  (('seydikurdi', 'AFP'), 2),
#  (('JuanCas96722034', 'Ronnie2K'), 2),
#  (('IrishHoligan', 'SportsGuy827'), 2),
#  (('benjaminjreeder', 'emmakapotes'), 2),
#  (('corpusjoe', 'benmaller'), 2),
#  (('echaan_', 'warriors'), 2),
#  (('b0rnr34dy', 'RealSkipBayless'), 2),
#  (('StChester', 'RexChapman'), 2),
#  (('JDWilsonLive', 'mcufan85'), 2),
#  (('BaylessDripp', 'EarnestRedner'), 2),
#  (('3DDigitalVenue', 'Timberwolves'), 2),
#  (('ar9cip', 'johnnymodem'), 2),
#  (('Maurice19684207', 'Sportsnet'), 2),
#  (('kdubmartins', 'NBA'), 2),
#  (('dabra866', 'NBA'), 2),
#  (('Don8Please', 'Tritonfootball'), 2),
#  (('spoodadoo23', 'CBSSports'), 2),
#  (('FLOATITEMSEAGLE', '304skywalkerjr'), 2),
#  (('FLOATITEMSEAGLE', 'FLOATITEMSEAGLE'), 2),
#  (('JBirdistehword', 'BeccaMVP'), 2),
#  (('VTrantolo', 'BleacherReport'), 2),
#  (('RolfOxford1965', 'mrclarkinc'), 2),
#  (('jordanw1096', 'AllTimeDynasty2'), 2),
#  (('chargers_talk', 'JustLob_It'), 2),
#  (('Bonnie80077905', 'dallasmavs'), 2),
#  (('fslnrrhmn', 'AliFG_PAGE'), 2),
#  (('MarqsJO', 'Jay7For7'), 2),
#  (('theringa', 'BillSimmons'), 2),
#  (('ddpage369', 'danyeeze'), 2),
#  (('dmh2123', 'minakimes'), 2),
#  (('JohnPea91483753', 'NBL'), 2),
#  (('JosephO100T', 'SubToOptimus'), 2),
#  (('duhhseann', 'NYG_4_LIFE'), 2),
#  (('SubToOptimus', 'JosephO100T'), 2),
#  (('realrozviking', 'mollyhannahm'), 2),
#  (('BtowncbdC', 'IanMcC508'), 2),
#  (('leonardFGA', 'DwyaneWade'), 2),
#  (('toshington3', 'TruGrind14'), 2),
#  (('Mo_Basil7', 'brownanddrunk'), 2),
#  (('xiong88253914', 'NBA'), 2),
#  (('LeBron_AD_xoxo', 'NBA'), 2),
#  (('V3RTEXRL', 'VexzRL'), 2),
#  (('elvisfan05', 'memgrizz'), 2),
#  (('karlbubi', 'roby_trillz'), 2),
#  (('karlbubi', 'ohheylolbye'), 2),
#  (('hahaxiaowen', 'NBA'), 2),
#  (('sambridges_10', 'NBL'), 2),
#  (('sambridges_10', 'StephenCurry30'), 2),
#  (('iamstevie', 'OlgunUluc'), 2),
#  (('ddpage369', 'LakersNation'), 2),
#  (('Magic_Mahomes', '412champs'), 2),
#  (('mr_stfo', 'NBA'), 2),
#  (('Olaitan7r', '10a2Newton'), 2),
#  (('PassPassRun', 'mrvincecarter15'), 2),
#  (('A7kyFUOceuiCW5z', 'EASPORTSNBALM'), 2),
#  (('ddpage369', 'TheBoostress'), 2),
#  (('ndr_sbl', 'warriors'), 2),
#  (('Rubiks6', 'jodurodola'), 2),
#  (('WorldclubBbal', 'GloballyBallin'), 2),
#  (('sid_vishnoi', 'TherenceJoseph'), 2),
#  (('Paulcowderoy', 'MikePradaSBN'), 2),
#  (('hustle_mobb', 'BleacherReport'), 2),
#  (('elvisfan05', 'GrizzliesPR'), 2),
#  (('freebird215', 'howaboutafresca'), 2),
#  (('vesnsports', 'newyscruggs'), 2),
#  (('MoscovaRoger13', 'AlecJ24'), 2),
#  (('bobby_burritos', 'AdamC11'), 2),
#  (('offlineoreo', 'panpanron'), 2),
#  (('jeffcent1001', 'JamesSmith1001'), 2),
#  (('BerniesTix', 'NBCSCeltics'), 2),
#  (('wedwingwon', 'joshtpm'), 2),
#  (('jaxsontl7', 'darcangel21'), 2),
#  (('MurKiR6', 'zZMaV3RiCkZz'), 2),
#  (('ciccaporta', 'espn'), 2),
#  (('bixford24', 'nyknicks'), 2),
#  (('yungdomdom', '9OneTwo11'), 2),
#  (('blackdisney1', 'TheSwaggyBlerd'), 2),
#  (('RastaAsim', 'Its_karishma'), 2),
#  (('pietererber', 'jovebenidine'), 2),
#  (('JeffreySorrell4', 'nyknicks'), 2),
#  (('Shamelessjt', 'Tom69259252'), 2),
#  (('rahmmagick', 'HtownFlows'), 2),
#  (('ChrisTookFlight', 'BleacherReport'), 2),
#  (('e_a86', 'SkySports'), 2),
#  (('OriginalKD7', 'mrpatriq'), 2),
#  (('TylerBMcKinley', 'espn'), 2),
#  (('iamtopherb', 'NBA'), 2),
#  (('howiegoldfarb', 'bdorman264'), 2),
#  (('howiegoldfarb', 'nyknicks'), 2),
#  (('MikoPalero', 'MikoPalero'), 2),
#  (('JayHughes1963', 'GottliebShow'), 2),
#  (('JohnJen1017', 'ShayneNY_'), 2),
#  (('LPFE1972', 'JoeyTheMisfit'), 2),
#  (('LPFE1972', 'nbastats'), 2),
#  (('LPFE1972', 'NBA'), 2),
#  (('LPFE1972', 'NBAHistory'), 2),
#  (('LPFE1972', 'EliasSports'), 2),
#  (('trentmayne7', 'NBL'), 2),
#  (('MosVision2', 'RaisedInHell666'), 2),
#  (('anthrolooker', 'ZacharySaldiva3'), 2),
#  (('prodbydomi', 'emafabolous'), 2),
#  (('_ChocolateCurry', 'Amdtrades'), 2),
#  (('LPFE1972', 'RubeOnRoundball'), 2),
#  (('vvvpavlic', 'sukairaaa'), 2),
#  (('JeffBigDreamerH', 'sklar37'), 2),
#  (('JeffBigDreamerH', 'PincheJuan107'), 2),
#  (('JeffBigDreamerH', 'ComplexSports'), 2),
#  (('JeffBigDreamerH', 'Complex'), 2),
#  (('Olaitan7r', 'shamewess'), 2),
#  (('mrkorcker', 'Smar9110'), 2),
#  (('_IamTrueHate', 'docKev_'), 2),
#  (('chrisbriano', '_jayfigs'), 2),
#  (('Ramsey_305', 'Wagner43371268'), 2),
#  (('tonyfinaugolf', 'NBA'), 1),
#  (('tonyfinaugolf', 'realgranthill33'), 1),
#  (('tonyfinaugolf', 'OrlandoMagic'), 1),
#  (('tonyfinaugolf', 'DetroitPistons'), 1),
#  (('LiveLoveSlush', 'Ballislife'), 1),
#  (('bablozapata', 'BleacherReport'), 1),
#  (('JMeuvi76', 'JMeuvi76'), 1),
#  (('JMeuvi76', 'BlackPressureC1'), 1),
#  (('JMeuvi76', 'MjsGoat'), 1),
#  (('2_fez', 'PuntsHeister'), 1),
#  (('2_fez', 'banks_220'), 1),
#  ...]

# %% [markdown]
# ### generate graph to analyze network measures

# %%
cluster_network = nx.DiGraph()

# %%
for edge in edges:
    cluster_network.add_edge(edge[0],edge[1],weight=edges[edge])

# %%
nx.triadic_census(cluster_network)
# Out:
# {'003': 13664612225,
#  '012': 15985466,
#  '021C': 876,
#  '021D': 2407,
#  '021U': 270157,
#  '030C': 0,
#  '030T': 88,
#  '102': 130251,
#  '111D': 24,
#  '111U': 43,
#  '120C': 0,
#  '120D': 2,
#  '120U': 22,
#  '201': 4,
#  '210': 0,
#  '300': 0}

# %% [markdown]
# ### generate hashtag coocurence graph for main cluster data

# %% [markdown]
# ##### find most used hashtags

# %%
hashtags = list()

for tweet,cluster in zip(collection.find({ "retweeted_status" : { "$exists" : False },'lang':'en' }),clusterizer.labels_):
    if(cluster==153):
        try:
            for hashtag in tweet['entities']['hashtags']:
                hashtags.append(hashtag['text'])
        except:
            pass
hashes = pd.DataFrame(hashtags,columns=['hashtags'])
hashes['hashtags'].value_counts()
# Out:
# NBA             247
# nba              56
# DFS              30
# NBATwitter       29
# basketball       20
#                ...
# SenseiSam         1
# sneakerheads      1
# SelltheTeam       1
# inplay            1
# LiangeloBall      1
# Name: hashtags, Length: 635, dtype: int64

# %% [markdown]
# ##### generate tuples of coocuring hashtags

# %%
cluster_hashtags = Counter()

# %%
for tweet,cluster in zip(collection.find({ "retweeted_status" : { "$exists" : False },'lang':'en' }),clusterizer.labels_):
    if(cluster==153):
        try:
            for pair in itertools.combinations(tweet['entities']['hashtags'],2):
                cluster_hashtags[frozenset([pair[0]['text'],pair[1]['text']])]+=1
        except:
            pass

# %%
cluster_hashtags.most_common()
# Out:
# [(frozenset({'DFS', 'NBA'}), 28),
#  (frozenset({'NBA', 'NBATwitter'}), 24),
#  (frozenset({'Celtics', 'NBA'}), 11),
#  (frozenset({'expertpicks', 'guaranteedpick'}), 8),
#  (frozenset({'NBA', 'basketball'}), 8),
#  (frozenset({'basketball', 'nba'}), 7),
#  (frozenset({'GrindCity', 'NBA'}), 6),
#  (frozenset({'Basketball', 'NBA'}), 6),
#  (frozenset({'NBA', 'NHL'}), 6),
#  (frozenset({'nba', 'nhl'}), 6),
#  (frozenset({'Fanduel', 'NBA'}), 6),
#  (frozenset({'feedly', 'sports'}), 6),
#  (frozenset({'BasketballCards', 'NBA'}), 5),
#  (frozenset({'NBA', 'WeGoHard'}), 5),
#  (frozenset({'DraftKings', 'NBA'}), 5),
#  (frozenset({'BeTheFight', 'NBA'}), 5),
#  (frozenset({'DFS', 'Fanduel'}), 5),
#  (frozenset({'MFFL', 'NBA'}), 5),
#  (frozenset({'nba', 'nfl'}), 5),
#  (frozenset({'Bucks', 'Pacers'}), 5),
#  (frozenset({'CBB', 'NBA'}), 5),
#  (frozenset({'NBA', 'TeamParieur'}), 4),
#  (frozenset({'Free', 'NBA'}), 4),
#  (frozenset({'Expert', 'NBA'}), 4),
#  (frozenset({'Betting', 'NBA'}), 4),
#  (frozenset({'NBA', 'Odds'}), 4),
#  (frozenset({'Basketball', 'Free'}), 4),
#  (frozenset({'Basketball', 'Expert'}), 4),
#  (frozenset({'Basketball', 'Betting'}), 4),
#  (frozenset({'Basketball', 'Odds'}), 4),
#  (frozenset({'Expert', 'Free'}), 4),
#  (frozenset({'Betting', 'Free'}), 4),
#  (frozenset({'Free', 'Odds'}), 4),
#  (frozenset({'Betting', 'Expert'}), 4),
#  (frozenset({'Expert', 'Odds'}), 4),
#  (frozenset({'Betting', 'Odds'}), 4),
#  (frozenset({'NBAPicks', 'NBATwitter'}), 4),
#  (frozenset({'NBA', 'WontBowDown'}), 4),
#  (frozenset({'GamblingTwitter', 'NBA'}), 4),
#  (frozenset({'Chicago', 'NBA'}), 4),
#  (frozenset({'GrindCity', 'WeGoHard'}), 4),
#  (frozenset({'Bulls', 'Chicago'}), 4),
#  (frozenset({'NBA', 'ThunderUp'}), 4),
#  (frozenset({'fanduel', 'nba'}), 4),
#  (frozenset({'dfs', 'fanduel'}), 4),
#  (frozenset({'dfs', 'nba'}), 4),
#  (frozenset({'NBA', 'NCAAB'}), 4),
#  (frozenset({'FanDuel', 'NBA'}), 4),
#  (frozenset({'fashion', 'poshmark'}), 4),
#  (frozenset({'lakers', 'nba'}), 3),
#  (frozenset({'2k20', 'nba'}), 3),
#  (frozenset({'nba', 'nba2k20'}), 3),
#  (frozenset({'2k20', 'nba2k20'}), 3),
#  (frozenset({'IndianaStyle', 'NBA'}), 3),
#  (frozenset({'NBATwitter', 'WontBowDown'}), 3),
#  (frozenset({'mlb', 'nba'}), 3),
#  (frozenset({'mlb', 'nfl'}), 3),
#  (frozenset({'LeBronJames', 'NBA'}), 3),
#  (frozenset({'bet', 'betting'}), 3),
#  (frozenset({'betting', 'bettingtips'}), 3),
#  (frozenset({'bettingtips', 'nba'}), 3),
#  (frozenset({'bet', 'bettingtips'}), 3),
#  (frozenset({'bettingtips', 'tipster'}), 3),
#  (frozenset({'FearTheDeer', 'NBA'}), 3),
#  (frozenset({'NBA', 'eBayAffiliate'}), 3),
#  (frozenset({'BasketballCards', 'eBayAffiliate'}), 3),
#  (frozenset({'DFS', 'FanDuel'}), 3),
#  (frozenset({'Basketball', 'Chicago'}), 3),
#  (frozenset({'Chicago', 'Free'}), 3),
#  (frozenset({'Chicago', 'Expert'}), 3),
#  (frozenset({'Betting', 'Chicago'}), 3),
#  (frozenset({'Chicago', 'Odds'}), 3),
#  (frozenset({'Bulls', 'NBA'}), 3),
#  (frozenset({'Basketball', 'Bulls'}), 3),
#  (frozenset({'Bulls', 'Free'}), 3),
#  (frozenset({'Bulls', 'Expert'}), 3),
#  (frozenset({'Betting', 'Bulls'}), 3),
#  (frozenset({'Bulls', 'Odds'}), 3),
#  (frozenset({'DFS', 'DraftKings'}), 3),
#  (frozenset({'MagicAboveAll', 'NBA'}), 3),
#  (frozenset({'CBB', 'NHL'}), 3),
#  (frozenset({'DetroitBasketball', 'NBA'}), 3),
#  (frozenset({'poshmark', 'style'}), 3),
#  (frozenset({'poshmark', 'shopmycloset'}), 3),
#  (frozenset({'fashion', 'style'}), 3),
#  (frozenset({'fashion', 'shopmycloset'}), 3),
#  (frozenset({'shopmycloset', 'style'}), 3),
#  (frozenset({'NBA', 'News'}), 3),
#  (frozenset({'NBA', 'Warriors'}), 2),
#  (frozenset({'lebronjames', 'nba'}), 2),
#  (frozenset({'lebron', 'nba'}), 2),
#  (frozenset({'lakers', 'losangeles'}), 2),
#  (frozenset({'lakers', 'lebronjames'}), 2),
#  (frozenset({'lakers', 'lebron'}), 2),
#  (frozenset({'lebron', 'lebronjames'}), 2),
#  (frozenset({'NBA', 'NBA2k20'}), 2),
#  (frozenset({'NBA2k20', 'badges'}), 2),
#  (frozenset({'NBA', 'badges'}), 2),
#  (frozenset({'deals', 'freebies'}), 2),
#  (frozenset({'deal', 'freebies'}), 2),
#  (frozenset({'freebies', 'moneysaver'}), 2),
#  (frozenset({'deal', 'deals'}), 2),
#  (frozenset({'deals', 'moneysaver'}), 2),
#  (frozenset({'deal', 'moneysaver'}), 2),
#  (frozenset({'Celtics', 'WeGoHard'}), 2),
#  (frozenset({'FreePicks', 'GamblingTwitter'}), 2),
#  (frozenset({'Denver', 'Nuggets'}), 2),
#  (frozenset({'Denver', 'NBA'}), 2),
#  (frozenset({'NBA', 'Nuggets'}), 2),
#  (frozenset({'NBA', 'NBAPicks'}), 2),
#  (frozenset({'Draftkings', 'Fanduel'}), 2),
#  (frozenset({'nhl', 'nhlpicks'}), 2),
#  (frozenset({'nba', 'nhlpicks'}), 2),
#  (frozenset({'GoPacers', 'NBA'}), 2),
#  (frozenset({'DraftKingsCheatsheet', 'NBA'}), 2),
#  (frozenset({'RepTheDistrict', 'RipCity'}), 2),
#  (frozenset({'DFS', 'NBATwitter'}), 2),
#  (frozenset({'Fanduel', 'NBATwitter'}), 2),
#  (frozenset({'nba', 'portland'}), 2),
#  (frozenset({'NBATwitter', 'NBAonTNT'}), 2),
#  (frozenset({'DFS', 'NHL'}), 2),
#  (frozenset({'FreePicks', 'NBA'}), 2),
#  (frozenset({'CHIvsMIN', 'NBA'}), 2),
#  (frozenset({'nba', 'warriors'}), 2),
#  (frozenset({'art', 'basketball'}), 2),
#  (frozenset({'2k', '2k20'}), 2),
#  (frozenset({'2k', 'nba'}), 2),
#  (frozenset({'2k', 'nba2k20'}), 2),
#  (frozenset({'basketball', 'lakers'}), 2),
#  (frozenset({'Grizzlies', 'NBA'}), 2),
#  (frozenset({'MFFL', 'NBATwitter'}), 2),
#  (frozenset({'MFFL', 'WontBowDown'}), 2),
#  (frozenset({'PrideNight', 'WeGoHard'}), 2),
#  (frozenset({'GrindCity', 'PrideNight'}), 2),
#  (frozenset({'NBA', 'PrideNight'}), 2),
#  (frozenset({'Grizzlies', 'Nets'}), 2),
#  (frozenset({'betoftheday', 'bettingtips'}), 2),
#  (frozenset({'betting', 'tipster'}), 2),
#  (frozenset({'bettingtips', 'expert'}), 2),
#  (frozenset({'bettingtips', 'nbabetting'}), 2),
#  (frozenset({'bettingtips', 'tips'}), 2),
#  (frozenset({'bet', 'tipster'}), 2),
#  (frozenset({'DraftDay', 'NBA'}), 2),
#  (frozenset({'Mensfashion', 'NBA'}), 2),
#  (frozenset({'NBA', 'drip'}), 2),
#  (frozenset({'DraftDay', 'NBATwitter'}), 2),
#  (frozenset({'DraftDay', 'Mensfashion'}), 2),
#  (frozenset({'DraftDay', 'drip'}), 2),
#  (frozenset({'Mensfashion', 'NBATwitter'}), 2),
#  (frozenset({'NBATwitter', 'drip'}), 2),
#  (frozenset({'Mensfashion', 'drip'}), 2),
#  (frozenset({'NBA', 'TakeNote'}), 2),
#  (frozenset({'FearTheDeer', 'ThunderUp'}), 2),
#  (frozenset({'TakeNote', 'ThunderUp'}), 2),
#  (frozenset({'FearTheDeer', 'TakeNote'}), 2),
#  (frozenset({'OklahomaCity', 'okc'}), 2),
#  (frozenset({'hiphop', 'hoodgrind'}), 2),
#  (frozenset({'hiphop', 'hiphopnews'}), 2),
#  (frozenset({'breakingnews', 'hiphop'}), 2),
#  (frozenset({'hiphopnews', 'hoodgrind'}), 2),
#  (frozenset({'breakingnews', 'hoodgrind'}), 2),
#  (frozenset({'breakingnews', 'hiphopnews'}), 2),
#  (frozenset({'FantasyBasketball', 'NBA'}), 2),
#  (frozenset({'MarchMadness', 'NBA'}), 2),
#  (frozenset({'nba', 'sportsbetting'}), 2),
#  (frozenset({'NBA', 'RipCity'}), 2),
#  (frozenset({'DraftKings', 'FanDuel'}), 2),
#  (frozenset({'CBB', 'POD'}), 2),
#  (frozenset({'CBB', 'PICKS'}), 2),
#  (frozenset({'CBB', 'PICK'}), 2),
#  (frozenset({'bettingtips', 'sportsbetting'}), 2),
#  (frozenset({'Lakers', 'NBA'}), 2),
#  (frozenset({'DetroitBasketball', 'ThunderUp'}), 2),
#  (frozenset({'BeTheFight', 'Celtics'}), 2),
#  (frozenset({'LetsGoMagic', 'NBA'}), 2),
#  (frozenset({'FearTheDeer', 'IndianaStyle'}), 2),
#  (frozenset({'nba', 'sports'}), 2),
#  (frozenset({'HEATTwitter', 'NBATwitter'}), 2),
#  (frozenset({'Celtics', 'MFFL'}), 2),
#  (frozenset({'NBA', 'UTAvsNYK'}), 2),
#  (frozenset({'clutchwin', 'xboxclips'}), 2),
#  (frozenset({'NBA', 'Timberwolves'}), 2),
#  (frozenset({'NBA', 'Thunder'}), 2),
#  (frozenset({'Jazz', 'Thunder'}), 2),
#  (frozenset({'StewsPicks', 'Thunder'}), 2),
#  (frozenset({'Cavaliers', 'Celtics'}), 2),
#  (frozenset({'Cavaliers', 'NBA'}), 2),
#  (frozenset({'NBA', 'Rockets'}), 2),
#  (frozenset({'nfl', 'nhl'}), 2),
#  (frozenset({'ncaa', 'nfl'}), 2),
#  (frozenset({'757sc', 'nfl'}), 2),
#  (frozenset({'mlb', 'nhl'}), 2),
#  (frozenset({'mlb', 'ncaa'}), 2),
#  (frozenset({'757sc', 'mlb'}), 2),
#  (frozenset({'nba', 'ncaa'}), 2),
#  (frozenset({'757sc', 'nba'}), 2),
#  (frozenset({'ncaa', 'nhl'}), 2),
#  (frozenset({'757sc', 'nhl'}), 2),
#  (frozenset({'757sc', 'ncaa'}), 2),
#  (frozenset({'NBA', 'OKCvsDET'}), 2),
#  (frozenset({'NBA', 'VIP'}), 2),
#  (frozenset({'NBA', 'SportsBetting'}), 2),
#  (frozenset({'GamblingTwitter', 'SportsBetting'}), 2),
#  (frozenset({'MarcusSmart', 'NBA'}), 2),
#  (frozenset({'AtlantaHawks', 'Klew'}), 2),
#  (frozenset({'NBA', 'TORvsGSW'}), 2),
#  (frozenset({'Cavs', 'NBA'}), 2),
#  (frozenset({'DFS', 'News'}), 2),
#  (frozenset({'football', 'nba'}), 2),
#  (frozenset({'TeamParieur', 'winamax'}), 1),
#  (frozenset({'NBA', 'winamax'}), 1),
#  (frozenset({'Celtics', 'GrindCity'}), 1),
#  (frozenset({'Mavs', 'NBA'}), 1),
#  (frozenset({'knicks', 'nyknicks'}), 1),
#  (frozenset({'knicks', 'newyorkknicks'}), 1),
#  (frozenset({'newyorkknicks', 'nyknicks'}), 1),
#  (frozenset({'Pistons', 'Suns'}), 1),
#  (frozenset({'GoldenStateWarriors', 'dubnation'}), 1),
#  (frozenset({'Warriors', 'dubnation'}), 1),
#  (frozenset({'NBA', 'dubnation'}), 1),
#  (frozenset({'GoldenStateWarriors', 'Warriors'}), 1),
#  (frozenset({'GoldenStateWarriors', 'NBA'}), 1),
#  (frozenset({'nba', 'taapathletics'}), 1),
#  (frozenset({'lakers', 'taapathletics'}), 1),
#  (frozenset({'losangeles', 'taapathletics'}), 1),
#  (frozenset({'la', 'taapathletics'}), 1),
#  (frozenset({'lakeshow', 'taapathletics'}), 1),
#  (frozenset({'nike', 'taapathletics'}), 1),
#  (frozenset({'lebronjames', 'taapathletics'}), 1),
#  (frozenset({'lebron', 'taapathletics'}), 1),
#  (frozenset({'king', 'taapathletics'}), 1),
#  (frozenset({'losangeles', 'nba'}), 1),
#  (frozenset({'la', 'nba'}), 1),
#  (frozenset({'lakeshow', 'nba'}), 1),
#  (frozenset({'nba', 'nike'}), 1),
#  (frozenset({'king', 'nba'}), 1),
#  (frozenset({'la', 'lakers'}), 1),
#  (frozenset({'lakers', 'lakeshow'}), 1),
#  (frozenset({'lakers', 'nike'}), 1),
#  (frozenset({'king', 'lakers'}), 1),
#  (frozenset({'la', 'losangeles'}), 1),
#  (frozenset({'lakeshow', 'losangeles'}), 1),
#  (frozenset({'losangeles', 'nike'}), 1),
#  (frozenset({'lebronjames', 'losangeles'}), 1),
#  (frozenset({'lebron', 'losangeles'}), 1),
#  (frozenset({'king', 'losangeles'}), 1),
#  (frozenset({'la', 'lakeshow'}), 1),
#  (frozenset({'la', 'nike'}), 1),
#  (frozenset({'la', 'lebronjames'}), 1),
#  (frozenset({'la', 'lebron'}), 1),
#  (frozenset({'king', 'la'}), 1),
#  (frozenset({'lakeshow', 'nike'}), 1),
#  (frozenset({'lakeshow', 'lebronjames'}), 1),
#  (frozenset({'lakeshow', 'lebron'}), 1),
#  (frozenset({'king', 'lakeshow'}), 1),
#  (frozenset({'lebronjames', 'nike'}), 1),
#  (frozenset({'lebron', 'nike'}), 1),
#  (frozenset({'king', 'nike'}), 1),
#  (frozenset({'king', 'lebronjames'}), 1),
#  (frozenset({'king', 'lebron'}), 1),
#  (frozenset({'MarketMover', 'NBA'}), 1),
#  (frozenset({'NBA', 'RadioTAB'}), 1),
#  (frozenset({'MarketMover', 'RadioTAB'}), 1),
#  (frozenset({'jordanmcrae', 'pistons'}), 1),
#  (frozenset({'pistons', 'troydaniels'}), 1),
#  (frozenset({'jordanmcrae', 'troydaniels'}), 1),
#  (frozenset({'KiaROTM', 'NBA'}), 1),
#  (frozenset({'Spurs', 'SpursNation'}), 1),
#  (frozenset({'PS4', 'Xbox'}), 1),
#  (frozenset({'Xbox', 'freebies'}), 1),
#  (frozenset({'Xbox', 'deals'}), 1),
#  (frozenset({'Xbox', 'deal'}), 1),
#  (frozenset({'Xbox', 'moneysaver'}), 1),
#  (frozenset({'Xbox', 'greatdeal'}), 1),
#  (frozenset({'Xbox', 'steals'}), 1),
#  (frozenset({'PS4', 'freebies'}), 1),
#  (frozenset({'PS4', 'deals'}), 1),
#  (frozenset({'PS4', 'deal'}), 1),
#  (frozenset({'PS4', 'moneysaver'}), 1),
#  (frozenset({'PS4', 'greatdeal'}), 1),
#  (frozenset({'PS4', 'steals'}), 1),
#  (frozenset({'freebies', 'greatdeal'}), 1),
#  (frozenset({'freebies', 'steals'}), 1),
#  (frozenset({'deals', 'greatdeal'}), 1),
#  (frozenset({'deals', 'steals'}), 1),
#  (frozenset({'deal', 'greatdeal'}), 1),
#  (frozenset({'deal', 'steals'}), 1),
#  (frozenset({'greatdeal', 'moneysaver'}), 1),
#  (frozenset({'moneysaver', 'steals'}), 1),
#  (frozenset({'greatdeal', 'steals'}), 1),
#  (frozenset({'GamblingTwitter', 'NBAPicks'}), 1),
#  (frozenset({'FreePicks', 'NBAPicks'}), 1),
#  (frozenset({'Kings', 'Sacramento'}), 1),
#  (frozenset({'Denver', 'Sacramento'}), 1),
#  (frozenset({'Nuggets', 'Sacramento'}), 1),
#  (frozenset({'NBA', 'Sacramento'}), 1),
#  (frozenset({'Basketball', 'Sacramento'}), 1),
#  (frozenset({'Free', 'Sacramento'}), 1),
#  (frozenset({'Expert', 'Sacramento'}), 1),
#  (frozenset({'Betting', 'Sacramento'}), 1),
#  (frozenset({'Odds', 'Sacramento'}), 1),
#  (frozenset({'Denver', 'Kings'}), 1),
#  (frozenset({'Kings', 'Nuggets'}), 1),
#  (frozenset({'Kings', 'NBA'}), 1),
#  (frozenset({'Basketball', 'Kings'}), 1),
#  (frozenset({'Free', 'Kings'}), 1),
#  (frozenset({'Expert', 'Kings'}), 1),
#  (frozenset({'Betting', 'Kings'}), 1),
#  (frozenset({'Kings', 'Odds'}), 1),
#  (frozenset({'Basketball', 'Denver'}), 1),
#  (frozenset({'Denver', 'Free'}), 1),
#  (frozenset({'Denver', 'Expert'}), 1),
#  (frozenset({'Betting', 'Denver'}), 1),
#  (frozenset({'Denver', 'Odds'}), 1),
#  (frozenset({'Basketball', 'Nuggets'}), 1),
#  (frozenset({'Free', 'Nuggets'}), 1),
#  (frozenset({'Expert', 'Nuggets'}), 1),
#  (frozenset({'Betting', 'Nuggets'}), 1),
#  (frozenset({'Nuggets', 'Odds'}), 1),
#  (frozenset({'NBA', 'RunWithUs'}), 1),
#  (frozenset({'NBATwitter', 'RunWithUs'}), 1),
#  (frozenset({'NBAPicks', 'RunWithUs'}), 1),
#  (frozenset({'borntobewild', 'okc'}), 1),
#  (frozenset({'borntobewild', 'downtownokc'}), 1),
#  (frozenset({'borntobewild', 'oklahoma'}), 1),
#  (frozenset({'borntobewild', 'oklahomacity'}), 1),
#  (frozenset({'downtownokc', 'okc'}), 1),
#  (frozenset({'okc', 'oklahoma'}), 1),
#  (frozenset({'okc', 'oklahomacity'}), 1),
#  (frozenset({'downtownokc', 'oklahoma'}), 1),
#  (frozenset({'downtownokc', 'oklahomacity'}), 1),
#  (frozenset({'oklahoma', 'oklahomacity'}), 1),
#  (frozenset({'InsideTheNBA', 'NBA'}), 1),
#  (frozenset({'NBA', 'Shaq'}), 1),
#  (frozenset({'NBA', 'TNTsports'}), 1),
#  (frozenset({'InsideTheNBA', 'Shaq'}), 1),
#  (frozenset({'InsideTheNBA', 'TNTsports'}), 1),
#  (frozenset({'Shaq', 'TNTsports'}), 1),
#  (frozenset({'2kCommunity', 'nba'}), 1),
#  (frozenset({'2kCommunity', 'xbox'}), 1),
#  (frozenset({'2k20', '2kCommunity'}), 1),
#  (frozenset({'2kCommunity', 'nba2k20'}), 1),
#  (frozenset({'2kCommunity', 'goat'}), 1),
#  (frozenset({'2kCommunity', 'powerdf'}), 1),
#  (frozenset({'2kCommunity', 'nadext'}), 1),
#  (frozenset({'nba', 'xbox'}), 1),
#  (frozenset({'goat', 'nba'}), 1),
#  (frozenset({'nba', 'powerdf'}), 1),
#  (frozenset({'nadext', 'nba'}), 1),
#  (frozenset({'2k20', 'xbox'}), 1),
#  (frozenset({'nba2k20', 'xbox'}), 1),
#  (frozenset({'goat', 'xbox'}), 1),
#  (frozenset({'powerdf', 'xbox'}), 1),
#  (frozenset({'nadext', 'xbox'}), 1),
#  (frozenset({'2k20', 'goat'}), 1),
#  (frozenset({'2k20', 'powerdf'}), 1),
#  (frozenset({'2k20', 'nadext'}), 1),
#  (frozenset({'goat', 'nba2k20'}), 1),
#  (frozenset({'nba2k20', 'powerdf'}), 1),
#  (frozenset({'nadext', 'nba2k20'}), 1),
#  (frozenset({'goat', 'powerdf'}), 1),
#  (frozenset({'goat', 'nadext'}), 1),
#  (frozenset({'nadext', 'powerdf'}), 1),
#  (frozenset({'NBA', 'OKC'}), 1),
#  (frozenset({'NBA', 'SAC'}), 1),
#  (frozenset({'NBA', 'TOR'}), 1),
#  (frozenset({'OKC', 'SAC'}), 1),
#  (frozenset({'OKC', 'TOR'}), 1),
#  (frozenset({'NHL', 'OKC'}), 1),
#  (frozenset({'SAC', 'TOR'}), 1),
#  (frozenset({'NHL', 'SAC'}), 1),
#  (frozenset({'NHL', 'TOR'}), 1),
#  (frozenset({'basketball', 'heart'}), 1),
#  (frozenset({'basketball', 'converse'}), 1),
#  (frozenset({'basketball', 'trickedkicks'}), 1),
#  (frozenset({'heart', 'nba'}), 1),
#  (frozenset({'converse', 'heart'}), 1),
#  (frozenset({'heart', 'trickedkicks'}), 1),
#  (frozenset({'converse', 'nba'}), 1),
#  (frozenset({'nba', 'trickedkicks'}), 1),
#  (frozenset({'converse', 'trickedkicks'}), 1),
#  (frozenset({'FacialRecognition', 'Walmart'}), 1),
#  (frozenset({'XBOX', 'eBay'}), 1),
#  (frozenset({'gamblingtwitter', 'nhlpicks'}), 1),
#  (frozenset({'nbatwitter', 'nhlpicks'}), 1),
#  (frozenset({'gamblingtwitter', 'nhl'}), 1),
#  (frozenset({'nbatwitter', 'nhl'}), 1),
#  (frozenset({'gamblingtwitter', 'nbatwitter'}), 1),
#  (frozenset({'gamblingtwitter', 'nba'}), 1),
#  (frozenset({'nba', 'nbatwitter'}), 1),
#  (frozenset({'atlanta', 'atlantahawks'}), 1),
#  (frozenset({'Bucs', 'IndianaStyle'}), 1),
#  (frozenset({'Bucs', 'GoPacers'}), 1),
#  (frozenset({'Bucs', 'NBA'}), 1),
#  (frozenset({'GoPacers', 'IndianaStyle'}), 1),
#  (frozenset({'Florida', 'Palisade'}), 1),
#  (frozenset({'Collection', 'Lakers'}), 1),
#  (frozenset({'NBA', 'SacramentoProud'}), 1),
#  (frozenset({'Pelicans', 'PelicansGameday'}), 1),
#  (frozenset({'Pelicans', 'WontBowDown'}), 1),
#  (frozenset({'NBA', 'Pelicans'}), 1),
#  (frozenset({'NBATwitter', 'Pelicans'}), 1),
#  (frozenset({'PelicansGameday', 'WontBowDown'}), 1),
#  (frozenset({'NBA', 'PelicansGameday'}), 1),
#  (frozenset({'NBATwitter', 'PelicansGameday'}), 1),
#  (frozenset({'Bucks', 'Warriors'}), 1),
#  (frozenset({'MontePolle', 'NBA'}), 1),
#  (frozenset({'MontePolle', 'Warriors'}), 1),
#  (frozenset({'oregonlive', 'portland'}), 1),
#  (frozenset({'mensgrooming', 'portland'}), 1),
#  (frozenset({'oregonbarber', 'portland'}), 1),
#  (frozenset({'pdx', 'portland'}), 1),
#  (frozenset({'portland', 'xfl'}), 1),
#  (frozenset({'mensgrooming', 'oregonlive'}), 1),
#  (frozenset({'oregonbarber', 'oregonlive'}), 1),
#  (frozenset({'oregonlive', 'pdx'}), 1),
#  (frozenset({'oregonlive', 'xfl'}), 1),
#  (frozenset({'nba', 'oregonlive'}), 1),
#  (frozenset({'mensgrooming', 'oregonbarber'}), 1),
#  (frozenset({'mensgrooming', 'pdx'}), 1),
#  (frozenset({'mensgrooming', 'xfl'}), 1),
#  (frozenset({'mensgrooming', 'nba'}), 1),
#  (frozenset({'oregonbarber', 'pdx'}), 1),
#  (frozenset({'oregonbarber', 'xfl'}), 1),
#  (frozenset({'nba', 'oregonbarber'}), 1),
#  (frozenset({'pdx', 'xfl'}), 1),
#  (frozenset({'nba', 'pdx'}), 1),
#  (frozenset({'nba', 'xfl'}), 1),
#  (frozenset({'basketball', 'memorabilia'}), 1),
#  (frozenset({'memorabilia', 'nba'}), 1),
#  (frozenset({'NBA', 'NBAonTNT'}), 1),
#  (frozenset({'Draftkings', 'NBADFS'}), 1),
#  (frozenset({'Fanduel', 'NBADFS'}), 1),
#  (frozenset({'NHL'}), 1),
#  (frozenset({'NBA', 'SportsBettingAdvice'}), 1),
#  (frozenset({'GrindCity', 'MFFL'}), 1),
#  (frozenset({'GamblingTwitter', 'GrindCity'}), 1),
#  (frozenset({'FreePicks', 'GrindCity'}), 1),
#  (frozenset({'GrindCity', 'SportsBettingAdvice'}), 1),
#  (frozenset({'GamblingTwitter', 'MFFL'}), 1),
#  (frozenset({'FreePicks', 'MFFL'}), 1),
#  (frozenset({'MFFL', 'SportsBettingAdvice'}), 1),
#  (frozenset({'GamblingTwitter', 'SportsBettingAdvice'}), 1),
#  (frozenset({'FreePicks', 'SportsBettingAdvice'}), 1),
#  (frozenset({'FBSM', 'Oklahoma'}), 1),
#  (frozenset({'ilovetimduncan', 'thetimeisright'}), 1),
#  (frozenset({'Detroit', 'RedWings'}), 1),
#  (frozenset({'Detroit', 'Pistons'}), 1),
#  (frozenset({'Detroit', 'Lions'}), 1),
#  (frozenset({'Detroit', 'Tigers'}), 1),
#  (frozenset({'Pistons', 'RedWings'}), 1),
#  (frozenset({'Lions', 'RedWings'}), 1),
#  (frozenset({'RedWings', 'Tigers'}), 1),
#  (frozenset({'Lions', 'Pistons'}), 1),
#  (frozenset({'Pistons', 'Tigers'}), 1),
#  (frozenset({'Lions', 'Tigers'}), 1),
#  (frozenset({'2K20', 'NBA'}), 1),
#  (frozenset({'NBATwitter', 'NFLTwitter'}), 1),
#  (frozenset({'NBATwitter', 'Nba'}), 1),
#  (frozenset({'NBATwitter', 'Nfl'}), 1),
#  (frozenset({'NFLTwitter', 'Nba'}), 1),
#  (frozenset({'NFLTwitter', 'Nfl'}), 1),
#  (frozenset({'Nba', 'Nfl'}), 1),
#  (frozenset({'NBA', 'Weekend'}), 1),
#  (frozenset({'NBA', 'Strippers'}), 1),
#  (frozenset({'Strippers', 'Weekend'}), 1),
#  (frozenset({'Chicago', 'Weekend'}), 1),
#  (frozenset({'Chicago', 'Strippers'}), 1),
#  (frozenset({'design', 'tshirt'}), 1),
#  (frozenset({'graphic', 'tshirt'}), 1),
#  (frozenset({'art', 'tshirt'}), 1),
#  (frozenset({'basketball', 'tshirt'}), 1),
#  (frozenset({'street', 'tshirt'}), 1),
#  (frozenset({'NBA', 'tshirt'}), 1),
#  (frozenset({'JBA', 'tshirt'}), 1),
#  (frozenset({'design', 'graphic'}), 1),
#  (frozenset({'art', 'design'}), 1),
#  (frozenset({'basketball', 'design'}), 1),
#  (frozenset({'design', 'street'}), 1),
#  (frozenset({'NBA', 'design'}), 1),
#  (frozenset({'JBA', 'design'}), 1),
#  (frozenset({'art', 'graphic'}), 1),
#  (frozenset({'basketball', 'graphic'}), 1),
#  (frozenset({'graphic', 'street'}), 1),
#  (frozenset({'NBA', 'graphic'}), 1),
#  (frozenset({'JBA', 'graphic'}), 1),
#  (frozenset({'art', 'street'}), 1),
#  (frozenset({'NBA', 'art'}), 1),
#  (frozenset({'JBA', 'art'}), 1),
#  (frozenset({'basketball', 'street'}), 1),
#  (frozenset({'JBA', 'basketball'}), 1),
#  (frozenset({'NBA', 'street'}), 1),
#  (frozenset({'JBA', 'street'}), 1),
#  (frozenset({'JBA', 'NBA'}), 1),
#  (frozenset({'76ers', 'thehobby'}), 1),
#  (frozenset({'76ers', 'whodoyoucollect'}), 1),
#  (frozenset({'thehobby', 'whodoyoucollect'}), 1),
#  (frozenset({'art', 'artist'}), 1),
#  (frozenset({'WednesdayMotivation', 'art'}), 1),
#  (frozenset({'art', 'blazers'}), 1),
#  (frozenset({'art', 'nba'}), 1),
#  (frozenset({'art', 'trailblazers'}), 1),
#  (frozenset({'art', 'portland'}), 1),
#  (frozenset({'WednesdayMotivation', 'artist'}), 1),
#  (frozenset({'artist', 'blazers'}), 1),
#  (frozenset({'artist', 'basketball'}), 1),
#  (frozenset({'artist', 'nba'}), 1),
#  (frozenset({'artist', 'trailblazers'}), 1),
#  (frozenset({'artist', 'portland'}), 1),
#  (frozenset({'WednesdayMotivation', 'blazers'}), 1),
#  (frozenset({'WednesdayMotivation', 'basketball'}), 1),
#  (frozenset({'WednesdayMotivation', 'nba'}), 1),
#  (frozenset({'WednesdayMotivation', 'trailblazers'}), 1),
#  (frozenset({'WednesdayMotivation', 'portland'}), 1),
#  (frozenset({'basketball', 'blazers'}), 1),
#  (frozenset({'blazers', 'nba'}), 1),
#  (frozenset({'blazers', 'trailblazers'}), 1),
#  (frozenset({'blazers', 'portland'}), 1),
#  (frozenset({'basketball', 'trailblazers'}), 1),
#  (frozenset({'basketball', 'portland'}), 1),
#  (frozenset({'nba', 'trailblazers'}), 1),
#  (frozenset({'portland', 'trailblazers'}), 1),
#  (frozenset({'game', 'nba'}), 1),
#  (frozenset({'nba', 'prono'}), 1),
#  (frozenset({'game', 'prono'}), 1),
#  (frozenset({'2k', '2kfreeagent'}), 1),
#  (frozenset({'2k20', '2kfreeagent'}), 1),
#  (frozenset({'2kfreeagent', 'nba'}), 1),
#  (frozenset({'2kfreeagent', 'nba2k20'}), 1),
#  (frozenset({'NoRimAllNetPod', 'WallpaperWednesday'}), 1),
#  (frozenset({'deccod', 'lebron'}), 1),
#  (frozenset({'deccod', 'nba'}), 1),
#  (frozenset({'basketball', 'deccod'}), 1),
#  (frozenset({'deccod', 'lakers'}), 1),
#  (frozenset({'deccod', 'lebronjames'}), 1),
#  (frozenset({'basketball', 'lebron'}), 1),
#  (frozenset({'basketball', 'lebronjames'}), 1),
#  (frozenset({'NBATwitter', 'Nbatwitter'}), 1),
#  (frozenset({'NBATwitter', 'Nfltwitter'}), 1),
#  (frozenset({'NBATwitter', 'nba'}), 1),
#  (frozenset({'NBATwitter', 'nfl'}), 1),
#  (frozenset({'NBATwitter', 'mlb'}), 1),
#  (frozenset({'Nbatwitter', 'Nfltwitter'}), 1),
#  (frozenset({'Nbatwitter', 'nba'}), 1),
#  (frozenset({'Nbatwitter', 'nfl'}), 1),
#  (frozenset({'Nbatwitter', 'mlb'}), 1),
#  (frozenset({'NBA', 'Nbatwitter'}), 1),
#  (frozenset({'Nfltwitter', 'nba'}), 1),
#  (frozenset({'Nfltwitter', 'nfl'}), 1),
#  (frozenset({'Nfltwitter', 'mlb'}), 1),
#  (frozenset({'NBA', 'Nfltwitter'}), 1),
#  (frozenset({'NBA', 'nba'}), 1),
#  (frozenset({'NBA', 'nfl'}), 1),
#  (frozenset({'NBA', 'mlb'}), 1),
#  (frozenset({'DolanWormhole', 'NBA'}), 1),
#  (frozenset({'OKC', 'Tulsa'}), 1),
#  (frozenset({'BettingPicks', 'NBA'}), 1),
#  (frozenset({'BettingPicks', 'NBATwitter'}), 1),
#  (frozenset({'BettingPicks', 'WontBowDown'}), 1),
#  (frozenset({'BettingPicks', 'MFFL'}), 1),
#  (frozenset({'NorthDakota', 'Palisade'}), 1),
#  (frozenset({'DK', 'NBA'}), 1),
#  (frozenset({'DFS', 'DK'}), 1),
#  (frozenset({'Covid_19', 'basketball'}), 1),
#  (frozenset({'CoronaOutbreak', 'basketball'}), 1),
#  (frozenset({'CoronaOutbreak', 'Covid_19'}), 1),
#  (frozenset({'LeBronJames', 'MVP'}), 1),
#  (frozenset({'MVP', 'NBA'}), 1),
#  (frozenset({'DefendTheLand', 'NBA'}), 1),
#  (frozenset({'NBA', 'mavs'}), 1),
#  (frozenset({'MarkCuban', 'mavs'}), 1),
#  (frozenset({'Luka', 'mavs'}), 1),
#  (frozenset({'MarkCuban', 'NBA'}), 1),
#  (frozenset({'Luka', 'NBA'}), 1),
#  (frozenset({'Luka', 'MarkCuban'}), 1),
#  (frozenset({'FtLauderdale', 'Miami'}), 1),
#  (frozenset({'KeyWest', 'Miami'}), 1),
#  (frozenset({'FtLauderdale', 'KeyWest'}), 1),
#  (frozenset({'LukaDoncic', 'ZionWilliamson'}), 1),
#  (frozenset({'AmericanAirlinesCenter', 'LukaDoncic'}), 1),
#  (frozenset({'AmericanAirlinesCenter', 'ZionWilliamson'}), 1),
#  (frozenset({'Nba', 'highlights'}), 1),
#  (frozenset({'Nba', 'sports'}), 1),
#  (frozenset({'Nba', 'betting'}), 1),
#  (frozenset({'Nba', 'bet'}), 1),
#  (frozenset({'Nba', 'bets'}), 1),
#  (frozenset({'Nba', 'wager'}), 1),
#  (frozenset({'Nba', 'parley'}), 1),
#  (frozenset({'Nba', 'tease'}), 1),
#  (frozenset({'highlights', 'sports'}), 1),
#  (frozenset({'betting', 'highlights'}), 1),
#  (frozenset({'bet', 'highlights'}), 1),
#  (frozenset({'bets', 'highlights'}), 1),
#  (frozenset({'highlights', 'wager'}), 1),
#  (frozenset({'highlights', 'parley'}), 1),
#  (frozenset({'highlights', 'tease'}), 1),
#  (frozenset({'betting', 'sports'}), 1),
#  (frozenset({'bet', 'sports'}), 1),
#  (frozenset({'bets', 'sports'}), 1),
#  (frozenset({'sports', 'wager'}), 1),
#  (frozenset({'parley', 'sports'}), 1),
#  (frozenset({'sports', 'tease'}), 1),
#  (frozenset({'bets', 'betting'}), 1),
#  (frozenset({'betting', 'wager'}), 1),
#  (frozenset({'betting', 'parley'}), 1),
#  (frozenset({'betting', 'tease'}), 1),
#  (frozenset({'bet', 'bets'}), 1),
#  (frozenset({'bet', 'wager'}), 1),
#  (frozenset({'bet', 'parley'}), 1),
#  (frozenset({'bet', 'tease'}), 1),
#  (frozenset({'bets', 'wager'}), 1),
#  (frozenset({'bets', 'parley'}), 1),
#  (frozenset({'bets', 'tease'}), 1),
#  (frozenset({'parley', 'wager'}), 1),
#  (frozenset({'tease', 'wager'}), 1),
#  (frozenset({'parley', 'tease'}), 1),
#  (frozenset({'Bulls', 'Cubs'}), 1),
#  (frozenset({'Bears', 'Bulls'}), 1),
#  (frozenset({'Bears', 'Cubs'}), 1),
#  (frozenset({'JamesDolanGottaGo', 'MakeJamesDolanSell'}), 1),
#  (frozenset({'JamesDolanGottaGo', 'NewYorkForever'}), 1),
#  (frozenset({'MakeJamesDolanSell', 'NewYorkForever'}), 1),
#  (frozenset({'fanduel', 'fever'}), 1),
#  (frozenset({'betoftheday', 'betting'}), 1),
#  (frozenset({'betoftheday', 'expert'}), 1),
#  (frozenset({'betoftheday', 'nbabetting'}), 1),
#  (frozenset({'betoftheday', 'nba'}), 1),
#  (frozenset({'bet', 'betoftheday'}), 1),
#  (frozenset({'betoftheday', 'tips'}), 1),
#  (frozenset({'betoftheday', 'tipster'}), 1),
#  (frozenset({'betting', 'expert'}), 1),
#  (frozenset({'betting', 'nbabetting'}), 1),
#  (frozenset({'betting', 'nba'}), 1),
#  (frozenset({'betting', 'tips'}), 1),
#  (frozenset({'bettingtips'}), 1),
#  (frozenset({'expert', 'nbabetting'}), 1),
#  (frozenset({'expert', 'nba'}), 1),
#  (frozenset({'bet', 'expert'}), 1),
#  (frozenset({'expert', 'tips'}), 1),
#  (frozenset({'expert', 'tipster'}), 1),
#  (frozenset({'nba', 'nbabetting'}), 1),
#  (frozenset({'bet', 'nbabetting'}), 1),
#  (frozenset({'nbabetting', 'tips'}), 1),
#  (frozenset({'nbabetting', 'tipster'}), 1),
#  (frozenset({'bet', 'nba'}), 1),
#  (frozenset({'nba', 'tips'}), 1),
#  (frozenset({'nba', 'tipster'}), 1),
#  (frozenset({'bet', 'tips'}), 1),
#  (frozenset({'tips', 'tipster'}), 1),
#  (frozenset({'Chicago', 'MichaelJordan'}), 1),
#  (frozenset({'Bulls', 'MichaelJordan'}), 1),
#  (frozenset({'AUCTION', 'MichaelJordan'}), 1),
#  (frozenset({'AUCTION', 'Chicago'}), 1),
#  (frozenset({'AUCTION', 'Bulls'}), 1),
#  (frozenset({'nba', 'stocks'}), 1),
#  (frozenset({'ED', 'NBA'}), 1),
#  (frozenset({'BasketballCards', 'ED'}), 1),
#  (frozenset({'ED', 'eBayAffiliate'}), 1),
#  (frozenset({'MonkeyKnifeFight', 'NBA'}), 1),
#  (frozenset({'DFS', 'MonkeyKnifeFight'}), 1),
#  (frozenset({'FanDuel', 'MonkeyKnifeFight'}), 1),
#  (frozenset({'Knicks', 'SpikeLee'}), 1),
#  (frozenset({'PacersvsBucks', 'Wizards'}), 1),
#  (frozenset({'FreePicks', 'PacersvsBucks'}), 1),
#  (frozenset({'DonGamer', 'PacersvsBucks'}), 1),
#  (frozenset({'DG', 'PacersvsBucks'}), 1),
#  (frozenset({'FreePicks', 'Wizards'}), 1),
#  (frozenset({'DonGamer', 'Wizards'}), 1),
#  (frozenset({'DG', 'Wizards'}), 1),
#  (frozenset({'DonGamer', 'FreePicks'}), 1),
#  (frozenset({'DG', 'FreePicks'}), 1),
#  (frozenset({'DG', 'DonGamer'}), 1),
#  (frozenset({'Gamblingtwitter', 'freepicks'}), 1),
#  (frozenset({'Gamblingtwitter', 'sportsgambling'}), 1),
#  (frozenset({'Gamblingtwitter', 'sportspicks'}), 1),
#  (frozenset({'freepicks', 'sportsgambling'}), 1),
#  (frozenset({'freepicks', 'sportspicks'}), 1),
#  (frozenset({'sportsgambling', 'sportspicks'}), 1),
#  (frozenset({'WCWS', 'softball'}), 1),
#  (frozenset({'OKC', 'WCWS'}), 1),
#  (frozenset({'USAhalloffamestadium', 'WCWS'}), 1),
#  (frozenset({'OKC', 'softball'}), 1),
#  (frozenset({'USAhalloffamestadium', 'softball'}), 1),
#  (frozenset({'OKC', 'USAhalloffamestadium'}), 1),
#  (frozenset({'Gamblingtwitter', 'nba'}), 1),
#  (frozenset({'PRONOCHTIC', 'RT'}), 1),
#  (frozenset({'Vimeo', 'nbapicks'}), 1),
#  (frozenset({'Vimeo', 'freepicks'}), 1),
#  (frozenset({'Vimeo', 'nbatwitter'}), 1),
#  (frozenset({'freepicks', 'nbapicks'}), 1),
#  (frozenset({'nbapicks', 'nbatwitter'}), 1),
#  (frozenset({'freepicks', 'nbatwitter'}), 1),
#  (frozenset({'CoronaOutbreak', 'Japan'}), 1),
#  (frozenset({'Japan', 'Miami'}), 1),
#  (frozenset({'CoronaOutbreak', 'Miami'}), 1),
#  (frozenset({'AFLW', 'NBLFinals'}), 1),
#  (frozenset({'DEN', 'NBA'}), 1),
#  (frozenset({'Celtics', 'NBAtwitter'}), 1),
#  (frozenset({'Celtics', 'French'}), 1),
#  (frozenset({'NBA', 'NBAtwitter'}), 1),
#  (frozenset({'French', 'NBA'}), 1),
#  (frozenset({'French', 'NBAtwitter'}), 1),
#  (frozenset({'Boston', 'Chicago'}), 1),
#  (frozenset({'Celtics', 'Chicago'}), 1),
#  (frozenset({'Boston', 'Bulls'}), 1),
#  (frozenset({'Bulls', 'Celtics'}), 1),
#  (frozenset({'Boston', 'Celtics'}), 1),
#  (frozenset({'Boston', 'NBA'}), 1),
#  (frozenset({'Basketball', 'Boston'}), 1),
#  (frozenset({'Boston', 'Free'}), 1),
#  (frozenset({'Boston', 'Expert'}), 1),
#  (frozenset({'Betting', 'Boston'}), 1),
#  (frozenset({'Boston', 'Odds'}), 1),
#  (frozenset({'Basketball', 'Celtics'}), 1),
#  (frozenset({'Celtics', 'Free'}), 1),
#  (frozenset({'Celtics', 'Expert'}), 1),
#  (frozenset({'Betting', 'Celtics'}), 1),
#  (frozenset({'Celtics', 'Odds'}), 1),
#  (frozenset({'FREEPICKS', 'NBA'}), 1),
#  (frozenset({'SoundCloud', 'np'}), 1),
#  (frozenset({'BennetLakersGameSumUp', 'LakeShow'}), 1),
#  (frozenset({'BennetLakersGameSumUp', 'PhilaUnite'}), 1),
#  (frozenset({'LakeShow', 'PhilaUnite'}), 1),
#  (frozenset({'cbd', 'spain'}), 1),
#  (frozenset({'NBA', 'PowerOfThePack'}), 1),
#  (frozenset({'NBA', 'sneakerheads'}), 1),
#  (frozenset({'NBA', 'Sixers'}), 1),
#  (frozenset({'Minnesota', 'Timberwolves'}), 1),
#  (frozenset({'FreePicks', 'SenseiSam'}), 1),
#  (frozenset({'BOS', 'MIA'}), 1),
#  (frozenset({'BOS', 'UTA'}), 1),
#  (frozenset({'BOS', 'NYK'}), 1),
#  (frozenset({'BOS', 'NorthernKnightSportsBetting'}), 1),
#  (frozenset({'MIA', 'UTA'}), 1),
#  (frozenset({'MIA', 'NYK'}), 1),
#  (frozenset({'MIA', 'NorthernKnightSportsBetting'}), 1),
#  (frozenset({'NYK', 'UTA'}), 1),
#  (frozenset({'NorthernKnightSportsBetting', 'UTA'}), 1),
#  (frozenset({'NYK', 'NorthernKnightSportsBetting'}), 1),
#  (frozenset({'NBA', 'NYKnicks'}), 1),
#  (frozenset({'76ers', 'Alhorford'}), 1),
#  (frozenset({'76ers', 'Libertycitysports'}), 1),
#  (frozenset({'Alhorford', 'Libertycitysports'}), 1),
#  (frozenset({'basketball', 'braggadocios'}), 1),
#  (frozenset({'basketball', 'gram'}), 1),
#  (frozenset({'basketball', 'instagram'}), 1),
#  (frozenset({'braggadocios', 'gram'}), 1),
#  (frozenset({'braggadocios', 'instagram'}), 1),
#  (frozenset({'braggadocios', 'lakers'}), 1),
#  (frozenset({'gram', 'instagram'}), 1),
#  (frozenset({'gram', 'lakers'}), 1),
#  (frozenset({'instagram', 'lakers'}), 1),
#  (frozenset({'NBA'}), 1),
#  (frozenset({'nytimes', 'wsj'}), 1),
#  (frozenset({'business', 'wsj'}), 1),
#  (frozenset({'reuters', 'wsj'}), 1),
#  (frozenset({'forbes', 'wsj'}), 1),
#  (frozenset({'nasdaq', 'wsj'}), 1),
#  (frozenset({'cnn', 'wsj'}), 1),
#  (frozenset({'bet', 'wsj'}), 1),
#  (frozenset({'foxnews', 'wsj'}), 1),
#  (frozenset({'business', 'nytimes'}), 1),
#  (frozenset({'nytimes', 'reuters'}), 1),
#  (frozenset({'forbes', 'nytimes'}), 1),
#  (frozenset({'nasdaq', 'nytimes'}), 1),
#  (frozenset({'cnn', 'nytimes'}), 1),
#  (frozenset({'bet', 'nytimes'}), 1),
#  (frozenset({'foxnews', 'nytimes'}), 1),
#  (frozenset({'business', 'reuters'}), 1),
#  (frozenset({'business', 'forbes'}), 1),
#  (frozenset({'business', 'nasdaq'}), 1),
#  (frozenset({'business', 'cnn'}), 1),
#  (frozenset({'bet', 'business'}), 1),
#  (frozenset({'business', 'foxnews'}), 1),
#  (frozenset({'forbes', 'reuters'}), 1),
#  (frozenset({'nasdaq', 'reuters'}), 1),
#  (frozenset({'cnn', 'reuters'}), 1),
#  (frozenset({'bet', 'reuters'}), 1),
#  (frozenset({'foxnews', 'reuters'}), 1),
#  (frozenset({'forbes', 'nasdaq'}), 1),
#  (frozenset({'cnn', 'forbes'}), 1),
#  (frozenset({'bet', 'forbes'}), 1),
#  (frozenset({'forbes', 'foxnews'}), 1),
#  (frozenset({'cnn', 'nasdaq'}), 1),
#  (frozenset({'bet', 'nasdaq'}), 1),
#  (frozenset({'foxnews', 'nasdaq'}), 1),
#  (frozenset({'bet', 'cnn'}), 1),
#  (frozenset({'cnn', 'foxnews'}), 1),
#  (frozenset({'bet', 'foxnews'}), 1),
#  (frozenset({'UFC', 'WWE'}), 1),
#  (frozenset({'AEW', 'UFC'}), 1),
#  (frozenset({'NFL', 'UFC'}), 1),
#  (frozenset({'UFC', 'XFL'}), 1),
#  (frozenset({'NWA', 'UFC'}), 1),
#  (frozenset({'MarchMadness', 'UFC'}), 1),
#  (frozenset({'NBA', 'UFC'}), 1),
#  (frozenset({'Pacers', 'UFC'}), 1),
#  (frozenset({'ClipperNation', 'UFC'}), 1),
#  (frozenset({'LakeShow', 'UFC'}), 1),
#  (frozenset({'AEW', 'WWE'}), 1),
#  (frozenset({'NFL', 'WWE'}), 1),
#  (frozenset({'WWE', 'XFL'}), 1),
#  (frozenset({'NWA', 'WWE'}), 1),
#  (frozenset({'MarchMadness', 'WWE'}), 1),
#  (frozenset({'NBA', 'WWE'}), 1),
#  (frozenset({'Pacers', 'WWE'}), 1),
#  (frozenset({'ClipperNation', 'WWE'}), 1),
#  (frozenset({'LakeShow', 'WWE'}), 1),
#  (frozenset({'AEW', 'NFL'}), 1),
#  (frozenset({'AEW', 'XFL'}), 1),
#  (frozenset({'AEW', 'NWA'}), 1),
#  (frozenset({'AEW', 'MarchMadness'}), 1),
#  (frozenset({'AEW', 'NBA'}), 1),
#  (frozenset({'AEW', 'Pacers'}), 1),
#  (frozenset({'AEW', 'ClipperNation'}), 1),
#  (frozenset({'AEW', 'LakeShow'}), 1),
#  (frozenset({'NFL', 'XFL'}), 1),
#  (frozenset({'NFL', 'NWA'}), 1),
#  (frozenset({'MarchMadness', 'NFL'}), 1),
#  (frozenset({'NBA', 'NFL'}), 1),
#  (frozenset({'NFL', 'Pacers'}), 1),
#  (frozenset({'ClipperNation', 'NFL'}), 1),
#  (frozenset({'LakeShow', 'NFL'}), 1),
#  (frozenset({'NWA', 'XFL'}), 1),
#  (frozenset({'MarchMadness', 'XFL'}), 1),
#  (frozenset({'NBA', 'XFL'}), 1),
#  (frozenset({'Pacers', 'XFL'}), 1),
#  (frozenset({'ClipperNation', 'XFL'}), 1),
#  (frozenset({'LakeShow', 'XFL'}), 1),
#  (frozenset({'MarchMadness', 'NWA'}), 1),
#  (frozenset({'NBA', 'NWA'}), 1),
#  (frozenset({'NWA', 'Pacers'}), 1),
#  (frozenset({'ClipperNation', 'NWA'}), 1),
#  (frozenset({'LakeShow', 'NWA'}), 1),
#  (frozenset({'MarchMadness', 'Pacers'}), 1),
#  (frozenset({'ClipperNation', 'MarchMadness'}), 1),
#  (frozenset({'LakeShow', 'MarchMadness'}), 1),
#  (frozenset({'NBA', 'Pacers'}), 1),
#  (frozenset({'ClipperNation', 'NBA'}), 1),
#  (frozenset({'LakeShow', 'NBA'}), 1),
#  (frozenset({'ClipperNation', 'Pacers'}), 1),
#  (frozenset({'LakeShow', 'Pacers'}), 1),
#  (frozenset({'ClipperNation', 'LakeShow'}), 1),
#  (frozenset({'SportsGambling', 'Winning'}), 1),
#  (frozenset({'NBA', 'SportsGambling'}), 1),
#  (frozenset({'NCAAB', 'SportsGambling'}), 1),
#  (frozenset({'Cash', 'SportsGambling'}), 1),
#  (frozenset({'NBA', 'Winning'}), 1),
#  (frozenset({'NCAAB', 'Winning'}), 1),
#  (frozenset({'Cash', 'Winning'}), 1),
#  (frozenset({'Cash', 'NBA'}), 1),
#  (frozenset({'Cash', 'NCAAB'}), 1),
#  (frozenset({'Dolan', 'Melnyk'}), 1),
#  (frozenset({'nhl', 'sportsbetting'}), 1),
#  (frozenset({'NBA', 'Predictions'}), 1),
#  (frozenset({'NBA', 'collegebasketball'}), 1),
#  (frozenset({'MFFL', 'RipCity'}), 1),
#  (frozenset({'IndianaStyle', 'RipCity'}), 1),
#  (frozenset({'MagicAboveAll', 'RipCity'}), 1),
#  (frozenset({'DFS', 'RipCity'}), 1),
#  (frozenset({'DraftKings', 'RipCity'}), 1),
#  (frozenset({'FanDuel', 'RipCity'}), 1),
#  (frozenset({'IndianaStyle', 'MFFL'}), 1),
#  (frozenset({'MFFL', 'MagicAboveAll'}), 1),
#  (frozenset({'DFS', 'MFFL'}), 1),
#  (frozenset({'DraftKings', 'MFFL'}), 1),
#  (frozenset({'FanDuel', 'MFFL'}), 1),
#  (frozenset({'IndianaStyle', 'MagicAboveAll'}), 1),
#  (frozenset({'DFS', 'IndianaStyle'}), 1),
#  (frozenset({'DraftKings', 'IndianaStyle'}), 1),
#  (frozenset({'FanDuel', 'IndianaStyle'}), 1),
#  (frozenset({'DFS', 'MagicAboveAll'}), 1),
#  (frozenset({'DraftKings', 'MagicAboveAll'}), 1),
#  (frozenset({'FanDuel', 'MagicAboveAll'}), 1),
#  (frozenset({'ProLyticsAI', 'fanduel'}), 1),
#  (frozenset({'NCAAB', 'WeGoHard'}), 1),
#  (frozenset({'NBA', 'cheatsheet'}), 1),
#  (frozenset({'NBA', 'RT'}), 1),
#  (frozenset({'RT', 'cheatsheet'}), 1),
#  (frozenset({'NBA', 'POD'}), 1),
#  (frozenset({'PICKS', 'POD'}), 1),
#  (frozenset({'NHL', 'POD'}), 1),
#  (frozenset({'PICK', 'POD'}), 1),
#  (frozenset({'NBA', 'PICKS'}), 1),
#  (frozenset({'NBA', 'PICK'}), 1),
#  (frozenset({'CBB'}), 1),
#  (frozenset({'NHL', 'PICKS'}), 1),
#  (frozenset({'PICK', 'PICKS'}), 1),
#  (frozenset({'NHL', 'PICK'}), 1),
#  (frozenset({'Coronavirus', 'NBA'}), 1),
#  (frozenset({'Coronavirus', 'health'}), 1),
#  (frozenset({'COVID19', 'Coronavirus'}), 1),
#  (frozenset({'Coronavirus', 'virus'}), 1),
#  (frozenset({'Coronavirus', 'CoronavirusOutbreak'}), 1),
#  (frozenset({'NBA', 'health'}), 1),
#  (frozenset({'COVID19', 'NBA'}), 1),
#  (frozenset({'NBA', 'virus'}), 1),
#  (frozenset({'CoronavirusOutbreak', 'NBA'}), 1),
#  (frozenset({'COVID19', 'health'}), 1),
#  (frozenset({'health', 'virus'}), 1),
#  (frozenset({'CoronavirusOutbreak', 'health'}), 1),
#  (frozenset({'COVID19', 'virus'}), 1),
#  (frozenset({'COVID19', 'CoronavirusOutbreak'}), 1),
#  (frozenset({'CoronavirusOutbreak', 'virus'}), 1),
#  (frozenset({'NBA', 'photooftheday'}), 1),
#  (frozenset({'NBA', 'beautiful'}), 1),
#  (frozenset({'NBA', 'fashion'}), 1),
#  (frozenset({'NBA', 'happy'}), 1),
#  (frozenset({'NBA', 'tbt'}), 1),
#  (frozenset({'NBA', 'cute'}), 1),
#  (frozenset({'NBA', 'instagood'}), 1),
#  (frozenset({'NBA', 'love'}), 1),
#  (frozenset({'beautiful', 'photooftheday'}), 1),
#  (frozenset({'fashion', 'photooftheday'}), 1),
#  (frozenset({'happy', 'photooftheday'}), 1),
#  (frozenset({'photooftheday', 'tbt'}), 1),
#  (frozenset({'cute', 'photooftheday'}), 1),
#  (frozenset({'instagood', 'photooftheday'}), 1),
#  (frozenset({'love', 'photooftheday'}), 1),
#  (frozenset({'beautiful', 'fashion'}), 1),
#  (frozenset({'beautiful', 'happy'}), 1),
#  (frozenset({'beautiful', 'tbt'}), 1),
#  (frozenset({'beautiful', 'cute'}), 1),
#  (frozenset({'beautiful', 'instagood'}), 1),
#  (frozenset({'beautiful', 'love'}), 1),
#  (frozenset({'fashion', 'happy'}), 1),
#  (frozenset({'fashion', 'tbt'}), 1),
#  (frozenset({'cute', 'fashion'}), 1),
#  (frozenset({'fashion', 'instagood'}), 1),
#  (frozenset({'fashion', 'love'}), 1),
#  (frozenset({'happy', 'tbt'}), 1),
#  (frozenset({'cute', 'happy'}), 1),
#  (frozenset({'happy', 'instagood'}), 1),
#  (frozenset({'happy', 'love'}), 1),
#  (frozenset({'cute', 'tbt'}), 1),
#  (frozenset({'instagood', 'tbt'}), 1),
#  (frozenset({'love', 'tbt'}), 1),
#  (frozenset({'cute', 'instagood'}), 1),
#  (frozenset({'cute', 'love'}), 1),
#  (frozenset({'instagood', 'love'}), 1),
#  (frozenset({'NBA', 'TheBasketballFans'}), 1),
#  (frozenset({'nbapicks', 'sportsbetting'}), 1),
#  (frozenset({'bettingbetter', 'sportsbetting'}), 1),
#  (frozenset({'GamblingTwitter', 'sportsbetting'}), 1),
#  (frozenset({'bettingtips', 'nbapicks'}), 1),
#  (frozenset({'bettingbetter', 'bettingtips'}), 1),
#  (frozenset({'GamblingTwitter', 'bettingtips'}), 1),
#  (frozenset({'nba', 'nbapicks'}), 1),
#  (frozenset({'bettingbetter', 'nba'}), 1),
#  (frozenset({'GamblingTwitter', 'nba'}), 1),
#  (frozenset({'bettingbetter', 'nbapicks'}), 1),
#  (frozenset({'GamblingTwitter', 'nbapicks'}), 1),
#  (frozenset({'GamblingTwitter', 'bettingbetter'}), 1),
#  (frozenset({'KobeBryant', 'NBA'}), 1),
#  (frozenset({'BallorFall', 'KobeBryant'}), 1),
#  (frozenset({'KobeBryant', 'Lakers'}), 1),
#  (frozenset({'BallorFall', 'NBA'}), 1),
#  (frozenset({'BallorFall', 'Lakers'}), 1),
#  (frozenset({'NeonDeion', 'Primetime'}), 1),
#  (frozenset({'CoronaAlert', 'NBA'}), 1),
#  (frozenset({'CoronaAlert', 'FearTheDeer'}), 1),
#  (frozenset({'Capping', 'tips'}), 1),
#  (frozenset({'Celtics', 'NBATwitter'}), 1),
#  (frozenset({'BeTheFight', 'NBATwitter'}), 1),
#  (frozenset({'Jets', 'Love'}), 1),
#  (frozenset({'Jets', 'Romantic'}), 1),
#  (frozenset({'Love', 'Romantic'}), 1),
#  (frozenset({'76ers', 'lakers'}), 1),
#  (frozenset({'FREE', 'NBA'}), 1),
#  (frozenset({'africa', 'basketball'}), 1),
#  (frozenset({'basketball', 'league'}), 1),
#  (frozenset({'africa', 'league'}), 1),
#  (frozenset({'NBATwitter', 'ThunderUp'}), 1),
#  (frozenset({'DetroitBasketball', 'NBATwitter'}), 1),
#  (frozenset({'Nuggets', 'released'}), 1),
#  (frozenset({'Nuggets', 'signed'}), 1),
#  (frozenset({'Nuggets', 'sports'}), 1),
#  (frozenset({'BREAKING_NEWS', 'Nuggets'}), 1),
#  (frozenset({'Denver', 'released'}), 1),
#  (frozenset({'Denver', 'signed'}), 1),
#  (frozenset({'Denver', 'sports'}), 1),
#  (frozenset({'BREAKING_NEWS', 'Denver'}), 1),
#  (frozenset({'NBA', 'released'}), 1),
#  (frozenset({'NBA', 'signed'}), 1),
#  (frozenset({'NBA', 'sports'}), 1),
#  (frozenset({'BREAKING_NEWS', 'NBA'}), 1),
#  (frozenset({'released', 'signed'}), 1),
#  (frozenset({'released', 'sports'}), 1),
#  (frozenset({'BREAKING_NEWS', 'released'}), 1),
#  (frozenset({'signed', 'sports'}), 1),
#  (frozenset({'BREAKING_NEWS', 'signed'}), 1),
#  (frozenset({'BREAKING_NEWS', 'sports'}), 1),
#  (frozenset({'gaming', 'nba'}), 1),
#  (frozenset({'gaming', 'nba2k20'}), 1),
#  (frozenset({'2k20', 'gaming'}), 1),
#  (frozenset({'2k', 'gaming'}), 1),
#  (frozenset({'IndianaStyle', 'NBATwitter'}), 1),
#  (frozenset({'FearTheDeer', 'NBATwitter'}), 1),
#  (frozenset({'las_vegas', 'nba'}), 1),
#  (frozenset({'las_vegas', 'sports'}), 1),
#  ...]

# %% [markdown]
# ### code for generating csv sample data

# %%
data_sample = collection.aggregate([{'$sample':{'size':100}}])
data_sample = list(data_sample)
data_sample = pd.DataFrame(data_sample)
data_sample.to_csv('sample.csv')
